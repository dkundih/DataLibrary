# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
df = pd.read_excel(r'C:\Users\kundi\Desktop\data.xlsx')

# %%
plt.figure(figsize=(20,8))
plt.scatter(x = df['Naziv_pozicije'], y = df[2017], label = '2017')
plt.scatter(x = df['Naziv_pozicije'], y = df[2018], label = '2018')
plt.scatter(x = df['Naziv_pozicije'], y = df[2019], label = '2019')
plt.scatter(x = df['Naziv_pozicije'], y = df[2020], label = '2020')
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
#df.set_index('Naziv pozicije', inplace = True)

# %%
df
# Out:
#                                        Naziv_pozicije      2017      2018  \
# 0                             B)  DUGOTRAJNA IMOVINA   0.837504  0.818882
# 1                              NEMATERIJALNA_IMOVINA   0.006199  0.005562
# 2                                 1. Izdaci za razvoj  0.000000  0.000000
# 3       2. Koncesije, patenti, licencije, robne i ...  0.005409  0.004422
# 4                                         3. Goodwill  0.000000  0.000000
# 5       4. Predujmovi za nabavu nematerijalne imovine  0.000000  0.000000
# 6                 5. Nematerijalna imovina u pripremi  0.000781  0.001136
# 7                     6. Ostala nematerijalna imovina  0.000009  0.000004
# 8                             II. MATERIJALNA IMOVINA  0.806234  0.782344
# 9                                        1. Zemljište  0.026659  0.025716
# 10                             2. Građevinski objekti  0.284325  0.269165
# 11                           3. Postrojenja i oprema   0.419073  0.424717
# ...

# %%
df1 = pd.read_excel(r'C:\Users\kundi\Desktop\data2.xlsx')

# %%
plt.figure(figsize=(15,10))
plt.scatter(y = df1['Naziv_pozicije'], x = df1[2017], label = '2017')
plt.scatter(y = df1['Naziv_pozicije'], x = df1[2018], label = '2018')
plt.scatter(y = df1['Naziv_pozicije'], x = df1[2019], label = '2019')
plt.scatter(y = df1['Naziv_pozicije'], x = df1[2020], label = '2020')
plt.ticklabel_format(style='plain', axis='x')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
df2 = pd.read_excel(r'C:\Users\kundi\Desktop\data3.xlsx')

# %%
plt.figure(figsize=(20,10))
plt.scatter(x = df2['Naziv_pozicije'], y = df2[2017], label = '2017')
plt.scatter(x = df2['Naziv_pozicije'], y = df2[2018], label = '2018')
plt.scatter(x = df2['Naziv_pozicije'], y = df2[2019], label = '2019')
plt.scatter(x = df2['Naziv_pozicije'], y = df2[2020], label = '2020')
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
dobit = pd.DataFrame({
    '2017' : [1300298679],
    '2018' : [1364751975],
    '2019' : [1404002155],
    '2020' : [1465144387],
})

# %%
dobit.iloc[0]
# Out:
# 2017    1300298679
# 2018    1364751975
# 2019    1404002155
# 2020    1465144387
# Name: 0, dtype: int64

# %%
plt.figure(figsize=(15,8))
plt.plot(dobit.iloc[0], label = 'Dobit')
plt.title('Kretanje dobiti HEP-a d.d u razdoblju 2017.-2020.')
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
porez = pd.DataFrame({
    '2017' : [290437563],
    '2018' : [318436857],
    '2019' : [315695495],
    '2020' : [350554589],
})

# %%
plt.figure(figsize=(15,8))
plt.plot(porez.iloc[0], label = 'Porez na dobit')
plt.title('Kretanje poreza na dobit HEP-a d.d u razdoblju 2017.-2020.')
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
prihodi = pd.DataFrame({
    '2017' : [14969285213],
    '2018' : [15198299588],
    '2019' : [15515243375],
    '2020' : [14372586536],
})

rashodi = pd.DataFrame({
    '2017' : [12674461952],
    '2018' : [13539842947],
    '2019' : [13820940958],
    '2020' : [12213812302],
})

# %%
plt.figure(figsize=(15,8))
plt.plot(prihodi.iloc[0], label = 'Poslovni prihodi')
plt.plot(rashodi.iloc[0], label = 'Poslovni rashodi')
plt.title('Kretanje poslovnih prihoda i rashoda HEP-a d.d u razdoblju 2017.-2020.')
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,12))
plt.pie(df[2017],autopct='%1.1f%%', startangle=90)
plt.legend(labels = df['Naziv_pozicije'],loc='center right', bbox_to_anchor=(-0.35, .5), fontsize=8)
plt.show()

# %%
pie = (df[2017][0], df[2017][20],df[2017][26],df[2017][31], df[2017][32], df[2017][33])
labels = ('Dugotrajna imovina', 'Kratkotrajna imovina', 'Kapital i rezerve', 'Rezerviranja', 'Dugoročne obveze', 'Kratkoročne obveze')

# %%
pie
# Out:
# (0.8375044687021022,
#  0.16075470398342806,
#  0.6691115670039797,
#  0.02621430560705304,
#  0.13319605948081034,
#  0.0868383139652937)

# %%
plt.figure(figsize=(12,12))
plt.pie(pie, labels = labels ,autopct='%1.1f%%', startangle=90)
plt.show()

# %% [markdown]
# POKAZATELJI

# %%
p1 = pd.DataFrame({
    '2017' : [
0.059,
1.257,
0.074,
1.261,
1.160
],
    
    '2018' : [0.041,
1.305,
0.095,
1.024,
1.110
],
    '2019' : [0.040,
1.413,
0.106,
1.037,
1.177
],
    '2020' : [0.048,
1.387,
0.106,
1.009,
1.157
],
})

# %%
p1
# Out:
#     2017   2018   2019   2020
# 0  0.059  0.041  0.040  0.048
# 1  1.257  1.305  1.413  1.387
# 2  0.074  0.095  0.106  0.106
# 3  1.261  1.024  1.037  1.009
# 4  1.160  1.110  1.177  1.157

# %%
p1.iloc[0]
# Out:
# 2017    0.059
# 2018    0.041
# 2019    0.040
# 2020    0.048
# Name: 0, dtype: float64

# %%
plt.figure(figsize=(15,8))
plt.title('BEX indeks kroz godine', size = 20)
plt.scatter(y = p1.iloc[0], x =['2017', '2018', '2019', '2020',], label = 'EX1')
plt.scatter(y = p1.iloc[1], x =['2017', '2018', '2019', '2020',], label = 'EX2')
plt.scatter(y = p1.iloc[2], x =['2017', '2018', '2019', '2020',], label = 'EX3')
plt.scatter(y = p1.iloc[3], x =['2017', '2018', '2019', '2020',], label = 'EX4')
plt.scatter(y = p1.iloc[4], x =['2017', '2018', '2019', '2020',], label = 'BEX', s = 250)
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
p2 = pd.read_excel(r'C:\Users\kundi\Desktop\pokaz.xlsx')

# %%
p2.drop(columns=['Godina'], inplace = True)

# %%
p2
# Out:
#        2017      2018      2019      2020
# 0  0.073916  0.095156  0.105908  0.105934
# 1  0.110408  0.066334  0.088810  0.100439
# 2  0.040944  0.041715  0.040376  0.040644
# 3  0.509430  0.490517  0.465063  0.443378
# 4  0.385294  0.376665  0.364567  0.321970
# 5  1.069338  1.015690  1.028270  0.989858

# %%
plt.figure(figsize=(15,8))
plt.title('Altmanov z-score indeks kroz godine', size= 20)
plt.scatter(y = p2.iloc[0], x =['2017', '2018', '2019', '2020',], label = 'X1')
plt.scatter(y = p2.iloc[1], x =['2017', '2018', '2019', '2020',], label = 'X2')
plt.scatter(y = p2.iloc[2], x =['2017', '2018', '2019', '2020',], label = 'X3')
plt.scatter(y = p2.iloc[3], x =['2017', '2018', '2019', '2020',], label = 'X4')
plt.scatter(y = p2.iloc[3], x =['2017', '2018', '2019', '2020',], label = 'X5')
plt.scatter(y = p2.iloc[4], x =['2017', '2018', '2019', '2020',], label = 'Z-score', s = 250)
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
p3 = pd.read_excel(r'C:\Users\kundi\Desktop\ems.xlsx')

# %%
p3
# Out:
#        2017      2018      2019      2020
# 0  0.073916  0.095156  0.105908  0.105934
# 1  0.110408  0.066334  0.088810  0.100439
# 2  0.040944  0.041715  0.040376  0.040644
# 3  2.022167  1.524972  1.511130  1.449159
# 4  6.493240  5.972017  6.092292  6.067105

# %%
plt.figure(figsize=(15,8))
plt.title('Altmanov EMS indeks kroz godine', size= 20)
plt.scatter(y = p3.iloc[0], x =['2017', '2018', '2019', '2020',], label = 'X1')
plt.scatter(y = p3.iloc[1], x =['2017', '2018', '2019', '2020',], label = 'X2')
plt.scatter(y = p3.iloc[2], x =['2017', '2018', '2019', '2020',], label = 'X3')
plt.scatter(y = p3.iloc[3], x =['2017', '2018', '2019', '2020',], label = 'X4')
plt.scatter(y = p3.iloc[4], x =['2017', '2018', '2019', '2020',], label = 'EMS', s = 250)
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
p4 = pd.read_excel(r'C:\Users\kundi\Desktop\svipokazatelji.xlsx')

# %%
p4
# Out:
#        2017      2018      2019      2020
# 0  0.086617  0.082803  0.092503  0.101852
# 1  0.090301  0.086483  0.097401  0.108829
# 2  0.033899  0.031784  0.034335  0.033153
# 3  0.038166  0.037045  0.038668  0.038471
# 4  0.066018  0.064266  0.073111  0.074057

# %%
plt.figure(figsize=(15,8))
plt.title('Financijski pokazatelji profitabilnosti kroz godine', size= 20)
plt.scatter(y = p4.iloc[0], x =['2017', '2018', '2019', '2020',], label = 'Neto marža profita')
plt.scatter(y = p4.iloc[1], x =['2017', '2018', '2019', '2020',], label = 'Bruto marža profita')
plt.scatter(y = p4.iloc[2], x =['2017', '2018', '2019', '2020',], label = 'Neto rentabilnost imovine')
plt.scatter(y = p4.iloc[3], x =['2017', '2018', '2019', '2020',], label = 'Bruto profitabilnost imovine')
plt.scatter(y = p4.iloc[4], x =['2017', '2018', '2019', '2020',], label = 'Rentabilnost vlastitog kapitala')
#plt.scatter(y = p4.iloc[5], x =['2017', '2018', '2019', '2020',], label = 'Stupanj pokrića II')
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation=90)
plt.legend()
plt.show()
