# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# Učitavanje datoteke u program
df = pd.read_csv(r'C:\Users\kundi\Moji_radovi\import_data\CROBEX.csv')

# %%
print (df)
# Out:
#        mic symbol          isin        date  open_value  high_value  \
# 0     XZAG    CBX  HRZB00ICBEX6  2021-04-16     1882.17     1883.34
# 1     XZAG    CBX  HRZB00ICBEX6  2021-04-15     1886.25     1889.23
# 2     XZAG    CBX  HRZB00ICBEX6  2021-04-14     1887.01     1890.21
# 3     XZAG    CBX  HRZB00ICBEX6  2021-04-13     1881.66     1888.29
# 4     XZAG    CBX  HRZB00ICBEX6  2021-04-12     1888.57     1888.59
# ...    ...    ...           ...         ...         ...         ...
# 2810  XZAG    CBX  HRZB00ICBEX6  2010-01-11     2080.33     2115.98
# 2811  XZAG    CBX  HRZB00ICBEX6  2010-01-08     2071.17     2074.79
# 2812  XZAG    CBX  HRZB00ICBEX6  2010-01-07     2058.04     2075.66
# 2813  XZAG    CBX  HRZB00ICBEX6  2010-01-05     2024.82     2071.80
# 2814  XZAG    CBX  HRZB00ICBEX6  2010-01-04     2001.34     2025.90
#
#       low_value  last_value  change_prev_close_percentage     turnover
# 0       1876.71     1878.67                         -0.19   3201986.74
# ...

# %%
# Ispisivanje obilježja iz .csv datoteke
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2815 entries, 0 to 2814
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   mic                           2815 non-null   object
#  1   symbol                        2815 non-null   object
#  2   isin                          2815 non-null   object
#  3   date                          2815 non-null   object
#  4   open_value                    2814 non-null   float64
#  5   high_value                    2814 non-null   float64
#  6   low_value                     2814 non-null   float64
#  7   last_value                    2814 non-null   float64
#  8   change_prev_close_percentage  2814 non-null   float64
#  9   turnover                      2815 non-null   float64
# dtypes: float64(6), object(4)
# memory usage: 220.0+ KB

# %%
# Uređivanje x osi, y osi i naslova iz .csv datoteke u godine.
naslov = 'CROBEX Indeks u razdoblju 2010. - 2021. godine'
os_x = 'Vremenski intervali u danima'
os_y = 'Vrijednost burzovnog indeksa'
plt.title(naslov, fontsize=17, weight= 'semibold', color= '0.3')
plt.xlabel(os_x, fontsize=15, weight = 'semibold', color = 'm')
plt.ylabel(os_y, fontsize=15, weight = 'semibold', color = 'm')

# Ispisivanje rezultata
df['last_value'].plot(figsize=(22,6));
