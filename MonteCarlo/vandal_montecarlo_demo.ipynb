# %%
import vandal #vandal 3.0.2 was used in this example. - DEVELOPER MODE
import pandas as pd #Importing pandas to create a DataFrame.

# %%
vandal.__version__ #Version used.
# Out:
# '3.0.2'

# %%
df = pd.DataFrame({
    'Example_data' : [38,37,38,36,36,35,36,34,33,34,35] #Example list of values.
})

# %%
MC = vandal.MonteCarlo() #Object defined as MC.

# %%
MC.execute(df['Example_data'], 50, 500) #Executes the Monte Carlo simulation.
# Out:
# Monte Carlo has been set up for 500 simulations in a period of 50 time measurement units.
# Monte Carlo simulation has been executed.
# NOTE: Use data with reasonable standard deviation in order to prevent exponential growth of the function that cannot be plotted properly, recognize such abnormal values by a + sign anywhere in the data executed below.
# The model that will be able to handle big standard deviations is currently being worked on, thank you for your patience.
#
# Monte Carlo simulation set up and ready to plot.
#           0          1          2          3          4          5    \
# 0   36.351039  37.775117  37.408205  38.839900  38.047208  37.386784
# 1   36.902090  38.460544  37.388017  37.009856  37.181778  36.719178
# 2   36.795300  38.428524  37.871855  37.479712  35.331100  38.267763
# 3   35.394806  36.788642  37.416653  37.023068  35.438172  38.184449
# 4   34.674925  33.295150  40.765248  34.827287  35.513303  36.382375
# 5   34.158041  32.166853  39.911342  35.041056  34.968514  36.073141
# 6   34.365052  30.004616  41.720742  35.929465  32.943380  34.543276
# 7   33.576302  31.375219  39.243317  34.722321  32.875802  33.144876
# 8   31.730008  30.965376  39.217870  35.224766  29.365183  32.467310
# 9   30.826849  29.622343  37.730295  34.900008  28.488749  32.152842
# 10  31.375649  29.676317  36.418657  35.267717  28.794659  31.387854
# 11  31.909109  29.285870  36.637093  35.940080  26.611360  30.585460
# 12  30.854421  29.951626  35.968269  36.022325  25.841196  31.339984
# 13  31.421490  28.382101  34.347138  36.019820  26.327774  31.390383
# 14  30.279682  29.654192  34.895961  36.921301  26.607172  31.010765
# 15  28.266188  30.689448  35.999858  34.978671  27.078772  29.823169
# 16  27.986494  30.767527  36.773221  35.420549  26.803839  27.903167
# 17  26.303392  30.163408  34.977136  32.708561  26.034625  27.473056
# 18  25.456354  31.439868  33.910022  32.445530  26.766829  27.973134
# 19  23.987067  30.787954  35.772655  32.091840  25.973157  27.966084
# 20  23.243479  31.353084  36.544491  30.919321  24.442818  25.849480
# 21  23.328664  30.266949  36.100299  30.758147  23.659302  26.030505
# 22  23.035128  31.397509  35.407499  28.546073  23.251603  25.697130
# 23  23.213798  29.909482  35.605843  29.670231  23.069895  24.638258
# 24  25.260471  29.003235  34.656143  29.081829  23.500411  24.553943
# 25  25.685959  28.598869  34.179499  28.113226  23.687514  24.046781
# 26  25.224180  28.971129  35.698387  27.730077  22.151878  22.976445
# 27  24.089442  28.747172  36.712219  28.937539  22.434583  22.688071
# 28  23.830390  28.939002  37.378267  30.389819  21.241839  21.262330
# 29  23.471913  29.601140  37.216550  29.629246  20.974586  21.272472
# 30  24.108779  30.924247  34.330038  26.869229  20.505705  22.154581
# 31  23.242560  30.488203  33.177468  27.357279  19.865607  23.108712
# 32  22.040024  29.708205  32.387329  27.569100  18.039903  22.896316
# 33  22.180330  28.725016  32.030227  27.295972  18.592174  22.910689
# 34  22.109987  26.177402  32.817584  27.573111  18.439859  23.720875
# 35  22.088989  26.394707  31.342046  28.027466  18.749955  23.479167
# 36  22.418728  24.086147  32.715061  27.335081  17.789888  22.185572
# 37  22.218445  23.296879  34.057865  27.460701  18.206017  21.631404
# 38  20.473638  23.988987  31.634876  26.639496  19.023343  22.228946
# 39  20.469895  22.543684  29.954557  26.025242  18.935622  20.506053
# 40  20.168456  22.583092  31.261039  26.348920  18.164931  20.037609
# 41  18.911576  23.263680  30.363834  26.461040  17.761375  20.742313
# 42  19.298823  22.617974  30.210200  25.440871  17.987858  21.702034
# 43  20.317651  22.470266  28.964336  26.477782  17.586335  21.281160
# 44  20.525973  23.167700  26.655945  26.342505  16.881601  20.911003
# 45  22.022400  23.947978  25.702001  26.774823  17.262187  19.905563
# 46  22.920688  24.564406  26.665826  26.331157  16.811604  20.484847
# 47  22.430100  25.854065  27.601148  25.633155  16.528398  19.843467
# 48  22.600826  26.113099  28.226857  24.327396  15.976710  19.159500
# 49  23.178023  26.367463  27.655568  23.726501  15.207841  19.161539
# 50  22.938372  24.000443  27.696498  24.569756  14.623696  19.226157
#
#           6          7          8          9    ...        490        491  \
# 0   37.485566  37.941830  37.429264  37.924565  ...  36.138248  36.882332
# 1   37.653034  39.280402  37.714828  36.412484  ...  35.159463  35.887453
# 2   39.855155  37.772583  38.486587  34.835543  ...  35.317486  37.900535
# 3   39.261456  36.943327  36.940230  36.958157  ...  34.564029  38.634035
# 4   41.309082  36.162733  36.854681  34.911208  ...  35.549149  37.319591
# 5   39.123640  35.841107  37.819398  35.918197  ...  36.262492  35.947374
# 6   39.569237  32.819104  36.601412  36.186751  ...  37.270175  39.492393
# 7   38.504618  32.895314  35.020473  38.728898  ...  36.830375  41.588486
# 8   38.038318  33.803216  34.492340  40.660252  ...  37.506564  42.173277
# 9   38.349630  34.539704  34.233581  38.380841  ...  35.295821  42.168398
# 10  36.261438  34.398138  33.162764  36.224967  ...  35.571410  38.758051
# 11  36.877390  34.252984  31.914005  36.665296  ...  35.554028  35.555768
# 12  36.269543  31.927079  32.603002  37.188357  ...  32.647651  33.636001
# 13  36.385391  29.361129  33.296027  37.685177  ...  31.835877  31.899217
# 14  34.608774  30.143404  31.692206  37.847310  ...  30.121611  32.747790
# 15  34.118426  28.045314  31.149006  37.984570  ...  29.769230  33.568267
# 16  32.460409  28.029372  30.454497  36.772459  ...  30.478450  33.422213
# 17  32.699946  30.016131  30.310502  36.450694  ...  29.528109  33.052152
# 18  33.306469  28.213652  30.170759  31.917766  ...  29.585053  31.685483
# 19  33.428974  27.839078  31.408991  33.982879  ...  29.524299  32.403382
# 20  33.537786  28.437643  31.285931  32.094435  ...  29.390585  33.701492
# 21  34.335403  26.488283  29.987505  32.080608  ...  28.143632  33.708454
# 22  34.376745  26.064125  30.549508  31.205787  ...  27.529818  32.398694
# 23  34.257408  26.523344  30.680671  30.886466  ...  27.866972  32.016067
# 24  34.588818  27.065597  28.665881  29.497698  ...  26.989280  31.538088
# 25  32.961276  27.472487  29.144218  30.429878  ...  27.474658  31.844162
# 26  32.030869  27.130972  29.134529  30.668643  ...  27.075837  32.067996
# 27  32.293818  26.841058  28.137767  30.819474  ...  26.208212  34.477690
# 28  30.954876  27.400599  27.411203  31.196156  ...  26.984197  35.806629
# 29  30.442541  28.127447  26.359871  30.449654  ...  27.943813  33.452169
# 30  30.628722  28.246466  27.497060  27.673886  ...  28.303897  32.886785
# 31  29.367865  27.660374  26.686221  28.588225  ...  28.798585  33.184964
# 32  28.244616  28.234390  28.542576  27.792747  ...  28.233022  32.815224
# 33  28.065266  27.867797  29.225798  27.284787  ...  29.423808  32.558261
# 34  28.603222  27.894452  26.705265  27.738835  ...  29.301095  32.018069
# 35  28.826156  27.865578  26.320356  27.693196  ...  30.589190  31.916299
# 36  29.767578  27.690417  27.114810  28.050508  ...  27.545841  32.763895
# 37  28.491943  28.334451  24.602913  25.917910  ...  27.151888  31.553527
# 38  30.133347  25.969255  25.934507  26.411102  ...  25.657228  32.095679
# 39  31.564339  27.208264  27.776138  24.909089  ...  26.206431  33.557909
# 40  30.934946  27.453349  27.553703  24.697260  ...  27.417507  31.818549
# 41  30.852613  26.578244  26.898853  25.601272  ...  27.490727  31.874600
# 42  29.304103  26.728287  25.394500  26.029208  ...  27.782067  33.621578
# 43  29.458856  28.464012  27.059665  26.142466  ...  26.258903  31.856421
# 44  29.485905  28.574395  27.636388  25.327334  ...  27.216380  31.949331
# 45  30.513374  29.912768  29.680740  26.045835  ...  26.947422  28.783644
# 46  31.494576  30.066462  28.407559  25.903871  ...  26.584656  28.111620
# 47  31.111750  30.586241  27.600355  26.170383  ...  26.645084  27.724312
# 48  31.318632  31.346633  27.329343  27.220369  ...  26.871000  28.546212
# 49  31.469706  31.010337  28.403293  26.726042  ...  26.459703  28.977561
# 50  29.153300  30.266028  26.806067  25.890404  ...  25.496744  29.220170
#
#           492        493        494        495        496        497  \
# 0   36.479514  40.525363  36.066703  38.365141  36.960949  38.379628
# 1   35.258655  43.152360  35.837237  40.120412  34.458020  35.745039
# 2   33.590858  41.956959  36.090907  39.810750  34.848905  35.729943
# 3   32.555424  40.400583  35.382828  39.425997  33.063896  35.797154
# 4   31.912262  39.081994  36.623264  36.850677  33.059178  34.534836
# 5   31.233997  36.152476  37.376801  38.178576  32.686105  35.197901
# 6   30.229257  36.411345  36.797383  38.541912  32.969557  35.738082
# 7   30.430775  37.844195  37.572795  39.568020  31.619337  36.289315
# 8   29.201181  38.395563  38.261592  37.097476  30.506180  34.078978
# 9   28.466950  38.413407  37.182526  35.032919  28.721722  32.644661
# 10  28.395647  37.442120  37.314126  34.369653  29.186122  32.472936
# 11  28.166309  36.820720  37.479595  34.150413  27.580259  32.511439
# 12  28.492827  38.984904  34.503862  32.856499  27.730988  33.253655
# 13  28.891187  38.038084  35.858806  33.314800  28.946098  31.448622
# 14  28.319833  38.880304  35.191122  32.923571  28.021437  31.685740
# 15  28.160110  38.223528  36.212844  34.322872  28.488776  32.949509
# 16  29.271857  38.704113  37.025011  32.371115  27.925252  33.434734
# 17  27.957612  40.794284  36.879792  32.069587  27.925042  33.424595
# 18  28.461889  41.825949  36.294998  29.780641  29.729770  32.862882
# 19  27.809490  41.103902  36.677896  28.042611  29.410362  32.764087
# 20  27.552771  41.154297  35.082872  25.997813  30.290941  32.786058
# 21  26.103184  39.658602  33.966288  26.714588  30.947030  31.508420
# 22  24.668947  39.172281  33.448744  26.758166  29.524057  31.425058
# 23  25.094000  37.687566  32.661599  26.865866  31.061085  33.057453
# 24  24.117934  35.442678  32.673722  26.291997  30.492088  34.266546
# 25  23.525886  34.280887  33.295995  24.289423  30.648968  34.874740
# 26  23.907293  33.536323  31.854964  23.057464  29.442878  33.991712
# 27  23.335929  32.881536  32.297587  23.155522  28.159771  33.111145
# 28  22.759240  33.005200  31.603773  23.826947  26.299265  32.720568
# 29  22.906156  32.298515  31.653659  24.523635  25.846250  32.287223
# 30  21.529191  32.991661  30.455813  25.065548  26.917151  31.729283
# 31  20.603017  32.291280  29.748653  25.185870  26.778359  30.280984
# 32  20.037930  32.691985  28.070307  24.795442  26.007583  29.648896
# 33  19.619350  32.891647  29.307871  24.510277  26.401815  27.860758
# 34  20.038549  32.339969  27.782229  23.746053  25.607622  28.269008
# 35  19.074327  32.153962  29.259462  22.954654  26.188528  27.716303
# 36  18.297687  33.410192  29.521610  23.693018  26.279222  27.234108
# 37  18.681954  32.005813  29.193391  23.014354  26.081711  27.270984
# 38  19.649395  32.248821  30.322376  20.854481  24.560810  27.519886
# 39  19.314915  31.924021  30.307438  20.028849  25.999579  27.312919
# 40  18.097620  32.506807  30.746818  20.185929  26.042245  27.661796
# 41  18.313999  34.805009  29.660316  18.638276  24.290807  26.836540
# 42  17.291916  34.055260  29.294022  17.627759  24.749072  26.530574
# 43  15.808100  32.714202  30.387433  17.187940  25.478032  25.262305
# 44  15.407892  31.703819  30.481441  16.368516  25.548129  23.753048
# 45  15.806540  31.649115  28.127591  16.467444  24.510136  24.416043
# 46  15.338256  30.005238  25.537288  16.713571  22.597317  24.214232
# 47  15.339337  30.215544  24.028829  15.984788  22.207461  23.982570
# 48  16.126874  29.300185  24.454193  15.612063  21.515260  23.913980
# 49  16.806370  29.679953  23.988815  16.303911  22.028977  22.951495
# 50  16.219996  29.102117  23.223978  16.530148  21.309426  22.084418
#
#           498        499
# 0   36.452708  37.231721
# 1   37.379467  38.063887
# 2   36.347431  37.294783
# 3   35.584171  38.830218
# 4   38.416187  37.257687
# 5   39.698863  36.891617
# 6   37.020086  36.597213
# 7   35.713995  37.459856
# 8   35.146812  35.169718
# 9   33.573803  36.370257
# 10  33.291601  36.579149
# 11  32.275279  36.914466
# 12  32.656000  36.220180
# 13  30.382052  35.420958
# 14  30.668896  36.203122
# 15  30.744747  35.440965
# 16  30.002478  33.361272
# 17  30.716845  31.051664
# 18  31.483431  30.963084
# 19  32.434272  30.192509
# 20  31.765681  29.663921
# 21  32.983500  30.002690
# 22  33.794888  30.384613
# 23  35.582235  30.005400
# 24  35.514271  29.333152
# 25  34.168622  30.622017
# 26  33.425337  29.470788
# 27  32.969147  29.717918
# 28  31.648511  28.932378
# 29  29.648722  30.251058
# 30  28.134442  29.570127
# 31  26.922227  29.368168
# 32  27.238068  27.777806
# 33  28.583822  27.596700
# 34  27.626178  26.411628
# 35  28.857699  26.321644
# 36  30.294835  26.103304
# 37  29.937708  26.434949
# 38  30.422522  25.929200
# 39  29.967941  25.036445
# 40  29.623206  24.666243
# 41  28.696625  22.065656
# 42  28.340698  21.578052
# 43  29.619970  21.649893
# 44  27.748714  20.515002
# 45  28.023968  20.246234
# 46  27.203640  20.572346
# 47  25.734380  21.404892
# 48  23.799927  22.511689
# 49  25.460527  22.714289
# 50  24.728456  23.222799
#
# [51 rows x 500 columns]

# %%
MC.graph() #Creates a graph of the executed Monte Carlo simulation.
# Out:
# MonteCarlo() plotting initialized.
# MonteCarlo() plotting finished.

# %%
MC.get_change() #Returns the list of percentage changes throughout the executed simulation.
# Out:
#          0         1         2         3         4         5         6    \
# 0        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1   0.015159  0.018145 -0.000540 -0.047118 -0.022746 -0.017857  0.004468
# 2  -0.002894 -0.000833  0.012941  0.012695 -0.049774  0.042174  0.058485
# 3  -0.038062 -0.042674 -0.012020 -0.012184  0.003031 -0.002177 -0.014896
# 4  -0.020339 -0.094961  0.089495 -0.059308  0.002120 -0.047194  0.052154
# 5  -0.014907 -0.033888 -0.020947  0.006138 -0.015340 -0.008500 -0.052905
# 6   0.006060 -0.067219  0.045335  0.025353 -0.057913 -0.042410  0.011389
# 7  -0.022952  0.045680 -0.059381 -0.033598 -0.002051 -0.040483 -0.026905
# 8  -0.054988 -0.013063 -0.000648  0.014470 -0.106784 -0.020443 -0.012110
# 9  -0.028464 -0.043372 -0.037931 -0.009220 -0.029846 -0.009686  0.008184
# 10  0.017803  0.001822 -0.034764  0.010536  0.010738 -0.023792 -0.054451
# 11  0.017002 -0.013157  0.005998  0.019065 -0.075823 -0.025564  0.016986
# 12 -0.033053  0.022733 -0.018255  0.002288 -0.028941  0.024669 -0.016483
# 13  0.018379 -0.052402 -0.045071 -0.000070  0.018830  0.001608  0.003194
# 14 -0.036338  0.044820  0.015979  0.025027  0.010612 -0.012093 -0.048828
# 15 -0.066497  0.034911  0.031634 -0.052615  0.017725 -0.038296 -0.014168
# 16 -0.009895  0.002544  0.021482  0.012633 -0.010153 -0.064380 -0.048596
# 17 -0.060140 -0.019635 -0.048842 -0.076565 -0.028698 -0.015414  0.007379
# 18 -0.032203  0.042318 -0.030509 -0.008042  0.028124  0.018202  0.018548
# 19 -0.057718 -0.020735  0.054929 -0.010901 -0.029651 -0.000252  0.003678
# 20 -0.031000  0.018356  0.021576 -0.036536 -0.058920 -0.075685  0.003255
# 21  0.003665 -0.034642 -0.012155 -0.005213 -0.032055  0.007003  0.023783
# 22 -0.012583  0.037353 -0.019191 -0.071918 -0.017232 -0.012807  0.001204
# 23  0.007756 -0.047393  0.005602  0.039380 -0.007815 -0.041206 -0.003471
# 24  0.088166 -0.030300 -0.026673 -0.019831  0.018661 -0.003422  0.009674
# 25  0.016844 -0.013942 -0.013754 -0.033306  0.007962 -0.020655 -0.047054
# 26 -0.017978  0.013017  0.044439 -0.013629 -0.064829 -0.044511 -0.028227
# 27 -0.044986 -0.007730  0.028400  0.043543  0.012762 -0.012551  0.008209
# 28 -0.010754  0.006673  0.018142  0.050187 -0.053165 -0.062841 -0.041461
# 29 -0.015043  0.022880 -0.004327 -0.025027 -0.012581  0.000477 -0.016551
# 30  0.027133  0.044698 -0.077560 -0.093152 -0.022355  0.041467  0.006116
# 31 -0.035930 -0.014100 -0.033573  0.018164 -0.031216  0.043067 -0.041166
# 32 -0.051739 -0.025584 -0.023816  0.007743 -0.091903 -0.009191 -0.038248
# 33  0.006366 -0.033095 -0.011026 -0.009907  0.030614  0.000628 -0.006350
# 34 -0.003171 -0.088690  0.024582  0.010153 -0.008192  0.035363  0.019168
# 35 -0.000950  0.008301 -0.044962  0.016478  0.016817 -0.010190  0.007794
# 36  0.014928 -0.087463  0.043807 -0.024704 -0.051204 -0.055095  0.032659
# 37 -0.008934 -0.032769  0.041045  0.004596  0.023391 -0.024979 -0.042853
# 38 -0.078530  0.029708 -0.071143 -0.029905  0.044893  0.027624  0.057609
# 39 -0.000183 -0.060249 -0.053116 -0.023058 -0.004611 -0.077507  0.047489
# 40 -0.014726  0.001748  0.043615  0.012437 -0.040701 -0.022844 -0.019940
# 41 -0.062319  0.030137 -0.028700  0.004255 -0.022216  0.035169 -0.002661
# 42  0.020477 -0.027756 -0.005060 -0.038554  0.012751  0.046269 -0.050191
# 43  0.052792 -0.006531 -0.041240  0.040758 -0.022322 -0.019393  0.005281
# 44  0.010253  0.031038 -0.079698 -0.005109 -0.040073 -0.017394  0.000918
# 45  0.072904  0.033680 -0.035787  0.016411  0.022544 -0.048082  0.034846
# 46  0.040790  0.025740  0.037500 -0.016570 -0.026102  0.029102  0.032156
# 47 -0.021404  0.052501  0.035076 -0.026509 -0.016846 -0.031310 -0.012155
# 48  0.007611  0.010019  0.022670 -0.050940 -0.033378 -0.034468  0.006650
# 49  0.025539  0.009741 -0.020239 -0.024700 -0.048124  0.000106  0.004824
# 50 -0.010340 -0.089770  0.001480  0.035541 -0.038411  0.003372 -0.073607
#
#          7         8         9    ...       490       491       492       493  \
# 0        NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 1   0.035280  0.007629 -0.039871  ... -0.027084 -0.026974 -0.033467  0.064824
# 2  -0.038386  0.020463 -0.043308  ...  0.004494  0.056094 -0.047302 -0.027702
# 3  -0.021954 -0.040179  0.060932  ... -0.021334  0.019353 -0.030825 -0.037095
# 4  -0.021129 -0.002316 -0.055386  ...  0.028501 -0.034023 -0.019756 -0.032638
# 5  -0.008894  0.026176  0.028844  ...  0.020066 -0.036769 -0.021254 -0.074958
# 6  -0.084317 -0.032205  0.007477  ...  0.027789  0.098617 -0.032168  0.007160
# 7   0.002322 -0.043193  0.070251  ... -0.011800  0.053076  0.006666  0.039352
# 8   0.027600 -0.015081  0.049869  ...  0.018360  0.014061 -0.040406  0.014569
# 9   0.021787 -0.007502 -0.056060  ... -0.058943 -0.000116 -0.025144  0.000465
# 10 -0.004099 -0.031280 -0.056171  ...  0.007808 -0.080874 -0.002505 -0.025285
# 11 -0.004220 -0.037655  0.012155  ... -0.000489 -0.082622 -0.008077 -0.016596
# 12 -0.067904  0.021589  0.014266  ... -0.081745 -0.053993  0.011593  0.058776
# 13 -0.080369  0.021256  0.013360  ... -0.024865 -0.051635  0.013981 -0.024287
# 14  0.026643 -0.048169  0.004302  ... -0.053847  0.026602 -0.019776  0.022141
# 15 -0.069604 -0.017140  0.003627  ... -0.011699  0.025054 -0.005640 -0.016892
# 16 -0.000568 -0.022296 -0.031911  ...  0.023824 -0.004351  0.039480  0.012573
# 17  0.070881 -0.004728 -0.008750  ... -0.031181 -0.011072 -0.044898  0.054004
# 18 -0.060050 -0.004610 -0.124358  ...  0.001928 -0.041349  0.018037  0.025289
# 19 -0.013276  0.041041  0.064701  ... -0.002054  0.022657 -0.022922 -0.017263
# 20  0.021501 -0.003918 -0.055570  ... -0.004529  0.040061 -0.009231  0.001226
# 21 -0.068549 -0.041502 -0.000431  ... -0.042427  0.000207 -0.052611 -0.036344
# 22 -0.016013  0.018741 -0.027269  ... -0.021810 -0.038856 -0.054945 -0.012263
# 23  0.017619  0.004293 -0.010233  ...  0.012247 -0.011810  0.017230 -0.037902
# 24  0.020444 -0.065670 -0.044964  ... -0.031496 -0.014929 -0.038896 -0.059566
# 25  0.015033  0.016687  0.031602  ...  0.017984  0.009705 -0.024548 -0.032779
# 26 -0.012431 -0.000332  0.007846  ... -0.014516  0.007029  0.016212 -0.021720
# 27 -0.010686 -0.034212  0.004918  ... -0.032044  0.075143 -0.023899 -0.019525
# 28  0.020846 -0.025822  0.012222  ...  0.029608  0.038545 -0.024712  0.003761
# 29  0.026527 -0.038354 -0.023929  ...  0.035562 -0.065755  0.006455 -0.021411
# 30  0.004231  0.043141 -0.091159  ...  0.012886 -0.016901 -0.060113  0.021461
# 31 -0.020749 -0.029488  0.033040  ...  0.017478  0.009067 -0.043019 -0.021229
# 32  0.020752  0.069562 -0.027825  ... -0.019639 -0.011142 -0.027427  0.012409
# 33 -0.012984  0.023937 -0.018277  ...  0.042177 -0.007831 -0.020889  0.006107
# 34  0.000956 -0.086243  0.016641  ... -0.004171 -0.016592  0.021367 -0.016773
# 35 -0.001035 -0.014413 -0.001645  ...  0.043961 -0.003179 -0.048118 -0.005752
# 36 -0.006286  0.030184  0.012903  ... -0.099491  0.026557 -0.040717  0.039069
# 37  0.023258 -0.092639 -0.076027  ... -0.014302 -0.036942  0.021001 -0.042034
# 38 -0.083474  0.054123  0.019029  ... -0.055048  0.017182  0.051785  0.007593
# 39  0.047711  0.071011 -0.056871  ...  0.021405  0.045558 -0.017022 -0.010072
# 40  0.009008 -0.008008 -0.008504  ...  0.046213 -0.051832 -0.063024  0.018255
# 41 -0.031876 -0.023766  0.036604  ...  0.002671  0.001762  0.011956  0.070699
# 42  0.005645 -0.055926  0.016715  ...  0.010598  0.054808 -0.055809 -0.021541
# 43  0.064940  0.065572  0.004351  ... -0.054825 -0.052501 -0.085810 -0.039379
# 44  0.003878  0.021313 -0.031180  ...  0.036463  0.002917 -0.025317 -0.030885
# 45  0.046838  0.073973  0.028369  ... -0.009882 -0.099085  0.025873 -0.001725
# 46  0.005138 -0.042896 -0.005451  ... -0.013462 -0.023347 -0.029626 -0.051941
# 47  0.017288 -0.028415  0.010289  ...  0.002273 -0.013778  0.000071  0.007009
# 48  0.024861 -0.009819  0.040121  ...  0.008479  0.029645  0.051341 -0.030294
# 49 -0.010728  0.039297 -0.018160  ... -0.015306  0.015111  0.042134  0.012961
# 50 -0.024002 -0.056234 -0.031267  ... -0.036393  0.008372 -0.034890 -0.019469
#
#          494       495       496       497       498       499
# 0        NaN       NaN       NaN       NaN       NaN       NaN
# 1  -0.006362  0.045752 -0.067718 -0.068646  0.025424  0.022351
# 2   0.007078 -0.007718  0.011344 -0.000422 -0.027610 -0.020206
# 3  -0.019619 -0.009665 -0.051221  0.001881 -0.020999  0.041170
# 4   0.035058 -0.065320 -0.000143 -0.035263  0.079586 -0.040498
# 5   0.020575  0.036035 -0.011285  0.019200  0.033389 -0.009825
# 6  -0.015502  0.009517  0.008672  0.015347 -0.067477 -0.007980
# 7   0.021072  0.026623 -0.040954  0.015424 -0.035281  0.023571
# 8   0.018332 -0.062438 -0.035205 -0.060909 -0.015881 -0.061136
# 9  -0.028202 -0.055652 -0.058495 -0.042088 -0.044755  0.034136
# 10  0.003539 -0.018933  0.016169 -0.005260 -0.008405  0.005743
# 11  0.004434 -0.006379 -0.055021  0.001186 -0.030528  0.009167
# 12 -0.079396 -0.037889  0.005465  0.022829  0.011796 -0.018808
# 13  0.039269  0.013949  0.043818 -0.054281 -0.069633 -0.022066
# 14 -0.018620 -0.011743 -0.031944  0.007540  0.009441  0.022082
# 15  0.029034  0.042501  0.016678  0.039884  0.002473 -0.021052
# 16  0.022428 -0.056865 -0.019781  0.014726 -0.024143 -0.058680
# 17 -0.003922 -0.009315 -0.000008 -0.000303  0.023810 -0.069230
# 18 -0.015857 -0.071374  0.064628 -0.016805  0.024957 -0.002853
# 19  0.010550 -0.058361 -0.010744 -0.003006  0.030201 -0.024887
# 20 -0.043487 -0.072918  0.029941  0.000671 -0.020614 -0.017507
# 21 -0.031827  0.027571  0.021660 -0.038969  0.038338  0.011420
# 22 -0.015237  0.001631 -0.045981 -0.002646  0.024600  0.012730
# 23 -0.023533  0.004025  0.052060  0.051946  0.052888 -0.012480
# 24  0.000371 -0.021361 -0.018319  0.036576 -0.001910 -0.022404
# 25  0.019045 -0.076167  0.005145  0.017749 -0.037890  0.043939
# 26 -0.043279 -0.050720 -0.039352 -0.025320 -0.021753 -0.037595
# 27  0.013895  0.004253 -0.043580 -0.025905 -0.013648  0.008386
# 28 -0.021482  0.028996 -0.066070 -0.011796 -0.040057 -0.026433
# 29  0.001578  0.029239 -0.017225 -0.013244 -0.063187  0.045578
# 30 -0.037842  0.022098  0.041434 -0.017281 -0.051074 -0.022509
# 31 -0.023219  0.004800 -0.005156 -0.045646 -0.043087 -0.006830
# 32 -0.056418 -0.015502 -0.028784 -0.020874  0.011732 -0.054153
# 33  0.044088 -0.011501  0.015158 -0.060310  0.049407 -0.006520
# 34 -0.052056 -0.031180 -0.030081  0.014653 -0.033503 -0.042943
# 35  0.053172 -0.033328  0.022685 -0.019552  0.044578 -0.003407
# 36  0.008959  0.032166  0.003463 -0.017398  0.049801 -0.008295
# 37 -0.011118 -0.028644 -0.007516  0.001354 -0.011788  0.012705
# 38  0.038673 -0.093849 -0.058313  0.009127  0.016194 -0.019132
# 39 -0.000493 -0.039590  0.058580 -0.007521 -0.014942 -0.034431
# 40  0.014497  0.007843  0.001641  0.012773 -0.011503 -0.014787
# 41 -0.035337 -0.076670 -0.067254 -0.029834 -0.031279 -0.105431
# 42 -0.012350 -0.054217  0.018866 -0.011401 -0.012403 -0.022098
# 43  0.037325 -0.024950  0.029454 -0.047804  0.045139  0.003329
# 44  0.003094 -0.047674  0.002751 -0.059743 -0.063175 -0.052420
# 45 -0.077222  0.006044 -0.040629  0.027912  0.009920 -0.013101
# 46 -0.092091  0.014946 -0.078042 -0.008266 -0.029272  0.016107
# 47 -0.059069 -0.043604 -0.017252 -0.009567 -0.054010  0.040469
# 48  0.017702 -0.023318 -0.031170 -0.002860 -0.075170  0.051708
# 49 -0.019031  0.044315  0.023877 -0.040248  0.069773  0.009000
# 50 -0.031883  0.013876 -0.032664 -0.037779 -0.028753  0.022387
#
# [51 rows x 500 columns]

# %%
MC.get_risk(15000) #Shows the risk evaluation on top of the number of simulations defined in the parentheses.
# Out:
# Risk for this option is 45.27 %.

# %%
MC.get_stats() #Shows the statistics of the executed Monte Carlo simulation.
# Out:
# Number of simulations:  50
# Number of iterations:  500
# Mean value:  25.83
# Standard deviation:  6.51
# Maximum:  52.04
# Minimum:  12.38

# %%
MC.hist(graph_title='GitHub Repository Demo', x_title = 'Time period', y_title = 'Value') #Histogram of values.
# Out:
# Histogram plotting initiated...
# CHOSEN METHOD: Basic histogram model.
# Histogram plotting finished.

# %%
MC.hist(x_title = 'Time period', y_title = 'Value', method = 'e') #Histogram with Empirical rule applied, BEWARE: this option is currently being worked on so do not use it in any research!!!
# Out:
# Histogram plotting initiated...
# CHOSEN METHOD: Empirical rule.
# Histogram plotting finished.

# %%
print(MC) #Explains the object.
# Out:
# Monte Carlo defining object that stores the configuration data for creating 500 simulations in a period of 50 time measurement units.

# %%
print(repr(MC)) #Explains the representation of the object.
# Out:
# Monte Carlo defining object that stores the configuration data for creating 500 simulations in a period of 50 time measurement units.

# %%
#MC.get_menu() #Shows the menu created by duality package decorators. - DEVELOPER MODE ONLY
# Out:
# {'init': '__init__',
#  'execution': 'execute',
#  'graph': 'graph',
#  'change': 'get_change',
#  'risk': 'get_risk',
#  'statistics': 'get_stats',
#  'histogram': 'hist',
#  'string': '__str__',
#  'repr': '__repr__',
#  'logs': 'get_menu'}

# %%
#MC.get_logs() #Shows the saved logs from a JSON file created by duality package decorators. - DEVELOPER MODE ONLY
# Out:
# {
#     "entry": [
#         {
#             "FUNCTION NAME: ": "init",
#             "EXECUTION TIME: ": "0:00:00",
#             "EXECUTED AT: ": "2021-12-28 12:24:47.300304",
#             "MEMORY SIZE: ": "136 bytes"
#         }
#     ]
# }{
#     "entry": [
#         {
#             "FUNCTION NAME: ": "execution",
#             "EXECUTION TIME: ": "0:00:32.259256",
#             "EXECUTED AT: ": "2021-12-28 12:25:19.835561",
#             "MEMORY SIZE: ": "136 bytes"
#         }
#     ]
# }{
#     "entry": [
#         {
#             "FUNCTION NAME: ": "graph",
#             "EXECUTION TIME: ": "0:00:04.680120",
#             "EXECUTED AT: ": "2021-12-28 12:25:24.677422",
#             "MEMORY SIZE: ": "136 bytes"
#         }
#     ]
# }{
#     "entry": [
#         {
#             "FUNCTION NAME: ": "change",
#             "EXECUTION TIME: ": "0:00:00.019006",
#             "EXECUTED AT: ": "2021-12-28 12:25:25.123833",
#             "MEMORY SIZE: ": "136 bytes"
#         }
#     ]
# }{
#     "entry": [
#         {
#             "FUNCTION NAME: ": "risk",
#             "EXECUTION TIME: ": "0:00:16.992837",
#             "EXECUTED AT: ": "2021-12-28 12:25:42.333665",
#             "MEMORY SIZE: ": "136 bytes"
#         }
#     ]
# }{
#     "entry": [
#         {
#             "FUNCTION NAME: ": "statistics",
#             "EXECUTION TIME: ": "0:00:00.001998",
#             "EXECUTED AT: ": "2021-12-28 12:25:42.363666",
#             "MEMORY SIZE: ": "136 bytes"
#         }
#     ]
# }{
#     "entry": [
#         {
#             "FUNCTION NAME: ": "statistics",
#             "EXECUTION TIME: ": "0:00:00.001000",
#             "EXECUTED AT: ": "2021-12-28 12:25:42.640939",
#             "MEMORY SIZE: ": "136 bytes"
#         }
#     ]
# }{
#     "entry": [
#         {
#             "FUNCTION NAME: ": "histogram",
#             "EXECUTION TIME: ": "0:00:56.186164",
#             "EXECUTED AT: ": "2021-12-28 12:26:38.826103",
#             "MEMORY SIZE: ": "136 bytes"
#         }
#     ]
# }{
#     "entry": [
#         {
#             "FUNCTION NAME: ": "statistics",
#             "EXECUTION TIME: ": "0:00:00.002013",
#             "EXECUTED AT: ": "2021-12-28 12:26:38.857698",
#             "MEMORY SIZE: ": "136 bytes"
#         }
#     ]
# }{
#     "entry": [
#         {
#             "FUNCTION NAME: ": "histogram",
#             "EXECUTION TIME: ": "0:00:55.103027",
#             "EXECUTED AT: ": "2021-12-28 12:27:33.958712",
#             "MEMORY SIZE: ": "136 bytes"
#         }
#     ]
# }{
#     "entry": [
#         {
#             "FUNCTION NAME: ": "string",
#             "EXECUTION TIME: ": "0:00:00",
#             "EXECUTED AT: ": "2021-12-28 12:27:34.036895",
#             "MEMORY SIZE: ": "136 bytes"
#         }
#     ]
# }{
#     "entry": [
#         {
#             "FUNCTION NAME: ": "representation",
#             "EXECUTION TIME: ": "0:00:00",
#             "EXECUTED AT: ": "2021-12-28 12:27:34.177891",
#             "MEMORY SIZE: ": "136 bytes"
#         }
#     ]
# }{
#     "entry": [
#         {
#             "FUNCTION NAME: ": "logs",
#             "EXECUTION TIME: ": "0:00:00",
#             "EXECUTED AT: ": "2021-12-28 12:27:34.320152",
#             "MEMORY SIZE: ": "136 bytes"
#         }
#     ]
# }{
#     "entry": [
#         {
#             "FUNCTION NAME: ": "logs",
#             "EXECUTION TIME: ": "0:00:00",
#             "EXECUTED AT: ": "2021-12-28 12:27:34.562997",
#             "MEMORY SIZE: ": "136 bytes"
#         }
#     ]
# }

# %%
vandal.__license__ #Shows the license.
# Out:
# 'Copyright © 2021- David Kundih. All rights reserved. Licensed under the Apache License, Version 2.0 | For more details about the license and terms of use visit the official vandal documentation linked at https://github.com/dkundih/vandal and https://pypi.org/project/vandal'

# %%
vandal.__contact__ #Shows the contact information.
# Out:
# 'dakundih@unin.hr | kundihdavid@gmail.com'

# %%
vandal.__documentation__ #Shows the documentation details.
# Out:
# 'https://github.com/dkundih/vandal | https://pypi.org/project/vandal'

# %%
vandal.__donate__ #Shows the donation options.
# Out:
# 'https://patreon.com/dkundih | https://buymeacoffee.com/dkundih'

# %%
vandal.__credits__ #Shows credits.
# Out:
# ['dkundih <https://github.com/dkundih>']

# %%
vandal.__author__ #Shows the author.
# Out:
# 'David Kundih'

# %%
vandal.__copyright__ #Shows the copyright information.
# Out:
# 'Copyright © 2021- David Kundih'

# %%
help(vandal) #Help on library options and possibilities.
# Out:
# Help on package vandal:
#
# NAME
#     vandal
#
# DESCRIPTION
#     vandal - Data science, Data manipulation and Machine learning library.
#     =====================================================================
#
#     This is a connection to the __init__ file of the vandal library.
#
#     AVAILABLE FEATURES IN THE LIBRARY:
#
#             TOOLKIT (MODULE FUNCTIONS)
#             --------------------------
#
#             set of available data manipulation functions from the vandal library.
#                     print(help(any_function_listed_below)) in order to see the function details or print(help(vandal.toolkit)) for all functions at once.
#
#                     FUNCTIONS (ACCESSIBLE DIRECTLY FROM THE LIBRARY)
#                     ------------------------------------------------
#
#                     random_value(mean, st_dev, **rounded) - gives a random value of mean and standard deviation inputed, if rounded = 'y', value will be rounded.
#
#                     random_pool(mean, st_dev, pool_size, **rounded) - gives random values of mean and standard deviation inputed for the amount of values defined in the pool size, if rounded = 'y', values will be rounded.
#
#                     split_values(data, split_method) - splits the data using a split method character.
#
#                     join_values(data, join_method) - joins the data using a join metod character.
#
#                     replace_values(data, replaced_value, replacing_value) - replaces a defined value with a desired value.
#
#                     list_sort(data, array) - manually sorts data depending on defined array of indexes.
#
#                     index_sort(data, split_method, index_array) - sorts the indicies in a list of values based on the index array defined as [x,x,x].
#
#                     auto_sort(data, split_method, trigger = lambda x: x[0]) - automatically splits all values in a list and sorts them based on the added trigger as lambda x: [x[i], x[i]] and joins them back together.
#
#             MONTECARLO (OBJECT)
#             -------------------
#
#             vandal.MonteCarlo is a module for performing the Monte Carlo simulation over the defined data with a lot of useful features.
#                     print(help(vandal.MonteCarlo)) in order to see available features.
#
#             EOQ (OBJECT)
#             ------------
#
#             vandal.EOQ is a module for finding an Economic order quantity over the defined data with a lot of useful features.
#                     print(help(vandal.EOQ)) in order to see available features.
#
#             Dijkstra (OBJECT)
#             -----------------
#
#             vandal.Dijkstra is a module for finding the optimal route between the defined nodes from the place of origin to the final destination.
#                     print(help(vandal.Dijkstra)) in order to see available features.
#
#             CLI (EXECUTABLE FUNCTION)
#             -------------------------
#
#             vandal.CLI is an executable function that runs the Command Line Inerface of the vandal package.
#                     print(help(vandal.CLI)) in order to see available features.
#
# PACKAGE CONTENTS
#     hub (package)
#     misc (package)
#     objects (package)
#
# SUBMODULES
#     toolkit
#
# DATA
#     __all__ = [<function random_value>, <function random_pool>, <function ...
#     __contact__ = 'dakundih@unin.hr | kundihdavid@gmail.com'
#     __copyright__ = 'Copyright © 2021- David Kundih'
#     __documentation__ = 'https://github.com/dkundih/vandal | https://pypi....
#     __donate__ = 'https://patreon.com/dkundih | https://buymeacoffee.com/d...
#     __license__ = 'Copyright © 2021- David Kundih. All rights reser...kund...
#
# VERSION
#     3.0.2
#
# AUTHOR
#     David Kundih
#
# CREDITS
#     ['dkundih <https://github.com/dkundih>']
#
# FILE
#     c:\users\kundi\appdata\local\programs\python\python39\lib\site-packages\vandal\__init__.py

# %%
help(vandal.MonteCarlo) #Help on object options and possibilities.
# Out:
# Help on class MonteCarlo in module vandal.objects.montecarlo:
#
# class MonteCarlo(builtins.object)
#  |  MonteCarlo(*args, **kwargs)
#  |
#  |  (OBJECT INFO)
#  |  -------------
#  |
#  |  vandal.MonteCarlo - main class.
#  |
#  |  (OBJECT FUNCTIONS)
#  |  ------------------
#  |
#  |  eg. vandal.MonteCarlo.function()
#  |
#  |      .execute() - executes a Monte Carlo simulation on a defined data set.
#  |          * takes 4 additional arguments.
#  |          list_of_values - pandas dataframe of values.
#  |          time_seq - desired time sequence.
#  |          num_sims - desired number of simulation iterations.
#  |          ref_value_index (default: ref_value_index = 0) - index on which the starting point of the simulation is created.
#  |      * Requirements:
#  |          pandas Python module.
#  |          pd.DataFrame() defined data set.
#  |
#  |      .graph() - plots the Monte Carlo simulation on a graph.
#  |          * takes 5 optional customization arguments. (default: graph_title = 'Monte Carlo simulation', x_title = 'X axis', y_title = 'Y axis', plot_size = (25,10), perform_block = True).
#  |              graph_title - title of the graph.
#  |              x_title - title of the X axis.
#  |              y_title - title on the Y axis.
#  |              plot_size - desired size of the graph. eg. - (x_lenght_num, y_lenght_num). - NOTE: values must be inside the parentheses and divided by a comma.
#  |              perform_block (default: perform_block = True) - False/True may be used depending on the IDE requirements.
#  |
#  |      .get_risk() - calculates the risk of value decrease over time.
#  |          * takes 1 optional argument (default: risk_sims = 5000).
#  |
#  |      .get_stats() - shows the statistics of the Monte Carlo simulation.
#  |          * takes no additional arguments.
#  |
#  |      .get_change() - shows the percentage of Monte Carlo simulation value change for every iteration.
#  |          * takes no additional arguments.
#  |
#  |      .hist() - plots the histogram of Monte Carlo simulation.
#  |          * takes 6 optional customization arguments. (default: graph_title = 'Monte Carlo simulation', x_title = 'X axis', y_title = 'Y axis', plot_size = (25,10), perform_block = True, method = 'b').
#  |          If method = 'e' is chosen, no customization arguments apply.
#  |              graph_title - title of the graph.
#  |              x_title - title of the X axis.
#  |              y_title - title on the Y axis.
#  |              plot_size - desired size of the graph. eg. - (x_lenght_num, y_lenght_num). - NOTE: values must be inside the parentheses and divided by a comma.
#  |              perform_block (default: perform_block = True) - False/True may be used depending on the IDE requirements.
#  |              method - default method is Basic histogram and it's performed by automation. In order to plot Empirical rule histogram add method = 'e' as the last argument. - NOTE: method of a histogram must be placed within quotation marks.
#  |          * automatically executes the .get_stats(filtered = True) function in order to get standard deviation for the Empirical rule plotting.
#  |
#  |  (DEVELOPER MODE)
#  |  ----------------
#  |
#  |  Developer mode functions can only be set up manually by removing the '#DEVELOPER MODE -' in the source code.
#  |
#  |      * takes no additional arguments.
#  |      * Requirements:
#  |          '# DEVELOPER MODE -' removed in the code.
#  |
#  |  Methods defined here:
#  |
#  |  __init__ = logsaver(*args, **kwargs)
#  |
#  |  __repr__ = logsaver(*args, **kwargs)
#  |
#  |  __str__ = logsaver(*args, **kwargs)
#  |
#  |  execute = logsaver(*args, **kwargs)
#  |
#  |  get_change = logsaver(*args, **kwargs)
#  |
#  |  get_logs = decorator(*args, **kwargs)
#  |
#  |  get_menu = decorator(*args, **kwargs)
#  |
#  |  get_risk = logsaver(*args, **kwargs)
#  |
#  |  get_stats = logsaver(*args, **kwargs)
#  |
#  |  graph = logsaver(*args, **kwargs)
#  |
#  |  hist = logsaver(*args, **kwargs)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __contact__ = 'dakundih@unin.hr | kundihdavid@gmail.com'
#  |
#  |  __copyright__ = 'Copyright © 2021- David Kundih'
#  |
#  |  __documentation__ = 'https://github.com/dkundih/vandal | https://pypi....
#  |
#  |  __donate__ = 'https://patreon.com/dkundih | https://buymeacoffee.com/d...
#  |
#  |  __license__ = 'Copyright © 2021- David Kundih. All rights reser...kund...
#  |
#  |  record = <class 'duality.decorators.particles.record'>
#  |      # stores menu options over functions and class methods for listing.
#  |
#  |
#  |  track = <class 'duality.decorators.particles.track'>
#  |      # tracks function behaviuor and stores it into a JSON file.

# %%
help(vandal.MonteCarlo.graph) #Help on function options and possibilities.
# Out:
# Help on function logsaver in module duality.decorators.particles:
#
# logsaver(*args, **kwargs)

# %%
vandal.__file__ #Shows the library path.
# Out:
# 'C:\\Users\\kundi\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\vandal\\__init__.py'

# %%
vandal.__all__ #Shows the imported objects and modules from the library in the main module.
# Out:
# [<function vandal.hub.toolkit.random_value(mean, st_dev, **rounded)>,
#  <function vandal.hub.toolkit.random_pool(mean, st_dev, pool_size, **rounded)>,
#  <function vandal.hub.toolkit.split_values(data, split_method)>,
#  <function vandal.hub.toolkit.join_values(data, join_method)>,
#  <function vandal.hub.toolkit.replace_values(data, replaced_value, replacing_value)>,
#  <function vandal.hub.toolkit.list_sort(data, array)>,
#  <function vandal.hub.toolkit.index_sort(data, split_method, index_array)>,
#  <function vandal.hub.toolkit.auto_sort(data, split_method, trigger=<function <lambda> at 0x000001B6B1604B80>)>,
#  <module 'vandal.hub.toolkit' from 'C:\\Users\\kundi\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\vandal\\hub\\toolkit.py'>,
#  vandal.objects.montecarlo.MonteCarlo,
#  vandal.objects.eoq.EOQ,
#  vandal.objects.dijkstra.Dijkstra]

# %%
vandal.objects.__all__ #Shows the available objects from the objects module.
# Out:
# [vandal.objects.montecarlo.MonteCarlo,
#  vandal.objects.eoq.EOQ,
#  vandal.objects.dijkstra.Dijkstra]

# %%
vandal.misc.__all__ #Shows the meta data from the misc module.
# Out:
# ['David Kundih',
#  'Copyright © 2021- David Kundih',
#  ['dkundih <https://github.com/dkundih>'],
#  'Copyright © 2021- David Kundih. All rights reserved. Licensed under the Apache License, Version 2.0 | For more details about the license and terms of use visit the official vandal documentation linked at https://github.com/dkundih/vandal and https://pypi.org/project/vandal',
#  '3.0.2',
#  'https://github.com/dkundih/vandal | https://pypi.org/project/vandal',
#  'dakundih@unin.hr | kundihdavid@gmail.com',
#  'https://patreon.com/dkundih | https://buymeacoffee.com/dkundih']
