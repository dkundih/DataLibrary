# %% [markdown]
# vandal.MonteCarlo demonstration

# %%
import vandal # vandal 3.6.5 was used in this example.
import pandas as pd # importing pandas to create a DataFrame.

# %%
vandal.__version__ # version used.
# Out:
# '3.6.5'

# %%
df = pd.DataFrame({
    'Example_data' : [38,37,38,36,36,35,36,34,33,34,35] # example list of values.
})

# %%
MC = vandal.MonteCarlo(df['Example_data'], 50, 500) # object defined as MC.

# %%
MC.execute(filtered=False) # executes the Monte Carlo simulation.
# Out:
# Monte Carlo has been set up for 500 simulations in a period of 50 time measurement units and executed.
# NOTE: Use data with reasonable standard deviation in order to prevent exponential growth of the function that cannot be plotted properly, recognize such abnormal values by a + sign anywhere in the data executed below.
# Monte Carlo simulation set up and ready to plot.
#           0          1          2          3          4          5    \
# 0   37.505170  38.369625  38.913179  39.810954  37.635293  39.262955
# 1   36.352257  39.339106  38.726371  37.863946  38.601241  39.082482
# 2   36.107871  38.712576  37.130487  36.564744  41.791851  36.199956
# 3   35.510567  38.143839  35.287566  37.323882  36.655319  36.326729
# 4   36.732700  37.335061  36.296058  37.054608  37.738000  34.413148
# 5   37.615834  36.048012  35.790974  37.516609  37.266853  34.645975
# 6   37.604525  36.067313  35.720671  38.171618  36.196476  34.564665
# 7   34.865648  35.851320  32.754999  39.564460  35.164291  34.081675
# 8   36.338176  33.935981  32.141350  39.587216  34.983612  35.625257
# 9   36.825780  32.802206  31.049195  39.137314  34.274223  34.831742
# 10  35.389302  35.766094  29.971582  40.008074  35.365107  33.898239
# 11  35.446298  37.097091  28.903156  42.467892  37.696634  31.736723
# 12  35.288374  36.483325  28.361387  41.673086  39.122449  30.933907
# 13  36.262521  36.391919  27.201218  40.931582  38.228178  29.953198
# 14  35.492384  34.264533  27.205662  42.307391  38.288291  29.304889
# 15  35.896338  36.267889  26.436381  41.134773  36.586835  28.970526
# 16  36.410872  36.469971  27.287815  41.153392  36.189456  29.150199
# 17  37.020456  35.785263  25.820799  37.181896  36.193038  30.430537
# 18  34.649008  33.614661  26.058193  34.669843  34.560532  29.976842
# 19  36.362953  33.755451  24.144952  32.928658  35.070272  30.219361
# 20  34.613997  34.165694  24.369671  34.180710  35.517504  31.031492
# 21  34.589611  32.365822  22.995896  33.443656  34.894323  28.801032
# 22  33.194997  32.127389  22.943782  31.736597  33.109155  29.059133
# 23  33.653145  31.280702  22.310613  33.077161  33.441393  28.508896
# 24  33.642637  29.111809  22.336158  32.188835  35.642063  28.261989
# 25  34.003676  30.786926  22.360223  31.086246  35.448017  27.761195
# 26  34.868095  30.708805  22.978929  29.837760  34.309065  28.222177
# 27  33.419243  30.020945  23.633213  29.739857  34.375166  29.229590
# 28  32.931338  27.081669  24.287818  30.129017  34.146709  27.788899
# 29  34.183672  26.884589  23.839590  30.984856  34.011103  29.977015
# 30  34.690052  27.041301  24.905778  29.580301  34.649446  30.598439
# 31  33.521499  28.487190  25.619246  28.761984  32.657238  30.110027
# 32  33.105684  28.184154  24.500226  27.798134  32.433280  30.685782
# 33  32.176537  27.637386  24.325678  27.020480  31.317420  29.437727
# 34  31.301081  26.825750  23.986716  26.859705  30.981880  29.816805
# 35  30.820351  26.988071  24.026377  25.408309  29.921165  27.115572
# 36  29.720079  27.042502  22.988325  24.934450  29.905769  27.578078
# 37  29.975577  27.851023  22.752934  25.610815  30.170289  25.905132
# 38  29.812721  28.294578  21.446047  25.996675  27.336146  25.979039
# 39  28.741564  26.551627  21.403217  26.146471  27.543686  26.524459
# 40  28.087073  25.510274  20.484253  25.040691  25.405420  27.188930
# 41  27.818278  24.850335  20.938989  25.436095  25.146142  27.379488
# 42  27.123479  25.930000  21.592398  24.661715  24.921005  27.563571
# 43  27.594773  24.950861  22.882052  25.533790  25.299938  27.157893
# 44  27.849392  25.977591  24.346213  27.409096  24.307044  26.772040
# 45  28.009542  27.245925  24.268523  26.735685  23.095365  26.327582
# 46  27.719401  27.323399  22.519450  26.221972  23.024062  26.598436
# 47  26.315269  24.597333  21.710170  24.266666  23.219000  25.974183
# 48  24.418440  24.452318  20.234962  23.923672  22.569363  26.213423
# 49  23.878388  23.503987  19.132256  24.781905  22.743219  24.976187
# 50  24.509263  23.219324  18.092791  24.611288  22.549873  26.786608
#
#           6          7          8          9    ...        490        491  \
# 0   37.744961  38.372762  38.832611  37.365844  ...  38.580260  38.561740
# 1   38.486030  39.967969  37.850113  38.610462  ...  36.184966  38.585735
# 2   37.385889  40.080489  39.010390  38.016909  ...  37.009497  36.373051
# 3   37.088227  40.759430  38.348694  38.090974  ...  36.338189  34.963632
# 4   34.538054  42.551170  36.745709  38.014572  ...  37.880825  36.274167
# 5   33.701468  41.774464  35.733588  37.751188  ...  38.134919  36.651147
# 6   31.868188  42.720306  34.495784  38.018006  ...  38.551880  35.674886
# 7   30.791512  43.108109  35.034798  36.484146  ...  39.747495  34.398450
# 8   30.637113  42.449721  33.314293  35.282710  ...  41.215617  34.415990
# 9   30.655135  41.513176  34.711740  37.195433  ...  41.399300  33.337428
# 10  29.644252  39.402036  34.843468  32.974995  ...  43.778353  30.426092
# 11  28.824380  39.438807  33.799096  32.617918  ...  44.698962  28.510549
# 12  28.586110  39.795451  34.270764  31.215319  ...  42.876057  28.072507
# 13  27.544463  40.158370  34.096498  30.034628  ...  43.646570  26.196262
# 14  27.605483  39.765172  32.119522  30.216602  ...  44.334902  24.632331
# 15  28.726141  38.517763  32.052702  30.364485  ...  45.364601  23.089579
# 16  26.268248  39.094298  32.039231  29.034147  ...  45.944000  22.968395
# 17  26.716124  40.055463  31.753452  27.702933  ...  47.343539  22.107141
# 18  26.101501  40.455130  29.824659  27.462273  ...  45.521376  21.655180
# 19  25.548631  41.185632  29.028216  27.368493  ...  45.690190  21.071602
# 20  24.768667  39.148318  28.002005  27.361024  ...  43.672919  21.750764
# 21  25.641459  40.987559  25.340148  25.485495  ...  43.948545  21.737041
# 22  24.956774  38.889768  25.605898  25.059260  ...  43.811384  20.747498
# 23  26.564188  38.914281  25.530385  23.761310  ...  45.420009  21.853392
# 24  27.140152  39.762353  26.516264  24.048531  ...  44.578249  20.981747
# 25  28.091190  40.385572  25.390661  23.227273  ...  43.455666  20.064895
# 26  27.773612  41.184035  24.752279  22.940547  ...  40.594983  20.049693
# 27  28.084113  41.231046  24.884589  23.091599  ...  40.565553  19.770678
# 28  29.924085  40.395094  24.794771  22.888840  ...  39.654695  19.017566
# 29  29.288753  40.400220  24.085502  22.070536  ...  38.190949  19.510768
# 30  28.962678  39.444109  25.006690  20.941415  ...  38.316642  18.639181
# 31  29.783450  40.405408  26.184533  21.010624  ...  38.946409  18.719672
# 32  31.932289  39.283516  28.881869  19.705689  ...  38.553293  18.580353
# 33  33.263329  39.093151  27.112413  20.391034  ...  38.155954  19.066248
# 34  33.523746  38.033598  24.929426  19.428320  ...  36.732061  19.028043
# 35  34.226218  37.851980  24.695288  18.738569  ...  37.515473  19.588657
# 36  35.192752  37.924728  24.038260  18.668028  ...  35.587013  19.016545
# 37  34.361270  36.050527  24.869420  18.324775  ...  35.244182  18.641553
# 38  33.288593  36.120175  24.970203  19.292328  ...  36.018572  18.801047
# 39  35.287154  36.571881  25.445250  19.607377  ...  35.444349  18.685234
# 40  36.034404  37.022355  24.300033  19.173772  ...  36.381079  18.632619
# 41  35.053779  36.108988  23.264940  17.870672  ...  35.810352  17.457929
# 42  33.159294  34.982968  23.274698  18.204986  ...  33.712302  17.551629
# 43  34.096862  35.159661  23.925518  18.491326  ...  32.705424  17.207757
# 44  33.368246  32.900314  23.357309  17.604475  ...  33.909389  17.406999
# 45  33.484861  33.381739  23.980964  17.810000  ...  32.969997  16.872585
# 46  32.459368  31.744021  24.783641  17.961052  ...  31.663841  16.049440
# 47  31.674367  32.010185  26.118543  18.116987  ...  31.270334  16.572543
# 48  32.413658  31.695503  26.132216  17.162469  ...  31.274786  15.701557
# 49  34.428021  31.678462  26.449509  17.956496  ...  32.075378  16.228567
# 50  35.389201  29.976049  25.861669  17.912117  ...  32.087408  16.997075
#
#           492        493        494        495        496        497  \
# 0   36.342698  36.228451  38.210871  37.887128  38.544586  36.602072
# 1   37.244973  33.679063  38.866847  37.242175  39.232162  38.115505
# 2   36.985321  34.505642  39.970594  35.078587  40.864782  38.150247
# 3   37.545280  34.202163  35.972466  35.244403  43.209436  36.447397
# 4   38.416223  33.615512  36.028681  34.912613  41.517676  34.124001
# 5   37.425551  33.259056  37.830663  35.445667  44.338142  35.412266
# 6   37.432141  33.605894  35.273938  32.318195  42.823622  33.719831
# 7   34.534097  34.714673  37.684643  31.096745  42.831314  33.859500
# 8   34.638781  34.718019  38.841144  32.616004  41.881171  33.537269
# 9   33.130189  34.538003  39.112510  30.442655  40.794492  32.688636
# 10  33.196277  33.243501  36.994869  30.176438  40.637266  34.745232
# 11  32.959706  33.594236  38.708917  29.894147  41.753715  32.630171
# 12  33.588054  32.713873  36.977539  29.488137  42.606520  32.202244
# 13  33.825988  32.514442  34.893807  29.058148  42.197309  33.384726
# 14  33.940465  33.692988  35.508221  29.388998  40.465618  32.433098
# 15  34.035842  33.520274  35.786621  28.270409  41.225127  32.221167
# 16  35.520819  33.951841  33.553077  27.014390  41.208813  32.905814
# 17  36.979726  35.421653  34.078367  26.477946  43.326775  31.827507
# 18  35.655803  34.759831  33.470705  28.512434  43.549163  30.920044
# 19  33.778647  33.978362  33.338944  27.003554  42.810618  31.153906
# 20  37.195991  35.281604  32.446660  28.241314  40.449978  30.765273
# 21  34.754684  36.745422  30.987065  28.321215  37.498174  31.533679
# 22  33.168695  35.708382  31.518524  29.590308  38.538979  32.253033
# 23  33.313038  35.628313  29.943514  28.952084  38.801922  33.305290
# 24  33.288659  36.777621  26.918761  29.004610  39.266509  30.800031
# 25  32.847031  34.092375  26.907796  30.949045  39.678599  30.192750
# 26  32.487799  33.835927  27.562726  31.135836  41.165449  30.368107
# 27  33.842647  32.883716  26.410613  30.763542  39.757378  29.915947
# 28  34.027018  30.942965  27.139543  29.563156  38.206038  28.409039
# 29  33.294645  32.376684  27.260784  29.563978  36.590283  28.156687
# 30  32.370507  32.749867  27.398655  30.404648  36.077599  27.800454
# 31  32.625087  32.253534  25.483251  30.156258  34.814021  28.345783
# 32  32.694626  31.858670  24.840527  29.292812  35.078515  28.695077
# 33  31.566763  29.713817  24.180435  30.097235  36.716233  27.746775
# 34  31.493908  31.035427  23.326880  31.270426  37.478450  26.753691
# 35  33.435819  32.472840  24.960484  31.982896  35.335736  28.217208
# 36  34.017620  32.576948  24.443463  32.005146  34.289955  27.701427
# 37  32.510631  32.356472  24.054469  30.259304  33.040263  27.311767
# 38  31.498094  32.391013  23.573452  30.632766  32.649182  25.784352
# 39  29.929701  33.927318  25.274876  29.970599  31.519575  25.397288
# 40  29.057878  35.036401  24.405937  30.009352  32.324011  25.984336
# 41  28.798415  36.922722  24.459866  27.259789  33.548327  28.060373
# 42  26.716881  35.220753  23.056603  25.690809  34.714816  29.340385
# 43  27.195599  35.342398  22.564292  25.599111  35.174656  28.486970
# 44  26.253512  34.043377  23.042945  25.460139  34.402268  28.713197
# 45  25.811119  35.468383  23.245630  24.199579  32.092733  27.111803
# 46  26.509407  34.231892  23.628677  22.696668  31.313637  27.586612
# 47  26.170580  31.691015  24.044625  22.712618  30.256919  26.719567
# 48  24.967755  30.807666  23.613674  22.741055  30.799078  27.179203
# 49  26.187198  29.791325  23.960760  23.332162  29.938111  27.376852
# 50  24.320954  29.921726  24.577168  22.157498  28.765111  26.692541
#
#           498        499
# 0   38.598876  36.264569
# 1   38.661598  36.321009
# 2   36.573457  35.480299
# 3   35.485224  35.410612
# 4   35.031554  35.664041
# 5   34.590186  34.274060
# 6   33.511504  34.177211
# 7   34.266173  33.380914
# 8   33.421768  31.872661
# 9   30.420123  31.355249
# 10  31.194495  33.449139
# 11  31.178121  33.438568
# 12  29.687478  34.067591
# 13  29.927574  34.026005
# 14  31.284202  32.610792
# 15  33.181942  31.723189
# 16  33.076449  32.151467
# 17  34.814957  31.153338
# 18  33.729276  29.620856
# 19  33.937337  29.538329
# 20  33.921354  30.671926
# 21  33.589757  28.755399
# 22  31.902255  28.078882
# 23  32.230930  28.850536
# 24  32.522512  29.293097
# 25  32.627587  30.019051
# 26  32.157079  29.369617
# 27  30.943726  29.453197
# 28  29.413525  27.585263
# 29  27.433020  25.864454
# 30  28.194395  26.346066
# 31  27.054005  26.911736
# 32  26.381969  26.009801
# 33  26.267041  25.933627
# 34  27.043150  26.403914
# 35  24.960897  25.059688
# 36  23.759270  25.608293
# 37  24.487565  25.157827
# 38  24.223201  24.220467
# 39  23.449918  24.102694
# 40  23.928218  23.271984
# 41  22.776942  23.603536
# 42  22.714784  23.862151
# 43  21.926320  23.652120
# 44  22.248808  23.895809
# 45  22.021319  24.204993
# 46  21.378863  24.977885
# 47  21.503770  24.922534
# 48  21.015289  24.175595
# 49  20.188008  24.747695
# 50  20.741156  25.072249
#
# [51 rows x 500 columns]

# %%
MC.graph() # creates a graph of the executed Monte Carlo simulation.
# Out:
# MonteCarlo() plotting initialized.
# MonteCarlo() plotting finished.

# %%
MC.get_change() # returns the list of percentage changes throughout the executed simulation.
# Out:
#          0         1         2         3         4         5         6    \
# 0        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1  -0.030740  0.025267 -0.004801 -0.048906  0.025666 -0.004597  0.019634
# 2  -0.006723 -0.015926 -0.041209 -0.034312  0.082656 -0.073755 -0.028585
# 3  -0.016542 -0.014691 -0.049634  0.020761 -0.122908  0.003502 -0.007962
# 4   0.034416 -0.021203  0.028579 -0.007215  0.029537 -0.052677 -0.068760
# 5   0.024042 -0.034473 -0.013916  0.012468 -0.012485  0.006766 -0.024222
# 6  -0.000301  0.000535 -0.001964  0.017459 -0.028722 -0.002347 -0.054398
# 7  -0.072834 -0.005989 -0.083024  0.036489 -0.028516 -0.013974 -0.033785
# 8   0.042234 -0.053424 -0.018735  0.000575 -0.005138  0.045291 -0.005014
# 9   0.013419 -0.033409 -0.033980 -0.011365 -0.020278 -0.022274  0.000588
# 10 -0.039007  0.090356 -0.034707  0.022249  0.031828 -0.026800 -0.032976
# 11  0.001611  0.037214 -0.035648  0.061483  0.065927 -0.063765 -0.027657
# 12 -0.004455 -0.016545 -0.018744 -0.018715  0.037823 -0.025296 -0.008266
# 13  0.027605 -0.002505 -0.040907 -0.017793 -0.022858 -0.031703 -0.036439
# 14 -0.021238 -0.058458  0.000163  0.033612  0.001572 -0.021644  0.002215
# 15  0.011381  0.058467 -0.028277 -0.027717 -0.044438 -0.011410  0.040595
# 16  0.014334  0.005572  0.032207  0.000453 -0.010861  0.006202 -0.085563
# 17  0.016742 -0.018775 -0.053761 -0.096505  0.000099  0.043922  0.017050
# 18 -0.064058 -0.060656  0.009194 -0.067561 -0.045106 -0.014909 -0.023006
# 19  0.049466  0.004188 -0.073422 -0.050222  0.014749  0.008090 -0.021182
# 20 -0.048097  0.012153  0.009307  0.038023  0.012752  0.026874 -0.030529
# 21 -0.000705 -0.052681 -0.056372 -0.021563 -0.017546 -0.071877  0.035238
# 22 -0.040319 -0.007367 -0.002266 -0.051043 -0.051159  0.008962 -0.026702
# 23  0.013802 -0.026354 -0.027597  0.042240  0.010035 -0.018935  0.064408
# 24 -0.000312 -0.069336  0.001145 -0.026856  0.065807 -0.008661  0.021682
# 25  0.010732  0.057541  0.001077 -0.034254 -0.005444 -0.017720  0.035042
# 26  0.025421 -0.002537  0.027670 -0.040162 -0.032130  0.016605 -0.011305
# 27 -0.041552 -0.022399  0.028473 -0.003281  0.001927  0.035696  0.011180
# 28 -0.014600 -0.097908  0.027699  0.013085 -0.006646 -0.049289  0.065516
# 29  0.038029 -0.007277 -0.018455  0.028406 -0.003971  0.078741 -0.021231
# 30  0.014814  0.005829  0.044723 -0.045330  0.018769  0.020730 -0.011133
# 31 -0.033686  0.053470  0.028647 -0.027664 -0.057496 -0.015962  0.028339
# 32 -0.012404 -0.010638 -0.043679 -0.033511 -0.006858  0.019122  0.072149
# 33 -0.028066 -0.019400 -0.007124 -0.027975 -0.034405 -0.040672  0.041683
# 34 -0.027208 -0.029367 -0.013934 -0.005950 -0.010714  0.012877  0.007829
# 35 -0.015358  0.006051  0.001653 -0.054036 -0.034237 -0.090594  0.020954
# 36 -0.035700  0.002017 -0.043205 -0.018650 -0.000515  0.017057  0.028240
# 37  0.008597  0.029898 -0.010240  0.027126  0.008845 -0.060662 -0.023627
# 38 -0.005433  0.015926 -0.057438  0.015066 -0.093938  0.002853 -0.031218
# 39 -0.035930 -0.061600 -0.001997  0.005762  0.007592  0.020995  0.060037
# 40 -0.022772 -0.039220 -0.042936 -0.042292 -0.077632  0.025051  0.021176
# 41 -0.009570 -0.025870  0.022199  0.015790 -0.010206  0.007009 -0.027214
# 42 -0.024976  0.043447  0.031205 -0.030444 -0.008953  0.006723 -0.054045
# 43  0.017376 -0.037761  0.059727  0.035361  0.015205 -0.014718  0.028275
# 44  0.009227  0.041150  0.063987  0.073444 -0.039245 -0.014208 -0.021369
# 45  0.005751  0.048824 -0.003191 -0.024569 -0.049849 -0.016602  0.003495
# 46 -0.010359  0.002844 -0.072072 -0.019215 -0.003087  0.010288 -0.030626
# 47 -0.050655 -0.099770 -0.035937 -0.074567  0.008467 -0.023470 -0.024184
# 48 -0.072081 -0.005896 -0.067950 -0.014134 -0.027979  0.009211  0.023340
# 49 -0.022117 -0.038783 -0.054495  0.035874  0.007703 -0.047199  0.062146
# 50  0.026420 -0.012111 -0.054331 -0.006885 -0.008501  0.072486  0.027919
#
#          7         8         9    ...       490       491       492       493  \
# 0        NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 1   0.041571 -0.025301  0.033309  ... -0.062086  0.000622  0.024827 -0.070370
# 2   0.002815  0.030655 -0.015373  ...  0.022787 -0.057345 -0.006971  0.024543
# 3   0.016939 -0.016962  0.001948  ... -0.018139 -0.038749  0.015140 -0.008795
# 4   0.043959 -0.041800 -0.002006  ...  0.042452  0.037483  0.023197 -0.017152
# 5  -0.018253 -0.027544 -0.006929  ...  0.006708  0.010393 -0.025788 -0.010604
# 6   0.022642 -0.034640  0.007068  ...  0.010934 -0.026637  0.000176  0.010428
# 7   0.009078  0.015625 -0.040346  ...  0.031013 -0.035780 -0.077421  0.032994
# 8  -0.015273 -0.049108 -0.032930  ...  0.036936  0.000510  0.003031  0.000096
# 9  -0.022062  0.041947  0.054211  ...  0.004457 -0.031339 -0.043552 -0.005185
# 10 -0.050855  0.003795 -0.113467  ...  0.057466 -0.087329  0.001995 -0.037481
# 11  0.000933 -0.029973 -0.010829  ...  0.021029 -0.062957 -0.007126  0.010550
# 12  0.009043  0.013955 -0.043001  ... -0.040782 -0.015364  0.019064 -0.026206
# 13  0.009120 -0.005085 -0.037824  ...  0.017971 -0.066836  0.007084 -0.006096
# 14 -0.009791 -0.057982  0.006059  ...  0.015771 -0.059701  0.003384  0.036247
# 15 -0.031369 -0.002080  0.004894  ...  0.023225 -0.062631  0.002810 -0.005126
# 16  0.014968 -0.000420 -0.043812  ...  0.012772 -0.005248  0.043630  0.012875
# 17  0.024586 -0.008920 -0.045850  ...  0.030462 -0.037497  0.041072  0.043291
# 18  0.009978 -0.060743 -0.008687  ... -0.038488 -0.020444 -0.035801 -0.018684
# 19  0.018057 -0.026704 -0.003415  ...  0.003708 -0.026949 -0.052647 -0.022482
# 20 -0.049467 -0.035352 -0.000273  ... -0.044151  0.032231  0.101169  0.038355
# 21  0.046981 -0.095060 -0.068547  ...  0.006311 -0.000631 -0.065634  0.041490
# 22 -0.051181  0.010487 -0.016725  ... -0.003121 -0.045523 -0.045634 -0.028222
# 23  0.000630 -0.002949 -0.051795  ...  0.036717  0.053302  0.004352 -0.002242
# 24  0.021793  0.038616  0.012088  ... -0.018533 -0.039886 -0.000732  0.032258
# 25  0.015674 -0.042450 -0.034150  ... -0.025182 -0.043698 -0.013267 -0.073013
# 26  0.019771 -0.025142 -0.012344  ... -0.065830 -0.000758 -0.010937 -0.007522
# 27  0.001141  0.005345  0.006585  ... -0.000725 -0.013916  0.041703 -0.028142
# 28 -0.020275 -0.003609 -0.008781  ... -0.022454 -0.038092  0.005448 -0.059019
# 29  0.000127 -0.028606 -0.035751  ... -0.036912  0.025934 -0.021523  0.046334
# 30 -0.023666  0.038247 -0.051160  ...  0.003291 -0.044672 -0.027756  0.011526
# 31  0.024371  0.047101  0.003305  ...  0.016436  0.004318  0.007865 -0.015155
# 32 -0.027766  0.103013 -0.062108  ... -0.010094 -0.007442  0.002131 -0.012243
# 33 -0.004846 -0.061265  0.034779  ... -0.010306  0.026151 -0.034497 -0.067324
# 34 -0.027103 -0.080516 -0.047213  ... -0.037318 -0.002004 -0.002308  0.044478
# 35 -0.004775 -0.009392 -0.035502  ...  0.021328  0.029463  0.061660  0.046315
# 36  0.001922 -0.026605 -0.003764  ... -0.051404 -0.029206  0.017401  0.003206
# 37 -0.049419  0.034577 -0.018387  ... -0.009634 -0.019719 -0.044300 -0.006768
# 38  0.001932  0.004052  0.052800  ...  0.021972  0.008556 -0.031145  0.001067
# 39  0.012506  0.019025  0.016330  ... -0.015942 -0.006160 -0.049793  0.047430
# 40  0.012317 -0.045007 -0.022114  ...  0.026428 -0.002816 -0.029129  0.032690
# 41 -0.024671 -0.042596 -0.067963  ... -0.015687 -0.063045 -0.008929  0.053839
# 42 -0.031184  0.000419  0.018707  ... -0.058588  0.005367 -0.072279 -0.046095
# 43  0.005051  0.027963  0.015729  ... -0.029867 -0.019592  0.017918  0.003454
# 44 -0.064260 -0.023749 -0.047960  ...  0.036812  0.011579 -0.034641 -0.036755
# 45  0.014633  0.026701  0.011675  ... -0.027703 -0.030701 -0.016851  0.041859
# 46 -0.049060  0.033471  0.008481  ... -0.039617 -0.048786  0.027054 -0.034862
# 47  0.008385  0.053862  0.008682  ... -0.012428  0.032593 -0.012781 -0.074225
# 48 -0.009831  0.000523 -0.052686  ...  0.000142 -0.052556 -0.045961 -0.027874
# 49 -0.000538  0.012142  0.046265  ...  0.025599  0.033564  0.048841 -0.032990
# 50 -0.053740 -0.022225 -0.002471  ...  0.000375  0.047355 -0.071265  0.004377
#
#          494       495       496       497       498       499
# 0        NaN       NaN       NaN       NaN       NaN       NaN
# 1   0.017167 -0.017023  0.017838  0.041348  0.001625  0.001556
# 2   0.028398 -0.058095  0.041614  0.000911 -0.054011 -0.023147
# 3  -0.100027  0.004727  0.057376 -0.044635 -0.029755 -0.001964
# 4   0.001563 -0.009414 -0.039153 -0.063747 -0.012785  0.007157
# 5   0.050015  0.015268  0.067934  0.037752 -0.012599 -0.038974
# 6  -0.067583 -0.088233 -0.034158 -0.047792 -0.031185 -0.002826
# 7   0.068342 -0.037795  0.000180  0.004142  0.022520 -0.023299
# 8   0.030689  0.048856 -0.022183 -0.009517 -0.024643 -0.045183
# 9   0.006987 -0.066634 -0.025947 -0.025304 -0.089811 -0.016234
# 10 -0.054142 -0.008745 -0.003854  0.062915  0.025456  0.066780
# 11  0.046332 -0.009355  0.027474 -0.060873 -0.000525 -0.000316
# 12 -0.044728 -0.013582  0.020425 -0.013114 -0.047811  0.018811
# 13 -0.056351 -0.014582 -0.009604  0.036720  0.008087 -0.001221
# 14  0.017608  0.011386 -0.041038 -0.028505  0.045330 -0.041592
# 15  0.007840 -0.038061  0.018769 -0.006534  0.060661 -0.027218
# 16 -0.062413 -0.044429 -0.000396  0.021248 -0.003179  0.013500
# 17  0.015655 -0.019858  0.051396 -0.032770  0.052560 -0.031045
# 18 -0.017831  0.076837  0.005133 -0.028512 -0.031184 -0.049192
# 19 -0.003937 -0.052920 -0.016959  0.007563  0.006169 -0.002786
# 20 -0.026764  0.045837 -0.055141 -0.012475 -0.000471  0.038377
# 21 -0.044984  0.002829 -0.072974  0.024976 -0.009775 -0.062485
# 22  0.017151  0.044811  0.027756  0.022812 -0.050239 -0.023527
# 23 -0.049971 -0.021569  0.006823  0.032625  0.010303  0.027482
# 24 -0.101015  0.001814  0.011973 -0.075221  0.009047  0.015340
# 25 -0.000407  0.067039  0.010495 -0.019717  0.003231  0.024782
# 26  0.024340  0.006035  0.037472  0.005808 -0.014421 -0.021634
# 27 -0.041800 -0.011957 -0.034205 -0.014889 -0.037732  0.002846
# 28  0.027600 -0.039020 -0.039020 -0.050371 -0.049451 -0.063420
# 29  0.004467  0.000028 -0.042291 -0.008883 -0.067333 -0.062381
# 30  0.005057  0.028436 -0.014011 -0.012652  0.027754  0.018621
# 31 -0.069909 -0.008169 -0.035024  0.019616 -0.040447  0.021471
# 32 -0.025221 -0.028632  0.007597  0.012323 -0.024841 -0.033515
# 33 -0.026573  0.027461  0.046687 -0.033048 -0.004356 -0.002929
# 34 -0.035299  0.038980  0.020760 -0.035791  0.029547  0.018134
# 35  0.070031  0.022784 -0.057172  0.054703 -0.076997 -0.050910
# 36 -0.020714  0.000696 -0.029596 -0.018279 -0.048140  0.021892
# 37 -0.015914 -0.054549 -0.036445 -0.014066  0.030653 -0.017591
# 38 -0.019997  0.012342 -0.011836 -0.055925 -0.010796 -0.037259
# 39  0.072175 -0.021616 -0.034598 -0.015012 -0.031923 -0.004863
# 40 -0.034380  0.001293  0.025522  0.023115  0.020397 -0.034465
# 41  0.002210 -0.091624  0.037876  0.079896 -0.048114  0.014247
# 42 -0.057370 -0.057557  0.034770  0.045616 -0.002729  0.010957
# 43 -0.021352 -0.003569  0.013246 -0.029087 -0.034711 -0.008802
# 44  0.021213 -0.005429 -0.021959  0.007941  0.014708  0.010303
# 45  0.008796 -0.049511 -0.067133 -0.055772 -0.010225  0.012939
# 46  0.016478 -0.062105 -0.024276  0.017513 -0.029174  0.031931
# 47  0.017604  0.000703 -0.033746 -0.031430  0.005843 -0.002216
# 48 -0.017923  0.001252  0.017919  0.017202 -0.022716 -0.029970
# 49  0.014698  0.025993 -0.027954  0.007272 -0.039366  0.023664
# 50  0.025726 -0.050345 -0.039181 -0.024996  0.027400  0.013114
#
# [51 rows x 500 columns]

# %%
print(MC.get_risk(15000)) # shows the risk evaluation on top of the number of simulations defined in the parentheses.
# Out:
# 45.3%

# %%
MC.get_stats() # shows the statistics of the executed Monte Carlo simulation.
# Out:
#                     Statistics
# Mean value               25.48
# Standard deviation        6.17
# Maximum value            45.35
# Minimum value            11.19

# %%
MC.hist(graph_title='GitHub Repository Demo', x_title = 'Time period', y_title = 'Value') # histogram of values.
# Out:
# Histogram plotting initiated...
# CHOSEN METHOD: Basic histogram model.
# Histogram plotting finished.

# %%
MC.hist(x_title = 'Time period', y_title = 'Value', method = 'e') # histogram with Empirical rule applied, BEWARE: this option is currently being worked on so do not use it in any research!!!
# Out:
# Histogram plotting initiated...
# CHOSEN METHOD: Empirical rule.
# Histogram plotting finished.

# %%
print(MC) # explains the object.
# Out:
# Monte Carlo defining object that stores the configuration data for creating 500 simulations in a period of 50 time measurement units.

# %%
print(repr(MC)) # explains the representation of the object.
# Out:
# Monte Carlo defining object that stores the configuration data for creating 500 simulations in a period of 50 time measurement units.

# %%
vandal.__license__ #shows the license.
# Out:
# 'Copyright © 2021-2022 David Kundih. All rights reserved. Licensed under the Apache License, Version 2.0 | For more details about the license and terms of use visit the official vandal documentation linked at https://github.com/dkundih/vandal and https://pypi.org/project/vandal'

# %%
vandal.__contact__ # shows the contact information.
# Out:
# 'dakundih@unin.hr | kundihdavid@gmail.com'

# %%
vandal.__documentation__ # shows the documentation details.
# Out:
# 'https://github.com/dkundih/vandal | https://pypi.org/project/vandal'

# %%
vandal.__donate__ # shows the donation options.
# Out:
# 'https://patreon.com/dkundih | https://buymeacoffee.com/dkundih'

# %%
vandal.__credits__ # shows credits.
# Out:
# ['dkundih <https://github.com/dkundih>']

# %%
vandal.__author__ # shows the author.
# Out:
# 'David Kundih'

# %%
vandal.__copyright__ # shows the copyright information.
# Out:
# 'Copyright © 2021-2022 David Kundih'

# %%
help(vandal) # help on library options and possibilities.
# Out:
# Help on package vandal:
#
# NAME
#     vandal
#
# DESCRIPTION
#     vandal - Data science, Data manipulation and Machine learning library.
#     =====================================================================
#
#     This is a connection to the __init__ file of the vandal library.
#
#     AVAILABLE FEATURES IN THE LIBRARY:
#
#         TOOLKIT (MODULE FUNCTIONS)
#         --------------------------
#
#         set of available data manipulation functions from the vandal library.
#             print(help(any_function_listed_below)) in order to see the function details or print(help(vandal.toolkit)) for all functions at once.
#
#             FUNCTIONS (ACCESSIBLE DIRECTLY FROM THE LIBRARY)
#             ------------------------------------------------
#
#                 random_value(mean, st_dev, **rounded) - gives a random value of mean and standard deviation inputed, if rounded = 'y', value will be rounded.
#
#                 random_pool(mean, st_dev, pool_size, **rounded) - gives random values of mean and standard deviation inputed for the amount of values defined in the pool size, if rounded = 'y', values will be rounded.
#
#                 split_values(data, split_method) - splits the data using a split method character.
#
#                 join_values(data, join_method) - joins the data using a join metod character.
#
#                 replace_values(data, replaced_value, replacing_value) - replaces a defined value with a desired value.
#
#                 list_sort(data, array) - manually sorts data depending on defined array of indexes.
#
#                 index_sort(data, split_method, index_array) - sorts the indicies in a list of values based on the index array defined as [x,x,x].
#
#                 auto_sort(data, split_method, trigger = lambda x: x[0]) - automatically splits all values in a list and sorts them based on the added trigger as lambda x: [x[i], x[i]] and joins them back together.
#
#                 create_password(length) - creates a random password with adjustable lenght (default: length = 8).
#
#                 save_to(file, prefix, func_name, choice) - file saver for code clarity.
#
#                 file_handler(file) - handles the file extension upon import.
#
#         MONTECARLO (OBJECT)
#         -------------------
#
#         vandal.MonteCarlo is a module for performing the Monte Carlo simulation over the defined data with a lot of useful features.
#             print(help(vandal.MonteCarlo)) in order to see available features.
#
#         EOQ (OBJECT)
#         ------------
#
#         vandal.EOQ is a module for finding an Economic order quantity over the defined data with a lot of useful features.
#             print(help(vandal.EOQ)) in order to see available features.
#
#         Dijkstra (OBJECT)
#         -----------------
#
#         vandal.Dijkstra is a module for finding the optimal route between the defined nodes from the place of origin to the final destination.
#             print(help(vandal.Dijkstra)) in order to see available features.
#
#         MCapp (EXECUTABLE CLI MODULE)
#         -------------------------
#
#         vandal.MCapp is an executable function that runs the Command Line Interface of the vandal MonteCarlo module.
#             print(help(vandal.MCapp)) in order to see available features.
#
#         EOQapp (EXECUTABLE CLI MODULE)
#         -------------------------
#
#         vandal.EOQapp is an executable function that runs the Command Line Interface of the vandal EOQ module.
#             print(help(vandal.EOQapp)) in order to see available features.
#
# PACKAGE CONTENTS
#     __main__
#     hub (package)
#     misc (package)
#     objects (package)
#
# SUBMODULES
#     toolkit
#
# DATA
#     __APPversion__ = 'v 1.4.1'
#     __all__ = [<function random_value>, <function random_pool>, <function ...
#     __contact__ = 'dakundih@unin.hr | kundihdavid@gmail.com'
#     __copyright__ = 'Copyright © 2021-2022 David Kundih'
#     __documentation__ = 'https://github.com/dkundih/vandal | https://pypi....
#     __donate__ = 'https://patreon.com/dkundih | https://buymeacoffee.com/d...
#     __license__ = 'Copyright © 2021-2022 David Kundih. All rights r...kund...
#
# VERSION
#     3.6.5
#
# AUTHOR
#     David Kundih
#
# CREDITS
#     ['dkundih <https://github.com/dkundih>']
#
# FILE
#     c:\users\kundi\appdata\local\programs\python\python39\lib\site-packages\vandal\__init__.py

# %%
help(vandal.MonteCarlo) # help on object options and possibilities.
# Out:
# Help on class MonteCarlo in module vandal.objects.montecarlo:
#
# class MonteCarlo(builtins.object)
#  |  MonteCarlo(list_of_values: list = None, time_seq: int = None, num_sims: int = None, ref_value_index: int = 0) -> object
#  |
#  |  (OBJECT INFO)
#  |  -------------
#  |
#  |  eg. MonteCarlo = vandal.MonteCarlo()
#  |
#  |  vandal.MonteCarlo - main class that stores the simulation data.
#  |
#  |      * takes 5 additional arguments.
#  |          list_of_values - pandas dataframe of values.
#  |          time_seq - desired time sequence.
#  |          num_sims - desired number of simulation iterations.
#  |          ref_value_index (default: ref_value_index = 0) - index on which the starting point of the simulation is created.
#  |          filtered (defualt: filtered = True) - filters the print option and leaves just the return object.
#  |      * Requirements:
#  |          pandas Python module.
#  |          pd.DataFrame() defined data set.
#  |
#  |  (OBJECT FUNCTIONS)
#  |  ------------------
#  |
#  |  eg. vandal.MonteCarlo.function()
#  |
#  |      .execute() - executes a Monte Carlo simulation on a defined data set.
#  |          * takes 5 additional arguments.
#  |          list_of_values - pandas dataframe of values.
#  |          time_seq - desired time sequence.
#  |          num_sims - desired number of simulation iterations.
#  |          ref_value_index (default: ref_value_index = 0) - index on which the starting point of the simulation is created.
#  |          filtered (defualt: filtered = True) - filters the print options and leaves just the return object.
#  |      * Requirements:
#  |          pandas Python module.
#  |          pd.DataFrame() defined data set.
#  |
#  |      .graph() - plots the Monte Carlo simulation on a graph.
#  |          * takes 5 optional customization arguments. (default: graph_title = 'Monte Carlo simulation', x_title = 'X axis', y_title = 'Y axis', plot_size = (25,10), perform_block = True).
#  |              graph_title - title of the graph.
#  |              x_title - title of the X axis.
#  |              y_title - title on the Y axis.
#  |              plot_size - desired size of the graph. eg. - (x_lenght_num, y_lenght_num). - NOTE: values must be inside the parentheses and divided by a comma.
#  |              perform_block (default: perform_block = True) - False/True may be used depending on the IDE requirements.
#  |
#  |      .get_risk() - calculates the risk of value decrease over time.
#  |          * takes 1 additional argument.
#  |              risk_sims (default: risk_sims = 5000) - number of simulations to perform the risk percantage.
#  |
#  |      .get_stats() - shows the statistics of the Monte Carlo simulation.
#  |          * takes no additional arguments.
#  |
#  |      .get_change() - shows the percentage of Monte Carlo simulation value change for every iteration.
#  |          * takes no additional arguments.
#  |
#  |      .hist() - plots the histogram of Monte Carlo simulation.
#  |          * takes 7 optional customization arguments. (default: graph_title = 'Monte Carlo simulation', x_title = 'X axis', y_title = 'Y axis', plot_size = (25,10), set_bins = None, perform_block = True, method = 'b').
#  |          If method = 'e' is chosen, no customization arguments apply.
#  |              graph_title - title of the graph.
#  |              x_title - title of the X axis.
#  |              y_title - title on the Y axis.
#  |              plot_size - desired size of the graph. eg. - (x_lenght_num, y_lenght_num). - NOTE: values must be inside the parentheses and divided by a comma.
#  |              perform_block (default: perform_block = True) - False/True may be used depending on the IDE requirements.
#  |              method - default method is Basic histogram and it's performed by automation. In order to plot Empirical rule histogram add method = 'e' as the last argument. - NOTE: method of a histogram must be placed within quotation marks.
#  |              set_bins - sets the amount of bins of the histogram. (default: set_bins = self.time_seq)
#  |          * automatically executes the .get_stats() function in order to get standard deviation for the Empirical rule plotting.
#  |
#  |  MCapp (EXECUTABLE CLI MODULE)
#  |  -------------------------
#  |
#  |  vandal.MCapp is an executable function that runs the Command Line Interface of the vandal MonteCarlo module.
#  |      print(help(vandal.MCapp)) in order to see available features.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, list_of_values: list = None, time_seq: int = None, num_sims: int = None, ref_value_index: int = 0) -> object
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self) -> str
#  |      Return repr(self).
#  |
#  |  __str__(self) -> str
#  |      Return str(self).
#  |
#  |  execute(self, filtered: bool = True) -> list
#  |      # executes a Monte Carlo simulation on a defined data set.
#  |
#  |  get_change(self) -> float
#  |      # shows the percentage of Monte Carlo simulation value change for every iteration.
#  |
#  |  get_risk(self, risk_sims: int = 5000) -> float
#  |      # calculates the risk of negative values occuring.
#  |
#  |  get_stats(self) -> dict
#  |      # shows the statistics of the Monte Carlo simulation.
#  |
#  |  graph(self, graph_title: str = 'Monte Carlo simulation', x_title: str = 'X axis', y_title: str = 'Y axis', plot_size: tuple = (25, 10), perform_block: bool = True) -> object
#  |      # plots the Monte Carlo simulation on a graph.
#  |
#  |  hist(self, graph_title: str = 'Histogram of value frequencies', x_title: str = 'X axis', y_title: str = 'Y axis', plot_size: tuple = (25, 10), perform_block: bool = True, set_bins: int = None, **method: str) -> object
#  |      # plots the histogram of Monte Carlo simulation.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __APPversion__ = 'v 1.4.1'
#  |
#  |  __contact__ = 'dakundih@unin.hr | kundihdavid@gmail.com'
#  |
#  |  __copyright__ = 'Copyright © 2021-2022 David Kundih'
#  |
#  |  __documentation__ = 'https://github.com/dkundih/vandal | https://pypi....
#  |
#  |  __donate__ = 'https://patreon.com/dkundih | https://buymeacoffee.com/d...
#  |
#  |  __license__ = 'Copyright © 2021-2022 David Kundih. All rights r...kund...

# %%
help(vandal.MonteCarlo.graph) #Help on function options and possibilities.
# Out:
# Help on function graph in module vandal.objects.montecarlo:
#
# graph(self, graph_title: str = 'Monte Carlo simulation', x_title: str = 'X axis', y_title: str = 'Y axis', plot_size: tuple = (25, 10), perform_block: bool = True) -> object
#     # plots the Monte Carlo simulation on a graph.

# %%
vandal.__file__ # shows the library path.
# Out:
# 'C:\\Users\\kundi\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\vandal\\__init__.py'

# %%
vandal.__all__ # shows the imported objects and modules from the library in the main module.
# Out:
# [<function vandal.hub.toolkit.random_value(mean, st_dev, **rounded)>,
#  <function vandal.hub.toolkit.random_pool(mean, st_dev, pool_size, **rounded)>,
#  <function vandal.hub.toolkit.split_values(data, split_method)>,
#  <function vandal.hub.toolkit.join_values(data, join_method)>,
#  <function vandal.hub.toolkit.replace_values(data, replaced_value, replacing_value)>,
#  <function vandal.hub.toolkit.list_sort(data, array)>,
#  <function vandal.hub.toolkit.index_sort(data, split_method, index_array)>,
#  <function vandal.hub.toolkit.auto_sort(data, split_method, trigger=<function <lambda> at 0x00000220015ACAF0>)>,
#  <function vandal.hub.toolkit.create_password(length=8)>,
#  <function vandal.hub.toolkit.file_handler(file)>,
#  <function vandal.hub.toolkit.save_to(file, prefix, func_name, choice)>,
#  <module 'vandal.hub.toolkit' from 'C:\\Users\\kundi\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\vandal\\hub\\toolkit.py'>,
#  vandal.objects.montecarlo.MonteCarlo,
#  <function vandal.objects.montecarlo.MCapp()>,
#  vandal.objects.eoq.EOQ,
#  <function vandal.objects.eoq.EOQapp()>,
#  vandal.objects.dijkstra.Dijkstra]

# %%
vandal.objects.__all__ # shows the available objects from the objects module.
# Out:
# [vandal.objects.montecarlo.MonteCarlo,
#  vandal.objects.eoq.EOQ,
#  vandal.objects.dijkstra.Dijkstra,
#  <function vandal.objects.montecarlo.MCapp()>,
#  <function vandal.objects.eoq.EOQapp()>]

# %%
vandal.misc.__all__ # shows the meta data from the misc module.
# Out:
# ['David Kundih',
#  'Copyright © 2021-2022 David Kundih',
#  ['dkundih <https://github.com/dkundih>'],
#  'Copyright © 2021-2022 David Kundih. All rights reserved. Licensed under the Apache License, Version 2.0 | For more details about the license and terms of use visit the official vandal documentation linked at https://github.com/dkundih/vandal and https://pypi.org/project/vandal',
#  '3.6.5',
#  'https://github.com/dkundih/vandal | https://pypi.org/project/vandal',
#  'dakundih@unin.hr | kundihdavid@gmail.com',
#  'https://patreon.com/dkundih | https://buymeacoffee.com/dkundih',
#  'v 1.4.1']
