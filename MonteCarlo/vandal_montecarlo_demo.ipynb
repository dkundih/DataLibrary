# %%
import vandal #vandal 3.0.0 was used in this example.
import pandas as pd #Importing pandas to create a DataFrame.

# %%
vandal.__version__ #Version used.
# Out:
# '3.0.0'

# %%
df = pd.DataFrame({
    'Example_data' : [38,37,38,36,36,35,36,34,33,34,35] #Example list of values.
})

# %%
MC = vandal.MonteCarlo() #Object defined as MC.

# %%
MC.execute(df['Example_data'], 50, 500) #Executes the Monte Carlo simulation.
# Out:
# Monte Carlo has been set up for 500 simulations in a period of 50 time measurement units.
# Monte Carlo simulation has been executed.
# NOTE: Use data with reasonable standard deviation in order to prevent exponential growth of the function that cannot be plotted properly, recognize such abnormal values by a + sign anywhere in the data executed below.
# The model that will be able to handle big standard deviations is currently being worked on, thank you for your patience.
#
# Monte Carlo simulation set up and ready to plot.
#           0          1          2          3          4          5    \
# 0   39.284222  37.550912  38.753982  37.037540  36.736496  37.620102
# 1   40.797014  38.403296  37.989220  36.930675  36.411105  37.115331
# 2   42.500452  36.260313  39.454989  38.523432  33.023611  35.010434
# 3   38.858603  35.303969  41.347434  40.112725  33.205873  33.668375
# 4   39.678655  34.899234  42.257203  39.222218  33.213524  35.134957
# 5   37.821052  36.359247  43.598821  39.849518  32.833707  33.739936
# 6   37.209719  34.699601  42.459334  37.709062  31.718481  33.490623
# 7   38.354921  34.958012  42.795687  36.337273  31.598722  34.614224
# 8   41.120018  35.773518  43.508969  34.806712  31.808407  35.537754
# 9   41.945340  36.380107  42.579869  33.816082  31.973717  35.032112
# 10  44.954980  35.342200  41.811982  32.876434  31.209358  33.874311
# 11  44.008218  35.922837  41.772993  34.306487  32.440919  34.090004
# 12  44.184485  35.051502  41.687562  35.269360  33.390658  33.503159
# 13  42.205250  33.670638  41.758611  36.209783  33.754946  32.966124
# 14  42.560594  34.704990  41.429399  36.575126  34.382351  32.644114
# 15  42.064814  34.194811  40.030366  35.953327  34.125341  32.467617
# 16  39.561298  34.867976  38.905250  38.497160  34.595754  30.941306
# 17  40.461381  35.397149  38.043376  36.447449  31.195706  32.274002
# 18  37.238910  36.449775  34.723196  35.052767  32.238289  34.948759
# 19  36.499560  35.866412  33.914275  33.869167  31.707105  33.907574
# 20  38.467182  35.934439  34.181387  34.884560  31.494688  34.359523
# 21  38.647028  34.331414  35.715754  32.076596  30.826120  33.198315
# 22  38.233737  33.788040  34.703079  30.098700  31.445099  34.651766
# 23  36.674949  33.969739  32.686205  30.546890  28.477634  34.801803
# 24  34.850271  33.921639  31.385069  31.578538  27.342548  33.473208
# 25  33.155106  32.970402  30.411872  31.953542  28.360843  33.733927
# 26  32.242553  33.003749  31.841499  30.451286  28.025338  34.492952
# 27  29.588247  34.053411  32.078674  31.352235  29.528032  34.984330
# 28  30.043477  32.343163  31.101238  30.626413  27.993311  34.831794
# 29  29.133837  30.383553  29.930474  30.496737  26.297588  34.690349
# 30  28.158313  31.886817  30.197825  30.609004  25.565683  37.316142
# 31  28.481709  32.811713  30.315935  29.396153  25.483085  36.354824
# 32  26.414257  32.648560  30.092685  26.952143  25.814150  37.388761
# 33  26.856283  32.708034  27.538198  26.412630  25.642367  39.797817
# 34  27.284646  33.115902  26.022256  25.604498  24.510906  38.657650
# 35  26.098101  33.526292  26.207632  25.457477  23.787264  35.270737
# 36  25.242822  32.663789  26.660027  25.342680  22.667875  35.242957
# 37  23.612203  30.597704  26.044045  25.439640  22.107642  34.531865
# 38  23.997178  29.997792  27.049008  25.923111  22.201744  36.907657
# 39  23.240317  29.216821  26.069950  25.233868  21.721434  38.616864
# 40  22.105086  28.897752  25.090739  24.995574  22.486571  37.670693
# 41  21.983100  28.831010  23.604162  24.230142  21.988802  36.132138
# 42  21.279066  29.147141  23.769324  24.099038  21.127042  34.379850
# 43  22.072675  27.458047  25.414541  23.727411  19.998455  34.445638
# 44  21.566434  28.811430  24.787123  23.047828  19.851187  35.447608
# 45  21.771721  28.980515  23.324433  24.053315  18.657065  32.430516
# 46  21.708926  28.855925  24.252704  24.017384  18.712230  32.566100
# 47  22.883584  27.939162  23.952246  23.456319  19.397795  32.237978
# 48  22.010248  27.110857  23.772523  23.060832  18.928543  31.429214
# 49  23.106693  25.047031  22.571032  22.986464  17.807174  30.250785
# 50  22.823053  23.878890  23.083399  23.023084  17.899274  29.867169
#
#           6          7          8          9    ...        490        491  \
# 0   37.653683  37.756989  38.319882  39.198064  ...  38.456044  37.812791
# 1   37.802518  38.574075  37.991381  39.304848  ...  38.327981  40.046425
# 2   37.369628  36.721618  34.381508  39.720678  ...  41.761042  38.222933
# 3   37.576218  35.672305  34.376288  37.709791  ...  41.801406  39.769844
# 4   37.897109  33.997072  34.187511  36.902801  ...  41.346288  41.820787
# 5   37.016096  34.008820  33.303548  36.929563  ...  40.452010  40.300343
# 6   36.204707  32.755893  32.952309  36.797446  ...  40.336574  41.105725
# 7   36.074049  34.014025  32.445614  36.288328  ...  40.644997  39.646745
# 8   36.911670  33.481633  32.368379  36.418164  ...  39.556849  38.560777
# 9   36.723824  32.332630  32.898943  35.482396  ...  40.298177  40.219307
# 10  34.896289  33.051180  34.489242  36.515797  ...  42.299421  42.281271
# 11  35.141757  33.581461  34.203213  36.554563  ...  41.803254  39.447438
# 12  34.692199  33.297451  33.321250  38.695889  ...  42.096828  38.278580
# 13  33.431427  32.023199  34.295844  37.915124  ...  43.266810  37.880664
# 14  32.611404  31.732771  35.467046  36.344526  ...  42.689666  38.960148
# 15  31.783999  31.144906  35.749675  33.583851  ...  40.373902  39.856658
# 16  30.908051  32.909894  35.022369  34.617675  ...  38.448046  39.637860
# 17  28.459932  32.098635  33.509497  35.514912  ...  37.560667  39.220592
# 18  28.463728  31.769455  32.547164  37.219293  ...  38.511383  39.345158
# 19  29.459745  32.594105  30.169483  35.577670  ...  36.257034  38.126651
# 20  28.447779  30.289843  31.697045  34.388988  ...  36.223203  35.372285
# 21  28.308659  28.352195  33.142122  33.889645  ...  34.783893  36.352898
# 22  28.134910  28.443448  33.215317  34.099283  ...  35.130234  37.381942
# 23  29.448283  28.545009  34.888371  34.046277  ...  36.254335  37.542180
# 24  30.936199  27.626641  34.844954  34.275446  ...  37.196094  35.558715
# 25  31.247665  26.775489  35.105225  31.361783  ...  38.577289  35.484568
# 26  31.018200  23.674587  34.072628  29.284270  ...  38.050198  34.471934
# 27  33.706979  23.537470  35.266993  26.750223  ...  35.949014  30.732849
# 28  30.780749  22.577690  36.174825  26.006356  ...  36.744275  29.411085
# 29  31.415660  21.953198  36.807535  26.603352  ...  36.656710  28.476335
# 30  31.442760  21.385896  36.776079  26.858717  ...  34.587083  27.534023
# 31  29.845478  20.704721  38.622461  26.258777  ...  36.104195  27.706777
# 32  31.204736  19.928812  39.314234  25.370075  ...  36.033079  25.961381
# 33  31.569458  20.280965  39.486359  25.612923  ...  36.348873  27.047237
# 34  32.082825  18.932859  40.480012  24.928122  ...  35.913828  26.162945
# 35  31.058661  18.953881  40.260041  24.082467  ...  35.446030  26.687604
# 36  30.725717  19.003638  43.010113  23.298086  ...  34.015820  27.496500
# 37  29.754793  18.949355  42.556801  23.700473  ...  33.183546  25.829114
# 38  29.713030  20.383441  43.272187  24.042226  ...  31.672951  26.833646
# 39  29.806298  21.053837  40.105538  24.096823  ...  32.519193  25.718368
# 40  29.862929  21.818489  40.704965  24.010388  ...  33.655439  25.078196
# 41  31.595792  21.257522  38.850314  23.746513  ...  34.668710  25.114159
# 42  31.424230  21.977235  36.970428  23.353057  ...  33.366411  24.821197
# 43  31.489900  22.535168  36.625382  23.379902  ...  31.781159  24.380194
# 44  31.209993  22.373518  35.478837  22.622844  ...  30.599767  23.265925
# 45  31.941288  21.598484  35.980313  22.003754  ...  29.287970  24.111170
# 46  30.476201  20.737950  36.414721  21.538183  ...  28.236717  24.636857
# 47  29.818879  20.203944  35.152552  20.791061  ...  26.449363  24.962630
# 48  31.168073  21.912728  35.066383  20.849278  ...  27.184810  25.163398
# 49  30.946381  21.842191  32.731651  21.113196  ...  27.480999  25.507837
# 50  31.808616  21.694618  31.252055  19.939088  ...  25.936655  24.083864
#
#           492        493        494        495        496        497  \
# 0   36.009464  38.398948  39.503102  37.654997  36.888156  39.599342
# 1   36.964194  37.153440  39.930601  37.550663  36.561630  42.882852
# 2   37.921897  37.398553  35.623529  36.643681  36.429856  39.359661
# 3   39.520835  38.022009  34.675638  38.562607  37.192534  37.709267
# 4   38.050770  38.630663  34.721570  39.711634  37.410971  36.398566
# 5   36.772659  38.363808  34.431051  39.483105  35.549930  35.221242
# 6   38.674727  36.852718  33.729523  39.346965  35.618432  34.337052
# 7   37.029072  34.886303  30.962639  37.117075  36.165089  35.228674
# 8   37.321256  32.787595  30.271904  37.050471  35.007177  36.871672
# 9   37.719665  31.944188  28.672044  36.470704  34.228075  36.608475
# 10  35.840086  30.953947  27.564678  34.158615  31.986129  36.350766
# 11  35.920833  30.732297  27.544990  35.495317  31.934758  35.991492
# 12  36.497307  29.123268  28.147526  33.637091  30.700641  36.145758
# 13  37.518922  27.339209  28.845175  33.098083  31.916298  36.438107
# 14  39.758206  27.598045  29.261652  34.390109  31.358207  37.045562
# 15  37.292349  29.882349  28.915543  36.122172  29.579529  35.590106
# 16  36.599627  26.927343  27.397893  37.143656  29.645494  37.090740
# 17  33.939437  26.912521  27.323068  36.883494  30.340512  36.231917
# 18  33.988141  27.183232  27.223305  35.826647  30.164221  35.369216
# 19  33.507548  27.164186  27.738331  35.423494  29.548094  35.089328
# 20  33.222798  26.574546  29.403362  33.488000  28.934350  35.337935
# 21  34.500341  25.551893  29.268860  34.880243  28.876206  34.955656
# 22  31.970414  24.830272  29.317802  35.393780  29.396756  35.182835
# 23  30.837258  25.030771  29.047201  38.627749  30.210376  33.902081
# 24  31.206049  25.303818  29.111087  38.459546  30.746299  31.866588
# 25  30.420456  24.829923  28.574248  38.479758  30.850283  34.125261
# 26  31.083917  25.740763  29.860674  36.624683  30.293748  32.350443
# 27  31.711642  24.109077  27.676030  34.577207  28.995328  34.169420
# 28  31.539545  22.839880  28.091012  34.388401  28.190301  36.454775
# 29  30.313533  25.142655  25.889696  32.965430  28.550923  36.244961
# 30  30.380888  25.478763  25.650004  34.008458  28.222450  36.825237
# 31  29.786362  24.975522  25.685270  34.748515  26.842982  36.896171
# 32  28.381333  24.234997  22.776743  32.275164  27.646433  37.479630
# 33  26.938974  24.770316  22.049616  31.319031  26.976454  33.563285
# 34  27.288295  25.301813  23.205279  31.579528  26.856597  32.702686
# 35  27.819461  24.224670  23.092028  31.332491  25.835620  32.376978
# 36  27.960366  24.714699  23.661096  30.378347  24.811894  32.073499
# 37  28.395914  25.772554  23.233642  30.846820  24.479102  32.340932
# 38  28.402358  24.492448  21.529352  30.312071  24.186916  31.110102
# 39  27.214706  25.125782  20.802093  31.351453  25.090772  32.253076
# 40  29.075035  24.747131  19.563388  31.261633  26.173648  30.779643
# 41  28.077282  25.226669  19.050790  31.195592  26.085236  29.221155
# 42  27.670700  25.031676  17.934275  33.925830  25.496427  29.445098
# 43  27.233957  25.647217  17.967304  34.319123  25.863531  29.210432
# 44  27.094098  24.475370  17.995703  35.042637  26.596161  28.367302
# 45  28.280863  25.357552  18.117748  36.806827  24.542099  27.603345
# 46  28.274548  25.529273  18.003327  38.128748  23.894158  25.630826
# 47  29.939681  25.687928  16.685970  36.705411  25.087953  25.737099
# 48  28.963417  25.399658  16.097114  37.656105  24.688490  24.797981
# 49  27.879441  25.666118  16.625213  36.555517  25.039369  24.125075
# 50  27.518951  26.183715  15.332186  35.396118  25.281329  24.203369
#
#           498        499
# 0   39.867542  37.174467
# 1   38.991168  35.425801
# 2   39.892677  36.553020
# 3   38.585540  36.919301
# 4   38.092797  36.942116
# 5   37.468117  36.763052
# 6   36.402389  37.208061
# 7   37.410022  38.137241
# 8   37.125908  38.297690
# 9   39.158077  37.945142
# 10  38.733849  36.899018
# 11  38.800696  36.569352
# 12  39.854455  38.677825
# 13  40.036411  38.770228
# 14  39.023642  37.192940
# 15  38.404399  36.539778
# 16  39.122179  37.323712
# 17  38.604179  38.492048
# 18  38.013624  37.456057
# 19  38.877713  36.535983
# 20  40.448527  35.561436
# 21  40.530293  33.937525
# 22  39.955898  33.496953
# 23  38.685849  34.526169
# 24  36.527590  34.148466
# 25  37.660686  34.344219
# 26  36.841734  35.395221
# 27  37.492581  34.221725
# 28  36.798497  34.920162
# 29  36.871847  32.229412
# 30  37.278716  32.447293
# 31  38.929835  32.775250
# 32  39.828106  35.239137
# 33  39.029652  35.578981
# 34  38.540200  36.950141
# 35  36.584277  36.071377
# 36  36.690379  34.363876
# 37  35.919424  32.202206
# 38  34.056636  32.972188
# 39  33.737511  33.505748
# 40  32.787455  32.765470
# 41  32.571894  30.876005
# 42  32.572583  30.503179
# 43  33.702862  31.187912
# 44  33.749470  31.062451
# 45  33.217769  30.026125
# 46  31.825801  27.675728
# 47  31.825958  28.438672
# 48  30.520003  26.605965
# 49  30.701993  26.772154
# 50  31.226623  25.643376
#
# [51 rows x 500 columns]

# %%
MC.graph() #Creates a graph of the executed Monte Carlo simulation.
# Out:
# MonteCarlo() plotting initialized.
# MonteCarlo() plotting finished.

# %%
MC.get_change() #Returns the list of percentage changes throughout the executed simulation.
# Out:
#          0         1         2         3         4         5         6    \
# 0        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1   0.038509  0.022699 -0.019734 -0.002885 -0.008857 -0.013418  0.003953
# 2   0.041754 -0.055802  0.038584  0.043128 -0.093035 -0.056712 -0.011451
# 3  -0.085690 -0.026374  0.047965  0.041255  0.005519 -0.038333  0.005528
# 4   0.021103 -0.011464  0.022003 -0.022200  0.000230  0.043560  0.008540
# 5  -0.046816  0.041835  0.031749  0.015993 -0.011436 -0.039705 -0.023247
# 6  -0.016164 -0.045646 -0.026136 -0.053713 -0.033966 -0.007389 -0.021920
# 7   0.030777  0.007447  0.007922 -0.036378 -0.003776  0.033550 -0.003609
# 8   0.072092  0.023328  0.016667 -0.042121  0.006636  0.026681  0.023220
# 9   0.020071  0.016956 -0.021354 -0.028461  0.005197 -0.014228 -0.005089
# 10  0.071751 -0.028530 -0.018034 -0.027787 -0.023906 -0.033050 -0.049764
# 11 -0.021060  0.016429 -0.000932  0.043498  0.039461  0.006367  0.007034
# 12  0.004005 -0.024256 -0.002045  0.028067  0.029276 -0.017215 -0.012793
# 13 -0.044795 -0.039395  0.001704  0.026664  0.010910 -0.016029 -0.036342
# 14  0.008419  0.030720 -0.007884  0.010090  0.018587 -0.009768 -0.024529
# 15 -0.011649 -0.014700 -0.033769 -0.017001 -0.007475 -0.005407 -0.025372
# 16 -0.059516  0.019686 -0.028107  0.070754  0.013785 -0.047010 -0.027559
# 17  0.022752  0.015176 -0.022153 -0.053243 -0.098279  0.043072 -0.079207
# 18 -0.079643  0.029738 -0.087274 -0.038266  0.033421  0.082877  0.000133
# 19 -0.019854 -0.016005 -0.023296 -0.033766 -0.016477 -0.029792  0.034992
# 20  0.053908  0.001897  0.007876  0.029980 -0.006699  0.013329 -0.034351
# 21  0.004675 -0.044610  0.044889 -0.080493 -0.021228 -0.033796 -0.004890
# 22 -0.010694 -0.015827 -0.028354 -0.061662  0.020080  0.043781 -0.006138
# 23 -0.040770  0.005378 -0.058118  0.014891 -0.094370  0.004330  0.046681
# 24 -0.049753 -0.001416 -0.039807  0.033773 -0.039859 -0.038176  0.050526
# 25 -0.048641 -0.028042 -0.031008  0.011875  0.037242  0.007789  0.010068
# 26 -0.027524  0.001011  0.047009 -0.047014 -0.011830  0.022500 -0.007343
# 27 -0.082323  0.031804  0.007449  0.029587  0.053619  0.014246  0.086684
# 28  0.015385 -0.050223 -0.030470 -0.023151 -0.051975 -0.004360 -0.086814
# 29 -0.030277 -0.060588 -0.037644 -0.004234 -0.060576 -0.004061  0.020627
# 30 -0.033484  0.049476  0.008932  0.003681 -0.027832  0.075692  0.000863
# 31  0.011485  0.029006  0.003911 -0.039624 -0.003231 -0.025761 -0.050800
# 32 -0.072589 -0.004972 -0.007364 -0.083140  0.012992  0.028440  0.045543
# 33  0.016734  0.001822 -0.084887 -0.020017 -0.006655  0.064433  0.011688
# 34  0.015950  0.012470 -0.055049 -0.030596 -0.044125 -0.028649  0.016261
# 35 -0.043488  0.012393  0.007124 -0.005742 -0.029523 -0.087613 -0.031923
# 36 -0.032772 -0.025726  0.017262 -0.004509 -0.047058 -0.000788 -0.010720
# 37 -0.064597 -0.063253 -0.023105  0.003826 -0.024715 -0.020177 -0.031600
# 38  0.016304 -0.019606  0.038587  0.019005  0.004257  0.068800 -0.001404
# 39 -0.031540 -0.026034 -0.036196 -0.026588 -0.021634  0.046310  0.003139
# 40 -0.048848 -0.010921 -0.037561 -0.009443  0.035225 -0.024502  0.001900
# 41 -0.005518 -0.002310 -0.059248 -0.030623 -0.022136 -0.040842  0.058027
# 42 -0.032026  0.010965  0.006997 -0.005411 -0.039191 -0.048497 -0.005430
# 43  0.037295 -0.057951  0.069216 -0.015421 -0.053419  0.001914  0.002090
# 44 -0.022935  0.049289 -0.024687 -0.028641 -0.007364  0.029088 -0.008889
# 45  0.009519  0.005869 -0.059010  0.043626 -0.060154 -0.085114  0.023431
# 46 -0.002884 -0.004299  0.039798 -0.001494  0.002957  0.004181 -0.045868
# 47  0.054109 -0.031770 -0.012389 -0.023361  0.036637 -0.010076 -0.021568
# 48 -0.038164 -0.029647 -0.007503 -0.016861 -0.024191 -0.025087  0.045246
# 49  0.049815 -0.076125 -0.050541 -0.003225 -0.059242 -0.037495 -0.007113
# 50 -0.012275 -0.046638  0.022700  0.001593  0.005172 -0.012681  0.027862
#
#          7         8         9    ...       490       491       492       493  \
# 0        NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 1   0.021641 -0.008573  0.002724  ... -0.003330  0.059071  0.026513 -0.032436
# 2  -0.048023 -0.095018  0.010580  ...  0.089571 -0.045534  0.025909  0.006597
# 3  -0.028575 -0.000152 -0.050626  ...  0.000967  0.040471  0.042164  0.016671
# 4  -0.046962 -0.005491 -0.021400  ... -0.010888  0.051570 -0.037197  0.016008
# 5   0.000346 -0.025856  0.000725  ... -0.021629 -0.036356 -0.033590 -0.006908
# 6  -0.036841 -0.010547 -0.003578  ... -0.002854  0.019984  0.051725 -0.039388
# 7   0.038409 -0.015377 -0.013836  ...  0.007646 -0.035493 -0.042551 -0.053359
# 8  -0.015652 -0.002380  0.003578  ... -0.026772 -0.027391  0.007891 -0.060159
# 9  -0.034317  0.016391 -0.025695  ...  0.018741  0.043011  0.010675 -0.025723
# 10  0.022224  0.048339  0.029124  ...  0.049661  0.051268 -0.049830 -0.030999
# 11  0.016044 -0.008293  0.001062  ... -0.011730 -0.067023  0.002253 -0.007161
# 12 -0.008457 -0.025786  0.058579  ...  0.007023 -0.029631  0.016048 -0.052356
# 13 -0.038269  0.029248 -0.020177  ...  0.027793 -0.010395  0.027992 -0.061259
# 14 -0.009069  0.034150 -0.041424  ... -0.013339  0.028497  0.059684  0.009468
# 15 -0.018525  0.007969 -0.075958  ... -0.054246  0.023011 -0.062021  0.082771
# 16  0.056670 -0.020344  0.030783  ... -0.047701 -0.005490 -0.018575 -0.098888
# 17 -0.024651 -0.043197  0.025918  ... -0.023080 -0.010527 -0.072684 -0.000550
# 18 -0.010255 -0.028718  0.047991  ...  0.025311  0.003176  0.001435  0.010059
# 19  0.025957 -0.073053 -0.044107  ... -0.058537 -0.030970 -0.014140 -0.000701
# 20 -0.070696  0.050633 -0.033411  ... -0.000933 -0.072243 -0.008498 -0.021707
# 21 -0.063970  0.045590 -0.014520  ... -0.039734  0.027723  0.038454 -0.038482
# 22  0.003219  0.002209  0.006186  ...  0.009957  0.028307 -0.073331 -0.028241
# 23  0.003571  0.050370 -0.001554  ...  0.031998  0.004287 -0.035444  0.008075
# 24 -0.032173 -0.001244  0.006731  ...  0.025976 -0.052833  0.011959  0.010908
# 25 -0.030809  0.007469 -0.085007  ...  0.037133 -0.002085 -0.025174 -0.018728
# 26 -0.115811 -0.029414 -0.066243  ... -0.013663 -0.028537  0.021810  0.036683
# 27 -0.005792  0.035053 -0.086533  ... -0.055221 -0.108468  0.020195 -0.063389
# 28 -0.040777  0.025742 -0.027808  ...  0.022122 -0.043008 -0.005427 -0.052644
# 29 -0.027660  0.017490  0.022956  ... -0.002383 -0.031782 -0.038872  0.100823
# 30 -0.025841 -0.000855  0.009599  ... -0.056460 -0.033091  0.002222  0.013368
# 31 -0.031852  0.050206 -0.022337  ...  0.043864  0.006274 -0.019569 -0.019751
# 32 -0.037475  0.017911 -0.033844  ... -0.001970 -0.062995 -0.047170 -0.029650
# 33  0.017671  0.004378  0.009572  ...  0.008764  0.041826 -0.050821  0.022089
# 34 -0.066471  0.025164 -0.026737  ... -0.011969 -0.032694  0.012967  0.021457
# 35  0.001110 -0.005434 -0.033924  ... -0.013026  0.020054  0.019465 -0.042572
# 36  0.002625  0.068308 -0.032571  ... -0.040349  0.030310  0.005065  0.020228
# 37 -0.002856 -0.010540  0.017271  ... -0.024467 -0.060640  0.015577  0.042803
# 38  0.075680  0.016810  0.014420  ... -0.045522  0.038891  0.000227 -0.049669
# 39  0.032889 -0.073180  0.002271  ...  0.026718 -0.041563 -0.041815  0.025858
# 40  0.036319  0.014946 -0.003587  ...  0.034941 -0.024892  0.068357 -0.015070
# 41 -0.025711 -0.045563 -0.010990  ...  0.030107  0.001434 -0.034316  0.019378
# 42  0.033857 -0.048388 -0.016569  ... -0.037564 -0.011665 -0.014481 -0.007730
# 43  0.025387 -0.009333  0.001150  ... -0.047510 -0.017767 -0.015784  0.024590
# 44 -0.007173 -0.031305 -0.032381  ... -0.037173 -0.045704 -0.005135 -0.045691
# 45 -0.034641  0.014135 -0.027366  ... -0.042870  0.036330  0.043802  0.036044
# 46 -0.039842  0.012073 -0.021159  ... -0.035894  0.021803 -0.000223  0.006772
# 47 -0.025750 -0.034661 -0.034688  ... -0.063299  0.013223  0.058892  0.006215
# 48  0.084577 -0.002451  0.002800  ...  0.027806  0.008043 -0.032608 -0.011222
# 49 -0.003219 -0.066580  0.012658  ...  0.010895  0.013688 -0.037426  0.010491
# 50 -0.006756 -0.045204 -0.055610  ... -0.056197 -0.055825 -0.012930  0.020167
#
#          494       495       496       497       498       499
# 0        NaN       NaN       NaN       NaN       NaN       NaN
# 1   0.010822 -0.002771 -0.008852  0.082918 -0.021982 -0.047039
# 2  -0.107864 -0.024154 -0.003604 -0.082159  0.023121  0.031819
# 3  -0.026609  0.052367  0.020936 -0.041931 -0.032766  0.010021
# 4   0.001325  0.029796  0.005873 -0.034758 -0.012770  0.000618
# 5  -0.008367 -0.005755 -0.049746 -0.032345 -0.016399 -0.004847
# 6  -0.020375 -0.003448  0.001927 -0.025104 -0.028444  0.012105
# 7  -0.082032 -0.056672  0.015348  0.025967  0.027680  0.024973
# 8  -0.022309 -0.001794 -0.032017  0.046638 -0.007595  0.004207
# 9  -0.052850 -0.015648 -0.022255 -0.007138  0.054737 -0.009205
# 10 -0.038622 -0.063396 -0.065500 -0.007040 -0.010834 -0.027569
# 11 -0.000714  0.039132 -0.001606 -0.009884  0.001726 -0.008934
# 12  0.021875 -0.052351 -0.038645  0.004286  0.027158  0.057657
# 13  0.024785 -0.016024  0.039597  0.008088  0.004566  0.002389
# 14  0.014438  0.039036 -0.017486  0.016671 -0.025296 -0.040683
# 15 -0.011828  0.050365 -0.056721 -0.039288 -0.015868 -0.017561
# 16 -0.052486  0.028279  0.002230  0.042164  0.018690  0.021454
# 17 -0.002731 -0.007004  0.023444 -0.023155 -0.013241  0.031303
# 18 -0.003651 -0.028654 -0.005810 -0.023811 -0.015298 -0.026914
# 19  0.018919 -0.011253 -0.020426 -0.007913  0.022731 -0.024564
# 20  0.060026 -0.054639 -0.020771  0.007085  0.040404 -0.026674
# 21 -0.004574  0.041574 -0.002010 -0.010818  0.002021 -0.045665
# 22  0.001672  0.014723  0.018027  0.006499 -0.014172 -0.012982
# 23 -0.009230  0.091371  0.027677 -0.036403 -0.031786  0.030726
# 24  0.002199 -0.004354  0.017740 -0.060040 -0.055789 -0.010940
# 25 -0.018441  0.000526  0.003382  0.070879  0.031020  0.005732
# 26  0.045020 -0.048209 -0.018040 -0.052009 -0.021746  0.030602
# 27 -0.073161 -0.055904 -0.042861  0.056227  0.017666 -0.033154
# 28  0.014994 -0.005460 -0.027764  0.066883 -0.018513  0.020409
# 29 -0.078364 -0.041379  0.012792 -0.005755  0.001993 -0.077054
# 30 -0.009258  0.031640 -0.011505  0.016010  0.011035  0.006760
# 31  0.001375  0.021761 -0.048878  0.001926  0.044291  0.010107
# 32 -0.113237 -0.071179  0.029932  0.015814  0.023074  0.075175
# 33 -0.031924 -0.029624 -0.024234 -0.104493 -0.020048  0.009644
# 34  0.052412  0.008318 -0.004443 -0.025641 -0.012541  0.038538
# 35 -0.004880 -0.007823 -0.038016 -0.009960 -0.050750 -0.023782
# 36  0.024643 -0.030452 -0.039625 -0.009373  0.002900 -0.047337
# 37 -0.018066  0.015421 -0.013413  0.008338 -0.021012 -0.062905
# 38 -0.073354 -0.017336 -0.011936 -0.038058 -0.051860  0.023911
# 39 -0.033780  0.034289  0.037370  0.036740 -0.009370  0.016182
# 40 -0.059547 -0.002865  0.043158 -0.045683 -0.028160 -0.022094
# 41 -0.026202 -0.002113 -0.003378 -0.050634 -0.006575 -0.057666
# 42 -0.058607  0.087520 -0.022573  0.007664  0.000021 -0.012075
# 43  0.001842  0.011593  0.014398 -0.007970  0.034700  0.022448
# 44  0.001581  0.021082  0.028327 -0.028864  0.001383 -0.004023
# 45  0.006782  0.050344 -0.077232 -0.026931 -0.015754 -0.033363
# 46 -0.006315  0.035915 -0.026401 -0.071459 -0.041904 -0.078278
# 47 -0.073173 -0.037330  0.049962  0.004146  0.000005  0.027567
# 48 -0.035290  0.025901 -0.015922 -0.036489 -0.041034 -0.064444
# 49  0.032807 -0.029227  0.014212 -0.027136  0.005963  0.006246
# 50 -0.077775 -0.031716  0.009663  0.003245  0.017088 -0.042162
#
# [51 rows x 500 columns]

# %%
MC.get_risk(15000) #Shows the risk evaluation on top of the number of simulations defined in the parentheses.
# Out:
# Risk for this option is 45.63 %.

# %%
MC.get_stats() #Shows the statistics of the executed Monte Carlo simulation.
# Out:
# Number of simulations:  50
# Number of iterations:  500
# Mean value:  25.14
# Standard deviation:  6.18
# Maximum:  54.68
# Minimum:  10.83

# %%
MC.hist(graph_title='GitHub Repository Demo', x_title = 'Time period', y_title = 'Value') #Histogram of values.
# Out:
# Histogram plotting initiated...
# CHOSEN METHOD: Basic histogram model.
# Histogram plotting finished.

# %%
MC.hist(x_title = 'Time period', y_title = 'Value', method = 'e') #Histogram with Empirical rule applied, BEWARE: this option is currently being worked on so do not use it in any research!!!
# Out:
# Histogram plotting initiated...
# CHOSEN METHOD: Empirical rule.
# Histogram plotting finished.

# %%
print(MC) #Explains the object.
# Out:
# Monte Carlo defining object that stores the configuration data for creating 500 simulations in a period of 50 time measurement units.

# %%
print(repr(MC)) #Explains the representation of the object.
# Out:
# Monte Carlo defining object that stores the configuration data for creating 500 simulations in a period of 50 time measurement units.

# %%
MC.get_logs() #Returns saved logs of executed functions. BEWARE: available only in DEVELOPER MODE.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3264/1429712747.py in <module>
# ----> 1 MC.get_logs() #Returns saved logs of executed functions. BEWARE: available only in DEVELOPER MODE.
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\vandal\objects\montecarlo.py in get_logs(self)
#     276     # returns the saved logs of executed functions.
#     277     def get_logs(self):
# --> 278         f = open('vandal Logs.txt', 'r')
#     279         print(f.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'vandal Logs.txt'

# %%
vandal.__license__ #Shows the license.
# Out:
# 'Copyright © 2021- David Kundih. All rights reserved. Licensed under the Apache License, Version 2.0 | For more details about the license and terms of use visit the official duality documentation linked at https://github.com/dkundih/duality and https://pypi.org/project/duality'

# %%
vandal.__contact__ #Shows the contact information.
# Out:
# 'dakundih@unin.hr | kundihdavid@gmail.com'

# %%
vandal.__documentation__ #Shows the documentation details.
# Out:
# 'https://github.com/dkundih/duality | https://pypi.org/project/duality'

# %%
vandal.__donate__ #Shows the donation options.
# Out:
# 'https://patreon.com/dkundih | https://buymeacoffee.com/dkundih'

# %%
vandal.__credits__ #Shows credits.
# Out:
# ['dkundih <https://github.com/dkundih>']

# %%
vandal.__author__ #Shows the author.
# Out:
# 'David Kundih'

# %%
vandal.__copyright__ #Shows the copyright information.
# Out:
# 'Copyright © 2021- David Kundih'

# %%
help(vandal) #Help on library options and possibilities.
# Out:
# Help on package duality:
#
# NAME
#     duality
#
# DESCRIPTION
#     duality - Data science, Data manipulation and Machine learning library.
#     =====================================================================
#
#     This is a connection to the main __init__ file of the duality library.
#
#     AVAILABLE FEATURES IN THE LIBRARY:
#
#             TOOLKIT (MODULE FUNCTIONS)
#             --------------------------
#
#             set of available data manipulation functions from the duality library.
#                     print(help(any_function_listed_below)) in order to see the function details or print(help(duality.toolkit)) for all functions at once.
#
#                     FUNCTIONS (ACCESSIBLE DIRECTLY FROM THE LIBRARY)
#                     ------------------------------------------------
#
#                     random_value(mean, st_dev, **rounded) - gives a random value of mean and standard deviation inputed, if rounded = 'y', value will be rounded.
#
#                     random_pool(mean, st_dev, pool_size, **rounded) - gives random values of mean and standard deviation inputed for the amount of values defined in the pool size, if rounded = 'y', values will be rounded.
#
#                     split_values(data, split_method) - splits the data using a split method character.
#
#                     join_values(data, join_method) - joins the data using a join metod character.
#
#                     replace_values(data, replaced_value, replacing_value) - replaces a defined value with a desired value.
#
#                     list_sort(data, array) - manually sorts data depending on defined array of indexes.
#
#                     index_sort(data, split_method, index_array) - sorts the indicies in a list of values based on the index array defined as [x,x,x].
#
#                     auto_sort(data, split_method, trigger = lambda x: x[0]) - automatically splits all values in a list and sorts them based on the added trigger as lambda x: [x[i], x[i]] and joins them back together.
#
#             MONTECARLO (OBJECT)
#             -------------------
#
#             duality.MonteCarlo is a module for performing the Monte Carlo simulation over the defined data with a lot of useful features.
#                     print(help(duality.MonteCarlo)) in order to see available features.
#
#             EOQ (OBJECT)
#             ------------
#
#             duality.EOQ is a module for finding an Economic order quantity over the defined data with a lot of useful features.
#                     print(help(duality.EOQ)) in order to see available features.
#
# PACKAGE CONTENTS
#     hub (package)
#     misc (package)
#     objects (package)
#
# SUBMODULES
#     toolkit
#
# DATA
#     __all__ = [<function random_value>, <function random_pool>, <function ...
#     __contact__ = 'dakundih@unin.hr | kundihdavid@gmail.com'
#     __copyright__ = 'Copyright © 2021- David Kundih'
#     __documentation__ = 'https://github.com/dkundih/duality | https://pypi...
#     __donate__ = 'https://patreon.com/dkundih | https://buymeacoffee.com/d...
#     __license__ = 'Copyright © 2021- David Kundih. All rights reser...ndih...
#
# VERSION
#     3.3.7
#
# AUTHOR
#     David Kundih
#
# CREDITS
#     ['dkundih <https://github.com/dkundih>']
#
# FILE
#     c:\users\kundi\appdata\local\programs\python\python39\lib\site-packages\duality\__init__.py

# %%
help(vandal.MonteCarlo) #Help on object options and possibilities.
# Out:
# Help on class MonteCarlo in module duality.objects.montecarlo:
#
# class MonteCarlo(builtins.object)
#  |  MonteCarlo(list_of_values, time_seq, num_sims, ref_value_index=0, return_data=True, log_summary=False)
#  |
#  |  (OBJECT INFO)
#  |  -------------
#  |
#  |  duality.MonteCarlo - main class that defines the data, desired time sequence and number of simulations.
#  |
#  |      * takes 6 additional arguments.
#  |          list_of_values - pandas dataframe of values.
#  |          time_seq - desired time sequence.
#  |          num_sims - desired number of simulation iterations.
#  |          ref_value_index (default: ref_value_index = 0) - index on which the starting point of the simulation is created.
#  |          return_data (default: return_data = True) - initiates execute() function after data setup.
#  |          log_summary (default: log_summary = False) - event log of executed functions. - DEVELOPER MODE ONLY
#  |      * Requirements:
#  |          pandas Python module.
#  |          pd.DataFrame() defined data set.
#  |      * automatically executes the .execute() function.
#  |
#  |  (OBJECT FUNCTIONS)
#  |  ------------------
#  |
#  |  eg. duality.MonteCarlo.function()
#  |
#  |      .execute() - executes a Monte Carlo simulation on a defined data set.
#  |          *is automatically executed with the Object setup.
#  |
#  |      .graph() - plots the Monte Carlo simulation on a graph.
#  |          * takes 4 optional customization arguments. (default: graph_title = 'Monte Carlo simulation', x_title = 'X axis', y_title = 'Y axis', plot_size = (25,10)).
#  |              graph_title - title of the graph.
#  |              x_title - title of the X axis.
#  |              y_title - title on the Y axis.
#  |              plot_size - desired size of the graph. eg. - (x_lenght_num, y_lenght_num). - NOTE: values must be inside the parentheses and divided by a comma.
#  |
#  |      .get_risk() - calculates the risk of value decrease over time.
#  |          * takes 1 optional argument (default: risk_sims = 5000).
#  |
#  |      .get_stats() - shows the statistics of the Monte Carlo simulation.
#  |          * takes no additional arguments.
#  |
#  |      .get_change() - shows the percentage of Monte Carlo simulation value change for every iteration.
#  |          * takes no additional arguments.
#  |
#  |      .hist() - plots the histogram of Monte Carlo simulation.
#  |          * takes 5 optional customization arguments. (default: graph_title = 'Monte Carlo simulation', x_title = 'X axis', y_title = 'Y axis', plot_size = (25,10), method = 'b').
#  |          If method = 'e' is chosen, no customization arguments apply.
#  |              graph_title - title of the graph.
#  |              x_title - title of the X axis.
#  |              y_title - title on the Y axis.
#  |              plot_size - desired size of the graph. eg. - (x_lenght_num, y_lenght_num). - NOTE: values must be inside the parentheses and divided by a comma.
#  |              method - default method is Basic histogram and it's performed by automation. In order to plot Empirical rule histogram add method = 'e' as the last argument. - NOTE: method of a histogram must be placed within quotation marks.
#  |          * automatically executes the .get_stats(filtered = True) function in order to get standard deviation for the Empirical rule plotting.
#  |
#  |  (DEVELOPER MODE)
#  |  ----------------
#  |
#  |  Developer mode functions can only be set up manually by removing the '#DEVELOPER MODE -' in the source code.
#  |
#  |      .get_logs() - shows the event log of executed functions.
#  |      * takes no additional arguments.
#  |      * Requirements:
#  |          log_summary = True.
#  |          '#DEVELOPER MODE -' removed in the code.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, list_of_values, time_seq, num_sims, ref_value_index=0, return_data=True, log_summary=False)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  __str__(self)
#  |      Return str(self).
#  |
#  |  classLog(func_name)
#  |      #DEVELOPER MODE - creates an event log that tracks the function execution time and duration.
#  |
#  |  execute(self)
#  |      #DEVELOPER MODE - @classLog('execute() - built in function.')
#  |      #executes a Monte Carlo simulation on a defined data set.
#  |
#  |  get_change(self)
#  |      #DEVELOPER MODE - @classLog('get_change()')
#  |      #shows the percentage of Monte Carlo simulation value change for every iteration.
#  |
#  |  get_logs(self)
#  |      #DEVELOPER MODE - @classLog('get_logs()')
#  |      #returns the saved logs of executed functions.
#  |
#  |  get_risk(self, risk_sims=5000)
#  |      #DEVELOPER MODE - @classLog('get_risk()')
#  |      #calculates the risk of negative values occuring.
#  |
#  |  get_stats(self, filtered=False)
#  |      #DEVELOPER MODE - @classLog('get_stats()')
#  |      #shows the statistics of the Monte Carlo simulation.
#  |
#  |  graph(self, graph_title='Monte Carlo simulation', x_title='X axis', y_title='Y axis', plot_size=(25, 10))
#  |      #DEVELOPER MODE - @classLog('graph()')
#  |      #plots the Monte Carlo simulation on a graph.
#  |
#  |  hist(self, graph_title='Histogram of value frequencies', x_title='X axis', y_title='Y axis', plot_size=(25, 10), **method)
#  |      #DEVELOPER MODE - @classLog('hist()')
#  |      #plots the histogram of Monte Carlo simulation.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __contact__ = 'dakundih@unin.hr | kundihdavid@gmail.com'
#  |
#  |  __copyright__ = 'Copyright © 2021- David Kundih'
#  |
#  |  __documentation__ = 'https://github.com/dkundih/duality | https://pypi...
#  |
#  |  __donate__ = 'https://patreon.com/dkundih | https://buymeacoffee.com/d...
#  |
#  |  __license__ = 'Copyright © 2021- David Kundih. All rights reser...ndih...

# %%
help(vandal.MonteCarlo.graph) #Help on function options and possibilities.
# Out:
# Help on function graph in module duality.objects.montecarlo:
#
# graph(self, graph_title='Monte Carlo simulation', x_title='X axis', y_title='Y axis', plot_size=(25, 10))
#     #DEVELOPER MODE - @classLog('graph()')
#     #plots the Monte Carlo simulation on a graph.

# %%
vandal.__file__ #Shows the library path.
# Out:
# 'C:\\Users\\kundi\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\duality\\__init__.py'

# %%
vandal.__all__ #Shows the imported objects and modules from the library in the main module.
# Out:
# [<function duality.hub.toolkit.random_value(mean, st_dev, **rounded)>,
#  <function duality.hub.toolkit.random_pool(mean, st_dev, pool_size, **rounded)>,
#  <function duality.hub.toolkit.split_values(data, split_method)>,
#  <function duality.hub.toolkit.join_values(data, join_method)>,
#  <function duality.hub.toolkit.replace_values(data, replaced_value, replacing_value)>,
#  <function duality.hub.toolkit.list_sort(data, array)>,
#  <function duality.hub.toolkit.index_sort(data, split_method, index_array)>,
#  <function duality.hub.toolkit.auto_sort(data, split_method, trigger=<function <lambda> at 0x000001BA56B72EE0>)>,
#  <module 'duality.hub.toolkit' from 'C:\\Users\\kundi\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\duality\\hub\\toolkit.py'>,
#  duality.objects.montecarlo.MonteCarlo,
#  duality.objects.eoq.EOQ]

# %%
vandal.objects.__all__ #Shows the available objects from the objects module.
# Out:
# [duality.objects.montecarlo.MonteCarlo, duality.objects.eoq.EOQ]

# %%
vandal.misc.__all__ #Shows the meta data from the misc module.
# Out:
# ['David Kundih',
#  'Copyright © 2021- David Kundih',
#  ['dkundih <https://github.com/dkundih>'],
#  'Copyright © 2021- David Kundih. All rights reserved. Licensed under the Apache License, Version 2.0 | For more details about the license and terms of use visit the official duality documentation linked at https://github.com/dkundih/duality and https://pypi.org/project/duality',
#  '3.3.7',
#  'https://github.com/dkundih/duality | https://pypi.org/project/duality',
#  'dakundih@unin.hr | kundihdavid@gmail.com',
#  'https://patreon.com/dkundih | https://buymeacoffee.com/dkundih']
