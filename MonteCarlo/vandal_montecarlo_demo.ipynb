# %%
import vandal #vandal 3.0.1 was used in this example.
import pandas as pd #Importing pandas to create a DataFrame.

# %%
vandal.__version__ #Version used.
# Out:
# '3.0.1'

# %%
df = pd.DataFrame({
    'Example_data' : [38,37,38,36,36,35,36,34,33,34,35] #Example list of values.
})

# %%
MC = vandal.MonteCarlo() #Object defined as MC.

# %%
MC.execute(df['Example_data'], 50, 500) #Executes the Monte Carlo simulation.
# Out:
# Monte Carlo has been set up for 500 simulations in a period of 50 time measurement units.
# Monte Carlo simulation has been executed.
# NOTE: Use data with reasonable standard deviation in order to prevent exponential growth of the function that cannot be plotted properly, recognize such abnormal values by a + sign anywhere in the data executed below.
# The model that will be able to handle big standard deviations is currently being worked on, thank you for your patience.
#
# Monte Carlo simulation set up and ready to plot.
#           0          1          2          3          4          5    \
# 0   39.370729  38.565514  37.793455  37.547826  37.172692  38.083495
# 1   38.848904  39.172694  39.370742  36.231794  38.928502  36.588706
# 2   38.897553  39.000193  40.620017  38.033522  38.732487  35.077933
# 3   38.314768  39.379646  39.837410  37.395896  37.037055  35.506664
# 4   38.287838  38.262702  41.003974  38.064308  35.022609  36.691448
# 5   39.846859  40.219248  40.614577  36.557753  36.100041  35.806986
# 6   40.558711  38.465796  38.984058  36.141979  35.705555  35.843173
# 7   41.113841  39.263782  39.723779  36.655531  36.099595  35.325998
# 8   40.916753  37.536143  41.579422  36.253554  35.584996  32.893569
# 9   39.495646  36.632539  41.682822  36.424766  35.260462  32.757474
# 10  38.842607  34.729940  43.696180  34.779843  32.657666  35.110476
# 11  41.057429  34.630766  44.026198  34.254439  32.848005  35.895385
# 12  37.260991  33.789486  47.019370  33.978582  33.703358  36.906878
# 13  36.604625  32.441328  47.346312  35.720359  32.809078  38.986316
# 14  34.769115  32.332320  47.457588  36.727035  30.841210  42.368582
# 15  35.494761  33.974026  48.354086  38.543674  30.711996  42.307711
# 16  35.232539  32.940082  45.604968  35.599211  29.772737  42.379139
# 17  35.058447  34.622746  47.483982  36.702328  28.965081  40.878979
# 18  34.863136  34.740833  48.082597  38.242160  27.724719  41.935138
# 19  34.050411  36.392804  47.670971  37.725659  27.378105  40.890329
# 20  35.086368  36.157504  49.174579  34.608154  26.156347  40.741736
# 21  35.548199  36.864515  49.128456  35.852832  23.773229  40.267215
# 22  35.793442  35.612630  47.093231  33.771921  23.543669  39.572943
# 23  35.141924  36.291307  46.145975  34.879688  23.639130  43.220098
# 24  34.274005  34.096876  45.982786  35.523215  24.002185  42.366677
# 25  32.517060  34.292997  45.674967  32.853549  25.348653  44.476499
# 26  32.593272  35.341011  45.398231  33.418611  24.838429  45.412266
# 27  32.020140  35.571405  42.952263  34.243069  24.906363  46.792013
# 28  29.570253  35.403357  41.113131  34.738605  23.079901  46.603592
# 29  28.849646  33.734982  40.125266  34.198589  21.291314  46.120380
# 30  30.182806  34.411086  39.980402  32.152470  20.648903  44.630853
# 31  30.100919  35.645921  38.471581  31.190788  20.831295  46.054428
# 32  29.082871  37.659820  36.767743  29.660550  21.113713  47.242472
# 33  30.334460  40.859573  35.204754  29.614211  20.604737  48.535839
# 34  28.054261  41.587282  34.955552  28.722689  19.984416  47.923647
# 35  27.822931  41.093480  35.396048  28.745195  20.603089  49.087566
# 36  27.228760  41.003400  37.187588  29.449350  20.663847  50.577767
# 37  27.113827  38.554197  36.420903  27.826210  19.152016  50.771555
# 38  25.220643  37.079639  37.428422  27.648207  18.146366  50.266690
# 39  25.588521  35.063859  36.167948  26.989992  18.890361  50.085000
# 40  24.128040  33.817739  36.076867  26.239085  18.775197  49.131038
# 41  23.777177  34.676656  35.654175  27.279351  18.049152  47.951347
# 42  25.026865  35.057215  35.719619  27.365682  16.737747  48.709488
# 43  25.887970  34.916954  36.084877  26.660884  15.937241  48.389003
# 44  23.932501  34.530267  35.897795  26.494692  16.180728  47.560360
# 45  23.738942  33.488617  35.152239  25.278741  15.433266  49.188777
# 46  22.736805  32.053605  35.860932  23.972413  15.138420  50.160400
# 47  22.118373  32.997228  36.695583  22.667685  16.391734  47.539420
# 48  21.820369  32.514722  32.902724  21.427339  15.759173  46.974757
# 49  21.694766  32.879560  31.638121  22.331604  14.635375  45.954697
# 50  22.373966  32.720570  32.446680  22.410936  14.114745  45.115454
#
#           6          7          8          9    ...        490        491  \
# 0   38.190283  38.473212  36.877844  38.455921  ...  37.525007  36.970083
# 1   38.105442  39.838290  36.540717  38.999893  ...  35.596578  35.940224
# 2   39.453718  39.320266  36.063491  36.996010  ...  36.754826  34.154269
# 3   40.515159  39.348575  34.398915  36.109460  ...  34.724593  34.928343
# 4   40.937474  40.751197  33.008660  36.977701  ...  34.830710  33.749205
# 5   41.378639  41.226272  30.005613  37.975184  ...  32.220803  33.727152
# 6   41.156601  38.789875  29.937089  36.506795  ...  32.548284  32.755767
# 7   42.255173  38.942284  30.055013  38.719284  ...  31.765686  31.749556
# 8   39.659333  39.584761  29.595098  38.486758  ...  29.726959  32.103458
# 9   38.225564  37.247339  28.544428  38.733681  ...  28.382863  29.269352
# 10  38.186253  38.304544  30.072751  37.907237  ...  28.328842  26.800230
# 11  35.782610  39.335553  30.592355  38.771629  ...  28.288232  25.903288
# 12  34.589823  38.919432  30.179020  39.366879  ...  29.771810  26.845674
# 13  34.383227  37.055370  29.387859  41.893224  ...  28.147911  28.086427
# 14  34.408288  38.401879  31.062998  42.152096  ...  28.337774  27.641861
# 15  35.024952  37.549450  31.417982  39.839893  ...  26.815578  29.177047
# 16  33.132005  39.533818  30.302254  39.256056  ...  27.846833  28.564775
# 17  32.746099  38.542661  32.121573  39.588883  ...  28.289364  29.249949
# 18  29.326334  38.553811  31.387604  37.180489  ...  27.392788  30.064937
# 19  28.948377  37.710782  32.704516  36.705591  ...  28.185656  28.893921
# 20  27.518521  37.239832  32.168720  35.731169  ...  27.591918  29.582069
# 21  27.330912  35.756007  30.783455  36.709977  ...  27.370601  28.078772
# 22  28.730712  36.487060  29.740476  40.000483  ...  28.715032  27.803702
# 23  28.405577  38.017977  28.345203  40.131321  ...  28.380297  28.702073
# 24  27.993650  37.395391  28.589834  39.686635  ...  27.473892  28.875324
# 25  27.295020  37.807521  29.637176  40.957663  ...  28.393694  27.997421
# 26  25.928735  37.015982  29.954855  43.671756  ...  28.437461  28.355206
# 27  25.918850  37.314598  31.118939  44.027846  ...  27.107989  28.930239
# 28  25.232435  38.079080  30.882097  45.125739  ...  25.606365  29.417490
# 29  24.938386  37.200196  30.276511  42.158581  ...  24.979761  30.228754
# 30  23.865438  38.248492  29.750960  42.009961  ...  26.296329  29.798649
# 31  25.908117  36.771100  28.594853  41.113156  ...  25.817817  29.562881
# 32  24.784366  35.606548  28.777852  40.538168  ...  26.436251  28.481038
# 33  23.795660  35.007482  30.195016  38.494382  ...  27.136801  27.810699
# 34  24.860849  35.847508  31.835795  37.874208  ...  25.859725  26.428005
# 35  25.872563  34.682996  31.482956  35.766604  ...  25.198445  27.301830
# 36  25.245195  34.125713  31.916685  34.881242  ...  23.573425  27.090472
# 37  24.647225  32.592474  30.715196  32.953556  ...  24.377328  25.556328
# 38  23.634442  31.189435  29.559497  33.319784  ...  24.380865  26.563281
# 39  23.927211  30.828457  28.962566  32.211424  ...  23.047167  27.326602
# 40  23.572323  32.018966  28.985205  31.814151  ...  24.050154  26.671612
# 41  21.508927  31.076904  29.453267  32.345477  ...  23.123479  26.525882
# 42  21.393958  30.763140  28.431540  32.476804  ...  21.283585  27.662374
# 43  20.722802  33.440484  28.338835  30.148415  ...  20.887008  27.110399
# 44  20.312072  32.997285  27.631292  29.397077  ...  21.400233  26.272058
# 45  20.151001  33.193187  26.857135  28.985151  ...  22.379726  27.052823
# 46  20.688938  33.291245  27.062223  30.844402  ...  21.463190  25.480221
# 47  20.821478  33.083305  28.189829  30.403379  ...  22.584990  26.545148
# 48  21.407071  33.887432  28.320329  30.242248  ...  21.852326  25.844312
# 49  20.360503  31.845478  29.082490  30.291955  ...  22.193789  24.510322
# 50  18.195169  30.905590  29.052648  30.547859  ...  22.028087  22.789303
#
#           492        493        494        495        496        497  \
# 0   36.459074  41.385349  38.747024  37.794133  36.787998  38.164131
# 1   36.377070  39.910181  38.081595  36.526310  38.313317  38.441248
# 2   35.617504  39.608846  35.338198  35.930349  38.183230  38.490875
# 3   34.744353  37.010239  35.563346  35.654196  37.793114  35.155047
# 4   36.151084  35.745309  36.843420  35.836748  37.547296  31.967830
# 5   35.564398  35.074411  35.826430  36.394232  40.184512  32.243288
# 6   34.165156  34.213841  38.169881  35.098251  38.522874  32.910951
# 7   34.417945  34.016775  38.956503  35.324035  33.321398  32.743874
# 8   34.151593  33.170479  39.747857  35.320144  32.583969  32.714620
# 9   34.274279  34.818590  38.400086  31.933088  33.793181  32.076583
# 10  34.110970  36.733732  36.749305  31.909314  32.985846  32.394216
# 11  34.545316  34.372478  36.772325  29.096060  35.760571  31.408805
# 12  34.570492  33.733014  36.702501  29.366695  34.895932  31.501968
# 13  35.780264  33.756505  35.594835  29.349377  34.905267  30.982396
# 14  35.266416  33.645990  35.745383  27.568615  35.128502  31.988842
# 15  35.612870  34.178848  36.464064  25.328033  34.179548  31.420956
# 16  35.667657  34.237625  37.069259  24.680839  36.755638  31.750209
# 17  36.133901  31.347101  36.650413  24.819253  36.282755  32.380734
# 18  35.206930  31.200227  37.282382  25.353316  34.945740  30.843354
# 19  33.686129  30.117103  36.283602  25.057402  34.874125  30.040678
# 20  32.561379  29.819888  34.963423  24.964880  32.178677  29.593459
# 21  34.415872  29.951218  36.370894  25.703871  31.041306  29.154732
# 22  33.768725  30.072417  36.016838  23.974755  30.410954  29.321816
# 23  34.812506  29.558218  36.954153  25.660537  30.479062  29.034237
# 24  35.711005  29.284986  36.454819  24.553533  30.090556  28.415798
# 25  35.998821  29.740664  35.413346  25.535576  29.323006  30.627419
# 26  37.816614  30.209904  34.141356  26.045497  29.505374  32.014775
# 27  37.707906  30.552346  33.153747  24.396791  29.429869  32.206188
# 28  37.357974  30.196687  33.887138  23.435449  29.717499  32.600159
# 29  36.503520  31.123080  32.643848  24.848633  29.143964  33.230372
# 30  35.105095  32.095549  32.477408  23.996933  28.739648  32.745557
# 31  36.211118  32.356259  33.563320  22.725292  25.659091  33.905860
# 32  34.599407  32.569113  34.357022  22.300857  25.552655  33.138610
# 33  33.355309  32.663650  33.373941  22.134283  26.536756  33.263704
# 34  31.826179  31.785474  34.169320  23.673616  27.313029  32.833301
# 35  32.680761  31.678403  34.548560  23.901847  28.793781  32.214820
# 36  32.836896  31.880168  36.264413  23.781952  28.457865  32.193788
# 37  34.696300  31.341353  35.912872  25.482641  27.000974  31.645175
# 38  34.440600  30.923669  35.573822  24.628236  25.640802  31.006258
# 39  33.097619  33.384000  35.812268  25.162859  23.963454  30.664444
# 40  32.114243  32.920725  36.395174  25.673246  22.866168  30.954967
# 41  33.314814  33.604706  35.845258  24.700406  23.081952  30.982788
# 42  32.953322  32.525851  33.425239  25.862426  23.564909  29.463950
# 43  33.400401  32.712273  33.899443  25.342260  24.611841  28.536420
# 44  31.563062  33.029373  33.074949  25.468213  25.893109  28.540292
# 45  32.873179  34.194156  32.318101  24.563973  26.106712  29.016786
# 46  32.761632  34.660912  31.426507  24.230175  26.767798  27.370775
# 47  33.581011  33.383063  29.368337  24.265275  25.219921  27.374940
# 48  32.220260  34.624289  29.870931  23.715561  25.515372  27.053719
# 49  30.222741  34.505880  31.740349  23.632304  25.078951  25.225780
# 50  30.038770  33.876685  29.277274  22.433569  26.011132  24.759308
#
#           498        499
# 0   39.034708  39.179353
# 1   38.473217  39.101385
# 2   37.032823  38.975313
# 3   35.775979  36.744498
# 4   34.335292  37.544602
# 5   34.046874  36.487980
# 6   33.895589  36.730324
# 7   34.139610  39.864919
# 8   34.189427  37.445946
# 9   33.731810  35.967400
# 10  35.050772  38.026105
# 11  34.288583  35.461070
# 12  33.171952  33.896298
# 13  31.794264  30.595120
# 14  30.749708  30.346024
# 15  31.027608  29.851388
# 16  30.271519  29.086081
# 17  30.464800  28.780428
# 18  31.118631  29.084281
# 19  31.138890  28.869901
# 20  29.743617  29.164774
# 21  30.566712  29.056543
# 22  30.220535  27.748199
# 23  30.442504  27.220304
# 24  30.258239  27.675596
# 25  29.843291  27.965176
# 26  31.154934  26.951858
# 27  30.688210  27.550641
# 28  30.778079  26.993910
# 29  30.777162  26.040797
# 30  29.641523  25.152233
# 31  31.708258  25.374882
# 32  29.729588  23.159350
# 33  28.441530  22.440756
# 34  28.879385  22.591331
# 35  30.507881  22.030189
# 36  29.391802  22.460101
# 37  28.593865  24.047911
# 38  28.466801  23.087045
# 39  26.252854  24.094328
# 40  25.619681  24.377917
# 41  24.716027  24.991566
# 42  23.863940  24.605782
# 43  21.785381  25.329261
# 44  22.006832  26.202901
# 45  22.146398  26.964362
# 46  23.649216  26.629072
# 47  22.316189  27.753423
# 48  22.387041  27.480205
# 49  22.215011  27.351231
# 50  20.745286  27.375735
#
# [51 rows x 500 columns]

# %%
MC.graph() #Creates a graph of the executed Monte Carlo simulation.
# Out:
# MonteCarlo() plotting initialized.
# MonteCarlo() plotting finished.

# %%
MC.get_change() #Returns the list of percentage changes throughout the executed simulation.
# Out:
#          0         1         2         3         4         5         6    \
# 0        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1  -0.013254  0.015744  0.041734 -0.035049  0.047234 -0.039250 -0.002222
# 2   0.001252 -0.004404  0.031731  0.049728 -0.005035 -0.041291  0.035383
# 3  -0.014983  0.009730 -0.019267 -0.016765 -0.043773  0.012222  0.026903
# 4  -0.000703 -0.028363  0.029283  0.017874 -0.054390  0.033368  0.010424
# 5   0.040718  0.051135 -0.009497 -0.039579  0.030764 -0.024105  0.010777
# 6   0.017865 -0.043597 -0.040146 -0.011373 -0.010928  0.001011 -0.005366
# 7   0.013687  0.020745  0.018975  0.014209  0.011036 -0.014429  0.026692
# 8  -0.004794 -0.044001  0.046714 -0.010966 -0.014255 -0.068857 -0.061432
# 9  -0.034732 -0.024073  0.002487  0.004723 -0.009120 -0.004137 -0.036152
# 10 -0.016534 -0.051937  0.048302 -0.045159 -0.073816  0.071831 -0.001028
# 11  0.057020 -0.002856  0.007553 -0.015107  0.005828  0.022355 -0.062945
# 12 -0.092467 -0.024293  0.067986 -0.008053  0.026040  0.028179 -0.033334
# 13 -0.017615 -0.039899  0.006953  0.051261 -0.026534  0.056343 -0.005973
# 14 -0.050144 -0.003360  0.002350  0.028182 -0.059979  0.086755  0.000729
# 15  0.020870  0.050776  0.018891  0.049463 -0.004190 -0.001437  0.017922
# 16 -0.007388 -0.030433 -0.056854 -0.076393 -0.030583  0.001688 -0.054046
# 17 -0.004941  0.051083  0.041202  0.030987 -0.027127 -0.035399 -0.011648
# 18 -0.005571  0.003411  0.012607  0.041955 -0.042823  0.025836 -0.104433
# 19 -0.023312  0.047551 -0.008561 -0.013506 -0.012502 -0.024915 -0.012888
# 20  0.030424 -0.006466  0.031541 -0.082636 -0.044625 -0.003634 -0.049393
# 21  0.013163  0.019554 -0.000938  0.035965 -0.091111 -0.011647 -0.006818
# 22  0.006899 -0.033959 -0.041427 -0.058040 -0.009656 -0.017242  0.051217
# 23 -0.018202  0.019057 -0.020114  0.032801  0.004055  0.092163 -0.011317
# 24 -0.024698 -0.060467 -0.003536  0.018450  0.015358 -0.019746 -0.014502
# 25 -0.051262  0.005752 -0.006694 -0.075153  0.056098  0.049799 -0.024957
# 26  0.002344  0.030561 -0.006059  0.017199 -0.020128  0.021040 -0.050056
# 27 -0.017584  0.006519 -0.053878  0.024671  0.002735  0.030383 -0.000381
# 28 -0.076511 -0.004724 -0.042818  0.014471 -0.073333 -0.004027 -0.026483
# 29 -0.024369 -0.047125 -0.024028 -0.015545 -0.077495 -0.010369 -0.011654
# 30  0.046211  0.020042 -0.003610 -0.059831 -0.030172 -0.032296 -0.043024
# 31 -0.002713  0.035885 -0.037739 -0.029910  0.008833  0.031897  0.085592
# 32 -0.033821  0.056497 -0.044288 -0.049061  0.013557  0.025797 -0.043374
# 33  0.043035  0.084965 -0.042510 -0.001562 -0.024106  0.027377 -0.039892
# 34 -0.075169  0.017810 -0.007079 -0.030105 -0.030106 -0.012613  0.044764
# 35 -0.008246 -0.011874  0.012602  0.000784  0.030958  0.024287  0.040695
# 36 -0.021355 -0.002192  0.050614  0.024496  0.002949  0.030358 -0.024248
# 37 -0.004221 -0.059732 -0.020617 -0.055116 -0.073163  0.003831 -0.023686
# 38 -0.069824 -0.038246  0.027663 -0.006397 -0.052509 -0.009944 -0.041091
# 39  0.014586 -0.054364 -0.033677 -0.023807  0.041000 -0.003615  0.012387
# 40 -0.057076 -0.035539 -0.002518 -0.027822 -0.006096 -0.019047 -0.014832
# 41 -0.014542  0.025398 -0.011716  0.039646 -0.038670 -0.024011 -0.087535
# 42  0.052558  0.010975  0.001836  0.003165 -0.072657  0.015811 -0.005345
# 43  0.034407 -0.004001  0.010226 -0.025755 -0.047826 -0.006580 -0.031371
# 44 -0.075536 -0.011074 -0.005185 -0.006234  0.015278 -0.017125 -0.019820
# 45 -0.008088 -0.030166 -0.020769 -0.045894 -0.046195  0.034239 -0.007930
# 46 -0.042215 -0.042851  0.020161 -0.051677 -0.019105  0.019753  0.026695
# 47 -0.027200  0.029439  0.023275 -0.054426  0.082790 -0.052252  0.006406
# 48 -0.013473 -0.014623 -0.103360 -0.054719 -0.038590 -0.011878  0.028124
# 49 -0.005756  0.011221 -0.038435  0.042201 -0.071311 -0.021715 -0.048889
# 50  0.031307 -0.004836  0.025556  0.003552 -0.035573 -0.018262 -0.106350
#
#          7         8         9    ...       490       491       492       493  \
# 0        NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 1   0.035481 -0.009142  0.014145  ... -0.051391 -0.027857 -0.002249 -0.035645
# 2  -0.013003 -0.013060 -0.051382  ...  0.032538 -0.049692 -0.020880 -0.007550
# 3   0.000720 -0.046157 -0.023963  ... -0.055237  0.022664 -0.024515 -0.065607
# 4   0.035646 -0.040416  0.024045  ...  0.003056 -0.033759  0.040488 -0.034178
# 5   0.011658 -0.090978  0.026975  ... -0.074931 -0.000653 -0.016229 -0.018769
# 6  -0.059098 -0.002284 -0.038667  ...  0.010164 -0.028801 -0.039344 -0.024536
# 7   0.003929  0.003939  0.060605  ... -0.024044 -0.030719  0.007399 -0.005760
# 8   0.016498 -0.015302 -0.006005  ... -0.064180  0.011147 -0.007739 -0.024879
# 9  -0.059049 -0.035501  0.006416  ... -0.045215 -0.088280  0.003592  0.049686
# 10  0.028383  0.053542 -0.021337  ... -0.001903 -0.084359 -0.004765  0.055003
# 11  0.026916  0.017278  0.022803  ... -0.001434 -0.033468  0.012733 -0.064280
# 12 -0.010579 -0.013511  0.015353  ...  0.052445  0.036381  0.000729 -0.018604
# 13 -0.047895 -0.026216  0.064174  ... -0.054545  0.046218  0.034994  0.000696
# 14  0.036338  0.057001  0.006179  ...  0.006745 -0.015829 -0.014361 -0.003274
# 15 -0.022198  0.011428 -0.054854  ... -0.053716  0.055538  0.009824  0.015837
# 16  0.052847 -0.035512 -0.014655  ...  0.038457 -0.020985  0.001538  0.001720
# 17 -0.025071  0.060039  0.008478  ...  0.015892  0.023987  0.013072 -0.084425
# 18  0.000289 -0.022850 -0.060835  ... -0.031693  0.027863 -0.025654 -0.004685
# 19 -0.021866  0.041956 -0.012773  ...  0.028944 -0.038950 -0.043196 -0.034715
# 20 -0.012488 -0.016383 -0.026547  ... -0.021065  0.023816 -0.033389 -0.009869
# 21 -0.039845 -0.043062  0.027394  ... -0.008021 -0.050818  0.056954  0.004404
# 22  0.020446 -0.033881  0.089635  ...  0.049120 -0.009796 -0.018804  0.004047
# 23  0.041958 -0.046915  0.003271  ... -0.011657  0.032311  0.030910 -0.017099
# 24 -0.016376  0.008630 -0.011081  ... -0.031938  0.006036  0.025810 -0.009244
# 25  0.011021  0.036633  0.032027  ...  0.033479 -0.030403  0.008060  0.015560
# 26 -0.020936  0.010719  0.066266  ...  0.001541  0.012779  0.050496  0.015778
# 27  0.008067  0.038861  0.008154  ... -0.046751  0.020280 -0.002875  0.011335
# 28  0.020487 -0.007611  0.024936  ... -0.055394  0.016842 -0.009280 -0.011641
# 29 -0.023081 -0.019610 -0.065753  ... -0.024471  0.027578 -0.022872  0.030679
# 30  0.028180 -0.017358 -0.003525  ...  0.052705 -0.014228 -0.038309  0.031246
# 31 -0.038626 -0.038859 -0.021347  ... -0.018197 -0.007912  0.031506  0.008123
# 32 -0.031670  0.006400 -0.013985  ...  0.023954 -0.036595 -0.044509  0.006578
# 33 -0.016825  0.049245 -0.050416  ...  0.026500 -0.023536 -0.035957  0.002903
# 34  0.023996  0.054339 -0.016111  ... -0.047061 -0.049718 -0.045844 -0.026885
# 35 -0.032485 -0.011083 -0.055647  ... -0.025572  0.033064  0.026852 -0.003369
# 36 -0.016068  0.013777 -0.024754  ... -0.064489 -0.007742  0.004778  0.006369
# 37 -0.044929 -0.037645 -0.055264  ...  0.034102 -0.056630  0.056625 -0.016901
# 38 -0.043048 -0.037626  0.011113  ...  0.000145  0.039401 -0.007370 -0.013327
# 39 -0.011574 -0.020194 -0.033264  ... -0.054703  0.028736 -0.038994  0.079561
# 40  0.038617  0.000782 -0.012333  ...  0.043519 -0.023969 -0.029711 -0.013877
# 41 -0.029422  0.016148  0.016701  ... -0.038531 -0.005464  0.037384  0.020777
# 42 -0.010096 -0.034690  0.004060  ... -0.079568  0.042845 -0.010851 -0.032104
# 43  0.087031 -0.003261 -0.071694  ... -0.018633 -0.019954  0.013567  0.005732
# 44 -0.013253 -0.024967 -0.024921  ...  0.024571 -0.030923 -0.055009  0.009694
# 45  0.005937 -0.028017 -0.014012  ...  0.045770  0.029718  0.041508  0.035265
# 46  0.002954  0.007636  0.064145  ... -0.040954 -0.058131 -0.003393  0.013650
# 47 -0.006246  0.041667 -0.014298  ...  0.052266  0.041794  0.025010 -0.036867
# 48  0.024306  0.004629 -0.005300  ... -0.032440 -0.026402 -0.040521  0.037181
# 49 -0.060257  0.026912  0.001644  ...  0.015626 -0.051616 -0.061996 -0.003420
# 50 -0.029514 -0.001026  0.008448  ... -0.007466 -0.070216 -0.006087 -0.018234
#
#          494       495       496       497       498       499
# 0        NaN       NaN       NaN       NaN       NaN       NaN
# 1  -0.017174 -0.033546  0.041462  0.007261 -0.014384 -0.001990
# 2  -0.072040 -0.016316 -0.003395  0.001291 -0.037439 -0.003224
# 3   0.006371 -0.007686 -0.010217 -0.086665 -0.033939 -0.057237
# 4   0.035994  0.005120 -0.006504 -0.090662 -0.040270  0.021775
# 5  -0.027603  0.015556  0.070237  0.008617 -0.008400 -0.028143
# 6   0.065411 -0.035609 -0.041350  0.020707 -0.004443  0.006642
# 7   0.020608  0.006433 -0.135023 -0.005077  0.007199  0.085341
# 8   0.020314 -0.000110 -0.022131 -0.000893  0.001459 -0.060679
# 9  -0.033908 -0.095896  0.037111 -0.019503 -0.013385 -0.039485
# 10 -0.042989 -0.000745 -0.023890  0.009902  0.039101  0.057238
# 11  0.000626 -0.088164  0.084119 -0.030419 -0.021745 -0.067455
# 12 -0.001899  0.009301 -0.024179  0.002966 -0.032566 -0.044126
# 13 -0.030180 -0.000590  0.000268 -0.016493 -0.041532 -0.097391
# 14  0.004229 -0.060675  0.006395  0.032484 -0.032854 -0.008142
# 15  0.020106 -0.081273 -0.027014 -0.017753  0.009037 -0.016300
# 16  0.016597 -0.025552  0.075369  0.010479 -0.024368 -0.025637
# 17 -0.011299  0.005608 -0.012866  0.019859  0.006385 -0.010509
# 18  0.017243  0.021518 -0.036850 -0.047478  0.021462  0.010558
# 19 -0.026790 -0.011672 -0.002049 -0.026024  0.000651 -0.007371
# 20 -0.036385 -0.003692 -0.077291 -0.014887 -0.044808  0.010214
# 21  0.040256  0.029601 -0.035345 -0.014825  0.027673 -0.003711
# 22 -0.009735 -0.067271 -0.020307  0.005731 -0.011325 -0.045028
# 23  0.026024  0.070315  0.002240 -0.009808  0.007345 -0.019024
# 24 -0.013512 -0.043140 -0.012747 -0.021300 -0.006053  0.016726
# 25 -0.028569  0.039996 -0.025508  0.077831 -0.013714  0.010463
# 26 -0.035918  0.019969  0.006219  0.045298  0.043951 -0.036235
# 27 -0.028927 -0.063301 -0.002559  0.005979 -0.014981  0.022217
# 28  0.022121 -0.039404  0.009773  0.012233  0.002928 -0.020208
# 29 -0.036689  0.060301 -0.019300  0.019332 -0.000030 -0.035308
# 30 -0.005099 -0.034276 -0.013873 -0.014590 -0.036899 -0.034122
# 31  0.033436 -0.052992 -0.107188  0.035434  0.069724  0.008852
# 32  0.023648 -0.018677 -0.004148 -0.022629 -0.062402 -0.087312
# 33 -0.028614 -0.007469  0.038513  0.003775 -0.043326 -0.031028
# 34  0.023832  0.069545  0.029253 -0.012939  0.015395  0.006710
# 35  0.011099  0.009641  0.054214 -0.018837  0.056390 -0.024839
# 36  0.049665 -0.005016 -0.011666 -0.000653 -0.036583  0.019515
# 37 -0.009694  0.071512 -0.051195 -0.017041 -0.027148  0.070695
# 38 -0.009441 -0.033529 -0.050375 -0.020190 -0.004444 -0.039956
# 39  0.006703  0.021708 -0.065417 -0.011024 -0.077773  0.043630
# 40  0.016277  0.020283 -0.045790  0.009474 -0.024118  0.011770
# 41 -0.015110 -0.037893  0.009437  0.000899 -0.035272  0.025172
# 42 -0.067513  0.047045  0.020924 -0.049022 -0.034475 -0.015437
# 43  0.014187 -0.020113  0.044428 -0.031480 -0.087100  0.029403
# 44 -0.024322  0.004970  0.052059  0.000136  0.010165  0.034491
# 45 -0.022883 -0.035505  0.008249  0.016695  0.006342  0.029060
# 46 -0.027588 -0.013589  0.025322 -0.056726  0.067858 -0.012435
# 47 -0.065492  0.001449 -0.057826  0.000152 -0.056367  0.042223
# 48  0.017113 -0.022654  0.011715 -0.011734  0.003175 -0.009844
# 49  0.062583 -0.003511 -0.017104 -0.067567 -0.007684 -0.004693
# 50 -0.077601 -0.050724  0.037170 -0.018492 -0.066159  0.000896
#
# [51 rows x 500 columns]

# %%
MC.get_risk(15000) #Shows the risk evaluation on top of the number of simulations defined in the parentheses.
# Out:
# Risk for this option is 44.96 %.

# %%
MC.get_stats() #Shows the statistics of the executed Monte Carlo simulation.
# Out:
# Number of simulations:  50
# Number of iterations:  500
# Mean value:  25.81
# Standard deviation:  6.83
# Maximum:  56.01
# Minimum:  12.56

# %%
MC.hist(graph_title='GitHub Repository Demo', x_title = 'Time period', y_title = 'Value') #Histogram of values.
# Out:
# Histogram plotting initiated...
# CHOSEN METHOD: Basic histogram model.
# Histogram plotting finished.

# %%
MC.hist(x_title = 'Time period', y_title = 'Value', method = 'e') #Histogram with Empirical rule applied, BEWARE: this option is currently being worked on so do not use it in any research!!!
# Out:
# Histogram plotting initiated...
# CHOSEN METHOD: Empirical rule.
# Histogram plotting finished.

# %%
print(MC) #Explains the object.
# Out:
# Monte Carlo defining object that stores the configuration data for creating 500 simulations in a period of 50 time measurement units.

# %%
print(repr(MC)) #Explains the representation of the object.
# Out:
# Monte Carlo defining object that stores the configuration data for creating 500 simulations in a period of 50 time measurement units.

# %%
vandal.__license__ #Shows the license.
# Out:
# 'Copyright © 2021- David Kundih. All rights reserved. Licensed under the Apache License, Version 2.0 | For more details about the license and terms of use visit the official vandal documentation linked at https://github.com/dkundih/vandal and https://pypi.org/project/vandal'

# %%
vandal.__contact__ #Shows the contact information.
# Out:
# 'dakundih@unin.hr | kundihdavid@gmail.com'

# %%
vandal.__documentation__ #Shows the documentation details.
# Out:
# 'https://github.com/dkundih/vandal | https://pypi.org/project/vandal'

# %%
vandal.__donate__ #Shows the donation options.
# Out:
# 'https://patreon.com/dkundih | https://buymeacoffee.com/dkundih'

# %%
vandal.__credits__ #Shows credits.
# Out:
# ['dkundih <https://github.com/dkundih>']

# %%
vandal.__author__ #Shows the author.
# Out:
# 'David Kundih'

# %%
vandal.__copyright__ #Shows the copyright information.
# Out:
# 'Copyright © 2021- David Kundih'

# %%
help(vandal) #Help on library options and possibilities.
# Out:
# Help on package vandal:
#
# NAME
#     vandal
#
# DESCRIPTION
#     vandal - Data science, Data manipulation and Machine learning library.
#     =====================================================================
#
#     This is a connection to the __init__ file of the vandal library.
#
#     AVAILABLE FEATURES IN THE LIBRARY:
#
#             TOOLKIT (MODULE FUNCTIONS)
#             --------------------------
#
#             set of available data manipulation functions from the vandal library.
#                     print(help(any_function_listed_below)) in order to see the function details or print(help(vandal.toolkit)) for all functions at once.
#
#                     FUNCTIONS (ACCESSIBLE DIRECTLY FROM THE LIBRARY)
#                     ------------------------------------------------
#
#                     random_value(mean, st_dev, **rounded) - gives a random value of mean and standard deviation inputed, if rounded = 'y', value will be rounded.
#
#                     random_pool(mean, st_dev, pool_size, **rounded) - gives random values of mean and standard deviation inputed for the amount of values defined in the pool size, if rounded = 'y', values will be rounded.
#
#                     split_values(data, split_method) - splits the data using a split method character.
#
#                     join_values(data, join_method) - joins the data using a join metod character.
#
#                     replace_values(data, replaced_value, replacing_value) - replaces a defined value with a desired value.
#
#                     list_sort(data, array) - manually sorts data depending on defined array of indexes.
#
#                     index_sort(data, split_method, index_array) - sorts the indicies in a list of values based on the index array defined as [x,x,x].
#
#                     auto_sort(data, split_method, trigger = lambda x: x[0]) - automatically splits all values in a list and sorts them based on the added trigger as lambda x: [x[i], x[i]] and joins them back together.
#
#             MONTECARLO (OBJECT)
#             -------------------
#
#             vandal.MonteCarlo is a module for performing the Monte Carlo simulation over the defined data with a lot of useful features.
#                     print(help(vandal.MonteCarlo)) in order to see available features.
#
#             EOQ (OBJECT)
#             ------------
#
#             vandal.EOQ is a module for finding an Economic order quantity over the defined data with a lot of useful features.
#                     print(help(vandal.EOQ)) in order to see available features.
#
#             Dijkstra (OBJECT)
#             -----------------
#
#             vandal.Dijkstra is a module for finding the optimal route between the defined nodes from the place of origin to the final destination.
#                     print(help(vandal.Dijkstra)) in order to see available features.
#
#             CLI (EXECUTABLE FUNCTION)
#             -------------------------
#
#             vandal.CLI is an executable function that runs the Command Line Inerface of the vandal package.
#                     print(help(vandal.CLI)) in order to see available features.
#
# PACKAGE CONTENTS
#     hub (package)
#     misc (package)
#     objects (package)
#
# SUBMODULES
#     toolkit
#
# DATA
#     __all__ = [<function random_value>, <function random_pool>, <function ...
#     __contact__ = 'dakundih@unin.hr | kundihdavid@gmail.com'
#     __copyright__ = 'Copyright © 2021- David Kundih'
#     __documentation__ = 'https://github.com/dkundih/vandal | https://pypi....
#     __donate__ = 'https://patreon.com/dkundih | https://buymeacoffee.com/d...
#     __license__ = 'Copyright © 2021- David Kundih. All rights reser...kund...
#
# VERSION
#     3.0.1
#
# AUTHOR
#     David Kundih
#
# CREDITS
#     ['dkundih <https://github.com/dkundih>']
#
# FILE
#     c:\users\kundi\appdata\local\programs\python\python39\lib\site-packages\vandal\__init__.py

# %%
help(vandal.MonteCarlo) #Help on object options and possibilities.
# Out:
# Help on class MonteCarlo in module vandal.objects.montecarlo:
#
# class MonteCarlo(builtins.object)
#  |  (OBJECT INFO)
#  |  -------------
#  |
#  |  vandal.MonteCarlo - main class.
#  |
#  |  (OBJECT FUNCTIONS)
#  |  ------------------
#  |
#  |  eg. vandal.MonteCarlo.function()
#  |
#  |      .execute() - executes a Monte Carlo simulation on a defined data set.
#  |          * takes 4 additional arguments.
#  |          list_of_values - pandas dataframe of values.
#  |          time_seq - desired time sequence.
#  |          num_sims - desired number of simulation iterations.
#  |          ref_value_index (default: ref_value_index = 0) - index on which the starting point of the simulation is created.
#  |      * Requirements:
#  |          pandas Python module.
#  |          pd.DataFrame() defined data set.
#  |
#  |      .graph() - plots the Monte Carlo simulation on a graph.
#  |          * takes 5 optional customization arguments. (default: graph_title = 'Monte Carlo simulation', x_title = 'X axis', y_title = 'Y axis', plot_size = (25,10), perform_block = True).
#  |              graph_title - title of the graph.
#  |              x_title - title of the X axis.
#  |              y_title - title on the Y axis.
#  |              plot_size - desired size of the graph. eg. - (x_lenght_num, y_lenght_num). - NOTE: values must be inside the parentheses and divided by a comma.
#  |              perform_block (default: perform_block = True) - False/True may be used depending on the IDE requirements.
#  |
#  |      .get_risk() - calculates the risk of value decrease over time.
#  |          * takes 1 optional argument (default: risk_sims = 5000).
#  |
#  |      .get_stats() - shows the statistics of the Monte Carlo simulation.
#  |          * takes no additional arguments.
#  |
#  |      .get_change() - shows the percentage of Monte Carlo simulation value change for every iteration.
#  |          * takes no additional arguments.
#  |
#  |      .hist() - plots the histogram of Monte Carlo simulation.
#  |          * takes 6 optional customization arguments. (default: graph_title = 'Monte Carlo simulation', x_title = 'X axis', y_title = 'Y axis', plot_size = (25,10), perform_block = True, method = 'b').
#  |          If method = 'e' is chosen, no customization arguments apply.
#  |              graph_title - title of the graph.
#  |              x_title - title of the X axis.
#  |              y_title - title on the Y axis.
#  |              plot_size - desired size of the graph. eg. - (x_lenght_num, y_lenght_num). - NOTE: values must be inside the parentheses and divided by a comma.
#  |              perform_block (default: perform_block = True) - False/True may be used depending on the IDE requirements.
#  |              method - default method is Basic histogram and it's performed by automation. In order to plot Empirical rule histogram add method = 'e' as the last argument. - NOTE: method of a histogram must be placed within quotation marks.
#  |          * automatically executes the .get_stats(filtered = True) function in order to get standard deviation for the Empirical rule plotting.
#  |
#  |  (DEVELOPER MODE)
#  |  ----------------
#  |
#  |  Developer mode functions can only be set up manually by removing the '#DEVELOPER MODE -' in the source code.
#  |
#  |      * takes no additional arguments.
#  |      * Requirements:
#  |          '# DEVELOPER MODE -' removed in the code.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  __str__(self)
#  |      Return str(self).
#  |
#  |  execute(self, list_of_values, time_seq, num_sims, ref_value_index=0)
#  |      # DEVELOPER MODE - @classLog('execute() - built in function.')
#  |      # executes a Monte Carlo simulation on a defined data set.
#  |
#  |  get_change(self)
#  |      # DEVELOPER MODE - @classLog('get_change()')
#  |      #shows the percentage of Monte Carlo simulation value change for every iteration.
#  |
#  |  get_risk(self, risk_sims=5000)
#  |      # DEVELOPER MODE - @classLog('get_risk()')
#  |      # calculates the risk of negative values occuring.
#  |
#  |  get_stats(self, filtered=False)
#  |      # DEVELOPER MODE - @classLog('get_stats()')
#  |      # shows the statistics of the Monte Carlo simulation.
#  |
#  |  graph(self, graph_title='Monte Carlo simulation', x_title='X axis', y_title='Y axis', plot_size=(25, 10), perform_block=True)
#  |      # DEVELOPER MODE - @classLog('graph()')
#  |      # plots the Monte Carlo simulation on a graph.
#  |
#  |  hist(self, graph_title='Histogram of value frequencies', x_title='X axis', y_title='Y axis', plot_size=(25, 10), perform_block=True, **method)
#  |      # DEVELOPER MODE - @classLog('hist()')
#  |      # plots the histogram of Monte Carlo simulation.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __contact__ = 'dakundih@unin.hr | kundihdavid@gmail.com'
#  |
#  |  __copyright__ = 'Copyright © 2021- David Kundih'
#  |
#  |  __documentation__ = 'https://github.com/dkundih/vandal | https://pypi....
#  |
#  |  __donate__ = 'https://patreon.com/dkundih | https://buymeacoffee.com/d...
#  |
#  |  __license__ = 'Copyright © 2021- David Kundih. All rights reser...kund...

# %%
help(vandal.MonteCarlo.graph) #Help on function options and possibilities.
# Out:
# Help on function graph in module vandal.objects.montecarlo:
#
# graph(self, graph_title='Monte Carlo simulation', x_title='X axis', y_title='Y axis', plot_size=(25, 10), perform_block=True)
#     # DEVELOPER MODE - @classLog('graph()')
#     # plots the Monte Carlo simulation on a graph.

# %%
vandal.__file__ #Shows the library path.
# Out:
# 'C:\\Users\\kundi\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\vandal\\__init__.py'

# %%
vandal.__all__ #Shows the imported objects and modules from the library in the main module.
# Out:
# [<function vandal.hub.toolkit.random_value(mean, st_dev, **rounded)>,
#  <function vandal.hub.toolkit.random_pool(mean, st_dev, pool_size, **rounded)>,
#  <function vandal.hub.toolkit.split_values(data, split_method)>,
#  <function vandal.hub.toolkit.join_values(data, join_method)>,
#  <function vandal.hub.toolkit.replace_values(data, replaced_value, replacing_value)>,
#  <function vandal.hub.toolkit.list_sort(data, array)>,
#  <function vandal.hub.toolkit.index_sort(data, split_method, index_array)>,
#  <function vandal.hub.toolkit.auto_sort(data, split_method, trigger=<function <lambda> at 0x000002241BBA7790>)>,
#  <module 'vandal.hub.toolkit' from 'C:\\Users\\kundi\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\vandal\\hub\\toolkit.py'>,
#  vandal.objects.montecarlo.MonteCarlo,
#  vandal.objects.eoq.EOQ,
#  vandal.objects.dijkstra.Dijkstra]

# %%
vandal.objects.__all__ #Shows the available objects from the objects module.
# Out:
# [vandal.objects.montecarlo.MonteCarlo,
#  vandal.objects.eoq.EOQ,
#  vandal.objects.dijkstra.Dijkstra]

# %%
vandal.misc.__all__ #Shows the meta data from the misc module.
# Out:
# ['David Kundih',
#  'Copyright © 2021- David Kundih',
#  ['dkundih <https://github.com/dkundih>'],
#  'Copyright © 2021- David Kundih. All rights reserved. Licensed under the Apache License, Version 2.0 | For more details about the license and terms of use visit the official vandal documentation linked at https://github.com/dkundih/vandal and https://pypi.org/project/vandal',
#  '3.0.1',
#  'https://github.com/dkundih/vandal | https://pypi.org/project/vandal',
#  'dakundih@unin.hr | kundihdavid@gmail.com',
#  'https://patreon.com/dkundih | https://buymeacoffee.com/dkundih']
