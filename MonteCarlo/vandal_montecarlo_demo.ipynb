# %% [markdown]
# vandal.MonteCarlo demonstration

# %%
import vandal # vandal 3.6.6 was used in this example.
import pandas as pd # importing pandas to create a DataFrame.

# %%
vandal.__version__ # version used.
# Out:
# '3.6.6'

# %%
MC = vandal.MonteCarlo({
    'Example_data' : [38,37,38,36,36,35,36,34,33,34,35], # example list of values. (ref_col = 0)
    'Example_data2' : [142, 149, 153, 154, 150, 149, 149, 151, 152, 150, 146], # example list of values. (ref_col = 1)
    },
50, 
300, 
ref_col= 1,
ref_row = 6,
) # object defined as MC.

# %%
MC.execute(filtered=False) # executes the Monte Carlo simulation.
# Out:
# Monte Carlo has been set up for 300 simulations in a period of 50 time measurement units and executed.
# NOTE: Use data with reasonable standard deviation in order to prevent exponential growth of the function that cannot be plotted properly, recognize such abnormal values by a + sign anywhere in the data executed below.
# Monte Carlo simulation set up and ready to plot.
#            0           1           2           3           4           5    \
# 0   147.012252  151.618585  145.292737  151.157299  145.935683  149.935847
# 1   149.169024  156.235802  148.321703  151.646959  147.926750  147.833745
# 2   147.441334  158.032566  144.634606  147.411983  147.345288  143.860798
# 3   147.521775  159.213797  142.860559  144.262436  145.520487  141.760422
# 4   143.659973  163.907100  145.875792  143.609431  149.399628  145.698598
# 5   144.353197  168.759636  148.668133  144.731471  150.835827  149.935128
# 6   140.828407  174.450254  154.961905  146.280035  153.493175  152.125082
# 7   144.565441  173.614507  151.337715  144.544351  154.688060  156.259965
# 8   151.881323  182.871013  148.060474  142.623719  158.148298  152.231527
# 9   153.377054  181.289763  143.762474  142.013346  155.083171  154.587342
# 10  157.759318  181.905369  144.699730  139.983923  151.116693  151.706580
# 11  152.589395  180.514678  142.978916  145.564909  156.446109  150.834492
# 12  151.765445  179.608915  139.006188  140.603694  153.843203  152.986006
# 13  147.829009  185.439882  134.593428  144.008888  150.740542  151.065283
# 14  141.574146  177.051265  134.101908  144.804661  149.581386  145.479447
# 15  136.333317  178.679333  136.519041  144.413208  151.258758  145.603647
# 16  133.719899  180.963041  131.466036  143.563074  147.793704  140.513202
# 17  134.504123  178.166218  131.366824  147.414070  147.797011  142.861842
# 18  134.928333  181.512286  134.633070  138.418304  148.714627  143.200903
# 19  134.115316  187.694353  133.075342  142.838510  148.327543  140.980602
# 20  129.721630  187.718371  141.098768  137.340062  147.795177  145.457978
# 21  130.153105  186.267773  135.573747  143.939187  146.821153  140.650682
# 22  128.869669  186.699228  133.737569  142.259230  152.298703  144.104240
# 23  127.475334  189.846142  137.774453  138.149388  147.779371  145.807716
# 24  126.746844  184.663496  138.701623  135.546044  143.752021  148.144248
# 25  121.731971  182.081531  136.333465  134.412935  145.193889  150.417791
# 26  122.936885  178.293903  130.070212  132.328096  141.043528  149.813860
# 27  117.648592  180.566220  131.833018  134.519392  139.585093  149.732698
# 28  115.909625  180.234994  130.950659  136.628906  138.650061  151.880896
# 29  117.764446  174.698283  132.172595  135.305018  141.457336  152.375336
# 30  116.050009  179.071381  134.472670  134.370506  145.231050  154.406056
# 31  114.409196  173.901734  139.576052  140.639493  145.862563  155.202205
# 32  116.307491  169.083210  141.738015  149.682637  149.255159  154.006587
# 33  111.748596  172.330869  145.548918  150.730531  151.481196  151.815177
# 34  111.466742  174.723926  147.551093  150.375524  161.221785  148.289528
# 35  117.938153  177.129900  146.365801  147.571471  158.798350  145.007591
# 36  119.537130  177.118242  145.645230  153.167180  162.893312  141.073510
# 37  118.688916  169.687567  143.398341  154.003668  170.279283  138.889580
# 38  121.980859  175.061656  140.488131  157.583922  174.802441  140.767036
# 39  122.638052  175.766952  146.217626  154.943662  171.920444  136.436251
# 40  116.979100  174.902984  143.125985  152.307749  174.325120  140.636411
# 41  119.679013  178.806586  144.887392  148.204855  173.923176  144.283036
# 42  118.932212  182.584703  144.332091  146.307786  175.184275  144.261721
# 43  121.060936  184.220488  140.331270  147.604236  183.500482  149.746307
# 44  120.963967  186.541759  136.678568  145.820883  182.621041  146.230576
# 45  122.989967  182.966457  135.700865  145.178567  181.370466  145.950908
# 46  117.780494  189.462790  136.427943  149.055367  181.785709  148.292100
# 47  116.506983  190.350333  137.078052  147.689692  187.733341  145.087250
# 48  110.955377  189.036282  134.915306  150.771866  195.775113  144.937457
# 49  106.266974  186.925973  138.329881  148.356998  193.874146  146.923272
# 50  105.292217  190.257128  138.120858  148.722222  195.944871  144.311999
#
#            6           7           8           9    ...         290  \
# 0   147.490639  146.544607  150.142679  147.309115  ...  155.464482
# 1   144.772254  147.643070  150.686080  151.115590  ...  153.442958
# 2   144.486758  151.977008  147.016813  152.368482  ...  154.724347
# 3   145.125700  154.402582  149.713650  150.644636  ...  160.191592
# 4   141.469233  151.207885  150.245115  150.088660  ...  159.964431
# 5   135.291981  149.741716  149.469707  153.641937  ...  163.402216
# 6   141.383815  147.347236  150.261717  156.364751  ...  161.317963
# 7   140.749318  146.033432  149.965216  158.251007  ...  164.408030
# 8   145.995615  145.144427  150.951183  161.834032  ...  162.186564
# 9   146.588983  144.133579  151.838970  151.035822  ...  156.331016
# 10  133.870911  149.445409  154.557511  148.529839  ...  152.684577
# 11  137.831579  148.399319  155.267531  151.126758  ...  154.851266
# 12  141.486099  142.622008  156.058393  154.254328  ...  160.349390
# 13  144.214686  144.136100  155.415965  151.188194  ...  160.167489
# 14  141.003235  144.798535  153.505526  152.149964  ...  167.368494
# 15  149.597796  143.561623  153.875341  157.714980  ...  162.837066
# 16  154.173508  148.914007  160.015003  155.465509  ...  165.110407
# 17  155.237887  145.995059  164.348841  151.752158  ...  161.022660
# 18  160.217325  146.094191  165.009011  157.554803  ...  156.269075
# 19  154.962130  141.520279  168.191411  154.647151  ...  152.801505
# 20  156.265768  146.818512  167.493351  154.593377  ...  154.166147
# 21  151.679939  135.951632  175.823468  155.097937  ...  155.174413
# 22  150.973148  131.463303  176.828926  149.686538  ...  152.632656
# 23  150.987762  128.215416  172.215373  152.420170  ...  153.738737
# 24  149.553703  129.854857  171.458512  154.646054  ...  152.408038
# 25  146.397547  129.706943  167.763484  163.167190  ...  157.747534
# 26  142.156567  136.637956  167.377743  161.150484  ...  159.650520
# 27  143.107205  130.703207  166.267133  162.041296  ...  157.080706
# 28  145.330768  134.009707  159.333829  164.872839  ...  152.561752
# 29  147.851129  133.623788  159.726802  153.824417  ...  153.076379
# 30  140.303567  131.925186  160.575629  151.643705  ...  152.125804
# 31  139.502536  133.078422  160.512136  152.134845  ...  153.325398
# 32  138.300303  131.734067  164.636630  153.712087  ...  157.619507
# 33  135.973574  128.623162  165.684622  152.302136  ...  160.784819
# 34  138.468107  130.394946  164.480904  151.882947  ...  168.045814
# 35  142.027764  128.292087  164.446930  146.652757  ...  163.996690
# 36  143.747531  124.705435  162.434052  144.004452  ...  153.976435
# 37  146.197535  127.231794  156.417897  146.680549  ...  149.250058
# 38  145.449324  129.705179  159.057942  147.919753  ...  151.661472
# 39  141.224367  129.938368  155.800633  151.715595  ...  149.955102
# 40  139.307713  136.195414  154.527248  152.570521  ...  143.186113
# 41  136.095603  133.172120  159.344924  154.457988  ...  148.030286
# 42  135.471302  130.641894  160.317586  150.898391  ...  149.427429
# 43  140.713236  134.155565  157.893120  150.831468  ...  145.612153
# 44  146.798149  127.843294  157.598988  151.880521  ...  141.058608
# 45  150.989439  132.958079  158.329023  151.068723  ...  142.774768
# 46  156.472136  128.448284  161.313001  156.436834  ...  139.033153
# 47  150.634742  129.709617  160.611345  157.567611  ...  147.345154
# 48  147.164228  122.587000  160.953170  158.333361  ...  153.457175
# 49  149.282235  120.593260  165.158945  160.030949  ...  162.034625
# 50  152.185580  122.520565  161.337465  159.523624  ...  155.582458
#
#            291         292         293         294         295         296  \
# 0   152.971226  151.377473  147.265099  143.400443  144.402269  150.712754
# 1   153.916362  145.964608  146.761422  142.296681  147.155128  145.399099
# 2   159.323722  147.953753  145.909113  141.491651  149.450123  145.333126
# 3   156.834105  150.322982  143.696781  136.963020  149.888495  149.175427
# 4   161.873648  152.616763  139.879572  139.753294  151.491524  154.010243
# 5   164.781217  157.970072  143.259655  140.140966  151.810246  153.203107
# 6   163.335345  161.660856  145.653503  140.641582  154.124125  155.990745
# 7   162.920476  158.714909  146.706106  137.431615  156.405806  155.517551
# 8   166.396647  158.564853  153.391444  135.536772  153.717737  156.672267
# 9   154.977267  163.030584  152.553195  130.946535  157.828364  158.232124
# 10  158.615754  166.750413  150.454359  132.323047  152.716577  161.380043
# 11  153.090878  167.693235  159.330779  133.908219  149.931962  160.871946
# 12  156.140179  161.120616  160.363781  138.690116  149.793488  164.086302
# 13  156.704089  163.665823  157.139189  141.267943  143.764752  160.442570
# 14  161.431575  161.887185  159.856425  140.313810  145.155186  160.795422
# 15  159.521217  163.165552  160.218517  140.370534  144.646467  162.407682
# 16  161.863780  167.821624  165.219492  140.034133  148.809555  165.115032
# 17  159.161012  169.579725  171.044938  132.551215  153.157093  163.644787
# 18  158.860103  180.754835  172.154453  136.976599  156.180292  159.325482
# 19  158.441589  180.068737  178.027156  137.210211  153.397831  166.021076
# 20  158.849791  175.824640  175.022052  139.924168  152.393937  161.613684
# 21  162.473396  172.689164  172.383663  141.822189  150.509916  161.281977
# 22  165.997576  178.282870  174.275294  137.142784  144.475040  168.616985
# 23  165.442492  174.569207  170.228745  140.788836  143.909443  165.976066
# 24  171.219211  172.817568  171.069748  137.200476  149.576020  170.064640
# 25  181.597412  167.732824  173.000095  141.473321  145.847594  176.680911
# 26  181.554889  171.156921  169.787396  139.290683  144.583818  180.264043
# 27  178.583951  165.712197  167.244036  138.801863  139.386710  179.686005
# 28  187.185467  167.044245  170.927029  142.556347  145.387687  184.042976
# 29  185.926046  167.564136  173.456293  141.973815  144.373314  191.202756
# 30  183.121640  168.301455  170.085364  137.407366  144.113089  182.660687
# 31  182.086286  169.167113  172.330452  134.513151  143.077519  186.610538
# 32  182.208133  160.940800  163.103139  135.207504  142.288651  191.429621
# 33  185.521020  159.459542  166.288383  132.869451  140.855937  193.664940
# 34  190.497678  161.455136  166.932960  129.378901  138.075170  181.882189
# 35  191.188086  157.976703  171.308289  132.409027  141.553877  175.699223
# 36  183.412927  156.223112  172.779960  130.923954  141.260712  175.964968
# 37  189.383424  156.779389  172.121217  130.379320  138.618212  181.133521
# 38  194.229053  160.064336  169.067313  132.261260  137.629088  187.316022
# 39  196.536287  163.220678  162.624799  137.641062  129.056869  189.136627
# 40  195.643251  160.242559  163.784965  142.148162  129.096409  182.618294
# 41  183.591311  162.665856  169.048636  151.443136  124.107877  178.875396
# 42  186.312411  159.956783  166.916890  152.866393  120.604753  179.528023
# 43  188.484700  162.572148  167.279065  150.479788  123.666057  181.800001
# 44  196.207105  157.825622  166.201682  153.650412  124.933744  180.398470
# 45  200.544193  161.697340  168.993565  152.141023  126.251944  183.717421
# 46  196.175891  164.783739  175.838083  151.308094  130.224249  186.824930
# 47  200.644452  164.042305  175.196226  154.344401  126.122436  187.999702
# 48  197.313167  158.168720  180.745532  158.859500  127.752708  184.186305
# 49  205.136024  160.016105  179.450729  156.737940  131.892193  183.589211
# 50  203.721271  162.435079  183.393392  164.318584  132.346876  184.807088
#
#            297         298         299
# 0   156.103069  147.957996  150.961995
# 1   156.308721  147.114103  153.406707
# 2   154.971791  147.708906  150.473226
# 3   154.085341  151.000231  145.783665
# 4   154.986685  150.838546  140.632430
# 5   156.562880  159.241454  144.209045
# 6   152.200551  158.299156  149.353782
# 7   154.441144  162.994605  150.390841
# 8   159.492825  162.965933  149.125658
# 9   165.581797  161.892994  152.268478
# 10  167.121951  158.455107  153.456894
# 11  172.153332  157.195736  156.664357
# 12  180.134694  160.420244  158.131506
# 13  180.090191  157.215195  154.287239
# 14  183.585313  165.767389  160.390624
# 15  185.249236  167.696746  153.304510
# 16  179.055079  167.627093  152.800665
# 17  177.952821  166.790830  146.576428
# 18  173.563588  163.078327  147.535635
# 19  176.725202  168.057698  151.164591
# 20  177.067057  170.569185  155.935714
# 21  179.624469  174.262967  162.360251
# 22  179.128896  180.845714  160.942571
# 23  177.904905  180.358619  161.621646
# 24  177.930139  186.736181  158.453622
# 25  181.886676  190.602560  157.966200
# 26  179.047704  186.643151  162.048675
# 27  178.196097  193.597913  164.028903
# 28  174.473072  188.671010  166.303202
# 29  173.743879  190.708271  171.679939
# 30  171.537737  192.772593  174.752171
# 31  174.707922  190.433264  172.616319
# 32  168.527738  194.769764  171.081536
# 33  167.640221  195.682509  170.319765
# 34  165.247864  200.768366  171.787685
# 35  172.911218  199.998134  169.252281
# 36  164.506993  197.677272  179.523553
# 37  163.671169  203.745660  178.619197
# 38  162.037545  204.117587  183.717182
# 39  162.122074  210.220187  180.133828
# 40  162.923268  215.383215  184.406131
# 41  167.291734  214.947640  182.697300
# 42  167.108905  208.453913  184.703967
# 43  167.354162  203.095788  185.666657
# 44  171.305160  201.160670  190.626606
# 45  176.750625  200.997729  188.696793
# 46  174.325271  194.432405  189.361060
# 47  162.928312  190.134199  197.602432
# 48  156.373481  193.246711  201.848983
# 49  154.053522  190.099171  202.270355
# 50  161.327655  184.463417  205.903291
#
# [51 rows x 300 columns]

# %%
MC.graph() # creates a graph of the executed Monte Carlo simulation.
# Out:
# MonteCarlo() plotting initialized.
# MonteCarlo() plotting finished.

# %%
MC.get_change() # returns the list of percentage changes throughout the executed simulation.
# Out:
#          0         1         2         3         4         5         6    \
# 0        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1   0.014671  0.030453  0.020847  0.003239  0.013643 -0.014020 -0.018431
# 2  -0.011582  0.011500 -0.024859 -0.027927 -0.003931 -0.026874 -0.001972
# 3   0.000546  0.007475 -0.012266 -0.021366 -0.012385 -0.014600  0.004422
# 4  -0.026178  0.029478  0.021106 -0.004527  0.026657  0.027781 -0.025195
# 5   0.004825  0.029605  0.019142  0.007813  0.009613  0.029077 -0.043665
# 6  -0.024418  0.033720  0.042334  0.010700  0.017617  0.014606  0.045027
# 7   0.026536 -0.004791 -0.023388 -0.011865  0.007785  0.027181 -0.004488
# 8   0.050606  0.053316 -0.021655 -0.013287  0.022369 -0.025780  0.037274
# 9   0.009848 -0.008647 -0.029029 -0.004280 -0.019381  0.015475  0.004064
# 10  0.028572  0.003396  0.006519 -0.014290 -0.025576 -0.018635 -0.086760
# 11 -0.032771 -0.007645 -0.011892  0.039869  0.035267 -0.005749  0.029586
# 12 -0.005400 -0.005018 -0.027785 -0.034082 -0.016638  0.014264  0.026514
# 13 -0.025938  0.032465 -0.031745  0.024218 -0.020168 -0.012555  0.019285
# 14 -0.042311 -0.045236 -0.003652  0.005526 -0.007690 -0.036976 -0.022269
# 15 -0.037018  0.009195  0.018025 -0.002703  0.011214  0.000854  0.060953
# 16 -0.019169  0.012781 -0.037013 -0.005887 -0.022908 -0.034961  0.030587
# 17  0.005865 -0.015455 -0.000755  0.026824  0.000022  0.016715  0.006904
# 18  0.003154  0.018781  0.024864 -0.061024  0.006209  0.002373  0.032076
# 19 -0.006026  0.034059 -0.011570  0.031934 -0.002603 -0.015505 -0.032800
# 20 -0.032761  0.000128  0.060292 -0.038494 -0.003589  0.031759  0.008413
# 21  0.003326 -0.007728 -0.039157  0.048050 -0.006590 -0.033049 -0.029346
# 22 -0.009861  0.002316 -0.013544 -0.011671  0.037308  0.024554 -0.004660
# 23 -0.010820  0.016856  0.030185 -0.028890 -0.029674  0.011821  0.000097
# 24 -0.005715 -0.027299  0.006730 -0.018844 -0.027252  0.016025 -0.009498
# 25 -0.039566 -0.013982 -0.017074 -0.008360  0.010030  0.015347 -0.021104
# 26  0.009898 -0.020802 -0.045941 -0.015511 -0.028585 -0.004015 -0.028969
# 27 -0.043016  0.012745  0.013553  0.016560 -0.010340 -0.000542  0.006687
# 28 -0.014781 -0.001834 -0.006693  0.015682 -0.006699  0.014347  0.015538
# 29  0.016002 -0.030719  0.009331 -0.009690  0.020247  0.003255  0.017342
# 30 -0.014558  0.025032  0.017402 -0.006907  0.026677  0.013327 -0.051048
# 31 -0.014139 -0.028869  0.037951  0.046654  0.004348  0.005156 -0.005709
# 32  0.016592 -0.027708  0.015490  0.064300  0.023259 -0.007704 -0.008618
# 33 -0.039197  0.019207  0.026887  0.007001  0.014914 -0.014229 -0.016824
# 34 -0.002522  0.013886  0.013756 -0.002355  0.064302 -0.023223  0.018346
# 35  0.058057  0.013770 -0.008033 -0.018647 -0.015032 -0.022132  0.025707
# 36  0.013558 -0.000066 -0.004923  0.037919  0.025787 -0.027130  0.012109
# 37 -0.007096 -0.041953 -0.015427  0.005461  0.045342 -0.015481  0.017044
# 38  0.027736  0.031670 -0.020295  0.023248  0.026563  0.013518 -0.005118
# 39  0.005388  0.004029  0.040783 -0.016755 -0.016487 -0.030766 -0.029048
# 40 -0.046144 -0.004915 -0.021144 -0.017012  0.013987  0.030785 -0.013572
# 41  0.023080  0.022319  0.012307 -0.026938 -0.002306  0.025929 -0.023058
# 42 -0.006240  0.021130 -0.003833 -0.012800  0.007251 -0.000148 -0.004587
# 43  0.017899  0.008959 -0.027720  0.008861  0.047471  0.038018  0.038694
# 44 -0.000801  0.012601 -0.026029 -0.012082 -0.004793 -0.023478  0.043243
# 45  0.016749 -0.019166 -0.007153 -0.004405 -0.006848 -0.001913  0.028551
# 46 -0.042357  0.035506  0.005358  0.026704  0.002289  0.016041  0.036312
# 47 -0.010813  0.004685  0.004765 -0.009162  0.032718 -0.021612 -0.037306
# 48 -0.047650 -0.006903 -0.015777  0.020869  0.042836 -0.001032 -0.023039
# 49 -0.042255 -0.011164  0.025309 -0.016017 -0.009710  0.013701  0.014392
# 50 -0.009173  0.017821 -0.001511  0.002462  0.010681 -0.017773  0.019449
#
#          7         8         9    ...       290       291       292       293  \
# 0        NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 1   0.007496  0.003619  0.025840  ... -0.013003  0.006179 -0.035757 -0.003420
# 2   0.029354 -0.024350  0.008291  ...  0.008351  0.035132  0.013628 -0.005807
# 3   0.015960  0.018344 -0.011314  ...  0.035335 -0.015626  0.016013 -0.015162
# 4  -0.020691  0.003550 -0.003691  ... -0.001418  0.032133  0.015259 -0.026564
# 5  -0.009696 -0.005161  0.023675  ...  0.021491  0.017962  0.035077  0.024164
# 6  -0.015991  0.005299  0.017722  ... -0.012755 -0.008774  0.023364  0.016710
# 7  -0.008916 -0.001973  0.012063  ...  0.019155 -0.002540 -0.018223  0.007227
# 8  -0.006088  0.006575  0.022641  ... -0.013512  0.021337 -0.000945  0.045570
# 9  -0.006964  0.005881 -0.066724  ... -0.036104 -0.068627  0.028163 -0.005465
# 10  0.036854  0.017904 -0.016592  ... -0.023325  0.023478  0.022817 -0.013758
# 11 -0.007000  0.004594  0.017484  ...  0.014191 -0.034832  0.005654  0.058997
# 12 -0.038931  0.005094  0.020695  ...  0.035506  0.019918 -0.039194  0.006483
# 13  0.010616 -0.004117 -0.019877  ... -0.001134  0.003612  0.015797 -0.020108
# 14  0.004596 -0.012292  0.006361  ...  0.044959  0.030168 -0.010867  0.017292
# 15 -0.008542  0.002409  0.036576  ... -0.027075 -0.011834  0.007897  0.002265
# 16  0.037283  0.039900 -0.014263  ...  0.013961  0.014685  0.028536  0.031213
# 17 -0.019602  0.027084 -0.023885  ... -0.024758 -0.016698  0.010476  0.035259
# 18  0.000679  0.004017  0.038238  ... -0.029521 -0.001891  0.065899  0.006487
# 19 -0.031308  0.019286 -0.018455  ... -0.022190 -0.002634 -0.003796  0.034113
# 20  0.037438 -0.004150 -0.000348  ...  0.008931  0.002576 -0.023569 -0.016880
# 21 -0.074016  0.049734  0.003264  ...  0.006540  0.022812 -0.017833 -0.015075
# 22 -0.033014  0.005719 -0.034890  ... -0.016380  0.021691  0.032392  0.010973
# 23 -0.024706 -0.026090  0.018262  ...  0.007247 -0.003344 -0.020830 -0.023219
# 24  0.012787 -0.004395  0.014604  ... -0.008656  0.034917 -0.010034  0.004940
# 25 -0.001139 -0.021551  0.055101  ...  0.035034  0.060614 -0.029423  0.011284
# 26  0.053436 -0.002299 -0.012360  ...  0.012063 -0.000234  0.020414 -0.018571
# 27 -0.043434 -0.006635  0.005528  ... -0.016096 -0.016364 -0.031811 -0.014980
# 28  0.025298 -0.041700  0.017474  ... -0.028768  0.048165  0.008038  0.022022
# 29 -0.002880  0.002466 -0.067012  ...  0.003373 -0.006728  0.003112  0.014797
# 30 -0.012712  0.005314 -0.014177  ... -0.006210 -0.015083  0.004400 -0.019434
# 31  0.008742 -0.000395  0.003239  ...  0.007886 -0.005654  0.005143  0.013200
# 32 -0.010102  0.025696  0.010367  ...  0.028007  0.000669 -0.048628 -0.053544
# 33 -0.023615  0.006365 -0.009173  ...  0.020082  0.018182 -0.009204  0.019529
# 34  0.013775 -0.007265 -0.002752  ...  0.045160  0.026825  0.012515  0.003876
# 35 -0.016127 -0.000207 -0.034436  ... -0.024095  0.003624 -0.021544  0.026210
# 36 -0.027957 -0.012240 -0.018058  ... -0.061100 -0.040668 -0.011100  0.008591
# 37  0.020259 -0.037038  0.018583  ... -0.030695  0.032552  0.003561 -0.003813
# 38  0.019440  0.016878  0.008448  ...  0.016157  0.025586  0.020953 -0.017743
# 39  0.001798 -0.020479  0.025661  ... -0.011251  0.011879  0.019719 -0.038106
# 40  0.048154 -0.008173  0.005635  ... -0.045140 -0.004544 -0.018246  0.007134
# 41 -0.022198  0.031177  0.012371  ...  0.033831 -0.061602  0.015123  0.032138
# 42 -0.019000  0.006104 -0.023046  ...  0.009438  0.014822 -0.016654 -0.012610
# 43  0.026895 -0.015123 -0.000444  ... -0.025533  0.011659  0.016350  0.002170
# 44 -0.047052 -0.001863  0.006955  ... -0.031272  0.040971 -0.029196 -0.006441
# 45  0.040008  0.004632 -0.005345  ...  0.012166  0.022105  0.024532  0.016798
# 46 -0.033919  0.018847  0.035534  ... -0.026206 -0.021782  0.019088  0.040502
# 47  0.009820 -0.004350  0.007228  ...  0.059784  0.022778 -0.004499 -0.003650
# 48 -0.054912  0.002128  0.004860  ...  0.041481 -0.016603 -0.035805  0.031675
# 49 -0.016264  0.026130  0.010722  ...  0.055895  0.039647  0.011680 -0.007164
# 50  0.015982 -0.023138 -0.003170  ... -0.039820 -0.006897  0.015117  0.021971
#
#          294       295       296       297       298       299
# 0        NaN       NaN       NaN       NaN       NaN       NaN
# 1  -0.007697  0.019064 -0.035257  0.001317 -0.005704  0.016194
# 2  -0.005657  0.015596 -0.000454 -0.008553  0.004043 -0.019122
# 3  -0.032006  0.002933  0.026438 -0.005720  0.022283 -0.031165
# 4   0.020372  0.010695  0.032410  0.005850 -0.001071 -0.035335
# 5   0.002774  0.002104 -0.005241  0.010170  0.055708  0.025432
# 6   0.003572  0.015242  0.018196 -0.027863 -0.005917  0.035676
# 7  -0.022824  0.014804 -0.003033  0.014721  0.029662  0.006944
# 8  -0.013788 -0.017187  0.007425  0.032709 -0.000176 -0.008413
# 9  -0.033867  0.026741  0.009956  0.038177 -0.006584  0.021075
# 10  0.010512 -0.032388  0.019894  0.009301 -0.021236  0.007805
# 11  0.011980 -0.018234 -0.003148  0.030106 -0.007948  0.020901
# 12  0.035710 -0.000924  0.019981  0.046362  0.020513  0.009365
# 13  0.018587 -0.040247 -0.022206 -0.000247 -0.019979 -0.024311
# 14 -0.006754  0.009672  0.002199  0.019408  0.054398  0.039559
# 15  0.000404 -0.003505  0.010027  0.009063  0.011639 -0.044180
# 16 -0.002397  0.028781  0.016670 -0.033437 -0.000415 -0.003287
# 17 -0.053436  0.029215 -0.008904 -0.006156 -0.004989 -0.040734
# 18  0.033386  0.019739 -0.026394 -0.024665 -0.022258  0.006544
# 19  0.001705 -0.017816  0.042025  0.018216  0.030534  0.024597
# 20  0.019780 -0.006544 -0.026547  0.001934  0.014944  0.031562
# 21  0.013565 -0.012363 -0.002052  0.014443  0.021656  0.041200
# 22 -0.032995 -0.040096  0.045479 -0.002759  0.037775 -0.008732
# 23  0.026586 -0.003915 -0.015662 -0.006833 -0.002693  0.004219
# 24 -0.025488  0.039376  0.024634  0.000142  0.035360 -0.019601
# 25  0.031143 -0.024927  0.038904  0.022236  0.020705 -0.003076
# 26 -0.015428 -0.008665  0.020280 -0.015608 -0.020773  0.025844
# 27 -0.003509 -0.035945 -0.003207 -0.004756  0.037262  0.012220
# 28  0.027049  0.043053  0.024248 -0.020893 -0.025449  0.013865
# 29 -0.004086 -0.006977  0.038903 -0.004179  0.010798  0.032331
# 30 -0.032164 -0.001802 -0.044675 -0.012698  0.010825  0.017895
# 31 -0.021063 -0.007186  0.021624  0.018481 -0.012135 -0.012222
# 32  0.005162 -0.005514  0.025824 -0.035374  0.022772 -0.008891
# 33 -0.017292 -0.010069  0.011677 -0.005266  0.004686 -0.004453
# 34 -0.026271 -0.019742 -0.060841 -0.014271  0.025990  0.008619
# 35  0.023421  0.025194 -0.033994  0.046375 -0.003836 -0.014759
# 36 -0.011216 -0.002071  0.001513 -0.048604 -0.011604  0.060686
# 37 -0.004160 -0.018707  0.029373 -0.005081  0.030698 -0.005038
# 38  0.014434 -0.007136  0.034132 -0.009981  0.001825  0.028541
# 39  0.040676 -0.062285  0.009719  0.000522  0.029897 -0.019505
# 40  0.032745  0.000306 -0.034464  0.004942  0.024560  0.023717
# 41  0.065389 -0.038642 -0.020496  0.026813 -0.002022 -0.009267
# 42  0.009398 -0.028226  0.003648 -0.001093 -0.030211  0.010984
# 43 -0.015612  0.025383  0.012655  0.001468 -0.025704  0.005212
# 44  0.021070  0.010251 -0.007709  0.023609 -0.009528  0.026714
# 45 -0.009824  0.010551  0.018398  0.031788 -0.000810 -0.010124
# 46 -0.005475  0.031463  0.016915 -0.013722 -0.032664  0.003520
# 47  0.020067 -0.031498  0.006288 -0.065378 -0.022106  0.043522
# 48  0.029253  0.012926 -0.020284 -0.040231  0.016370  0.021490
# 49 -0.013355  0.032402 -0.003242 -0.014836 -0.016288  0.002088
# 50  0.048365  0.003447  0.006634  0.047218 -0.029646  0.017961
#
# [51 rows x 300 columns]

# %%
print(MC.get_risk(15000)) # shows the risk evaluation on top of the number of simulations defined in the parentheses.
# Out:
# 36.76%

# %%
MC.get_stats() # shows the statistics of the executed Monte Carlo simulation.
# Out:
#                     Statistics
# Mean value              172.35
# Standard deviation       29.87
# Maximum value           275.39
# Minimum value           105.29

# %%
MC.hist(graph_title='GitHub Repository Demo', x_title = 'Time period', y_title = 'Value') # histogram of values.
# Out:
# Histogram plotting initiated...
# CHOSEN METHOD: Basic histogram model.
# Histogram plotting finished.

# %%
MC.hist(x_title = 'Time period', y_title = 'Value', method = 'e') # histogram with Empirical rule applied, BEWARE: this option is currently being worked on so do not use it in any research!!!
# Out:
# Histogram plotting initiated...
# CHOSEN METHOD: Empirical rule.
# Histogram plotting finished.

# %%
print(MC) # explains the object.
# Out:
# Monte Carlo defining object that stores the configuration data for creating 300 simulations in a period of 50 time measurement units.

# %%
print(repr(MC)) # explains the representation of the object.
# Out:
# Monte Carlo defining object that stores the configuration data for creating 300 simulations in a period of 50 time measurement units.

# %%
vandal.__license__ #shows the license.
# Out:
# 'Copyright © 2021-2022 David Kundih. All rights reserved. Licensed under the Apache License, Version 2.0 | For more details about the license and terms of use visit the official vandal documentation linked at https://github.com/dkundih/vandal and https://pypi.org/project/vandal'

# %%
vandal.__contact__ # shows the contact information.
# Out:
# 'dakundih@unin.hr | kundihdavid@gmail.com'

# %%
vandal.__documentation__ # shows the documentation details.
# Out:
# 'https://github.com/dkundih/vandal | https://pypi.org/project/vandal'

# %%
vandal.__donate__ # shows the donation options.
# Out:
# 'https://patreon.com/dkundih | https://buymeacoffee.com/dkundih'

# %%
vandal.__credits__ # shows credits.
# Out:
# ['dkundih <https://github.com/dkundih>']

# %%
vandal.__author__ # shows the author.
# Out:
# 'David Kundih'

# %%
vandal.__copyright__ # shows the copyright information.
# Out:
# 'Copyright © 2021-2022 David Kundih'

# %%
help(vandal) # help on library options and possibilities.
# Out:
# Help on package vandal:
#
# NAME
#     vandal
#
# DESCRIPTION
#     vandal - Data science, Data manipulation and Machine learning library.
#     =====================================================================
#
#     This is a connection to the __init__ file of the vandal library.
#
#     AVAILABLE FEATURES IN THE LIBRARY:
#
#         TOOLKIT (MODULE FUNCTIONS)
#         --------------------------
#
#         set of available data manipulation functions from the vandal library.
#             print(help(any_function_listed_below)) in order to see the function details or print(help(vandal.toolkit)) for all functions at once.
#
#             FUNCTIONS (ACCESSIBLE DIRECTLY FROM THE LIBRARY)
#             ------------------------------------------------
#
#                 random_value(mean, st_dev, **rounded) - gives a random value of mean and standard deviation inputed, if rounded = 'y', value will be rounded.
#
#                 random_pool(mean, st_dev, pool_size, **rounded) - gives random values of mean and standard deviation inputed for the amount of values defined in the pool size, if rounded = 'y', values will be rounded.
#
#                 split_values(data, split_method) - splits the data using a split method character.
#
#                 join_values(data, join_method) - joins the data using a join metod character.
#
#                 replace_values(data, replaced_value, replacing_value) - replaces a defined value with a desired value.
#
#                 list_sort(data, array) - manually sorts data depending on defined array of indexes.
#
#                 index_sort(data, split_method, index_array) - sorts the indicies in a list of values based on the index array defined as [x,x,x].
#
#                 auto_sort(data, split_method, trigger = lambda x: x[0]) - automatically splits all values in a list and sorts them based on the added trigger as lambda x: [x[i], x[i]] and joins them back together.
#
#                 create_password(length) - creates a random password with adjustable lenght (default: length = 8).
#
#                 save_to(file, prefix, func_name, choice) - file saver for code clarity.
#
#                 file_handler(file) - handles the file extension upon import.
#
#         MONTECARLO (OBJECT)
#         -------------------
#
#         vandal.MonteCarlo is a module for performing the Monte Carlo simulation over the defined data with a lot of useful features.
#             print(help(vandal.MonteCarlo)) in order to see available features.
#
#         EOQ (OBJECT)
#         ------------
#
#         vandal.EOQ is a module for finding an Economic order quantity over the defined data with a lot of useful features.
#             print(help(vandal.EOQ)) in order to see available features.
#
#         Dijkstra (OBJECT)
#         -----------------
#
#         vandal.Dijkstra is a module for finding the optimal route between the defined nodes from the place of origin to the final destination.
#             print(help(vandal.Dijkstra)) in order to see available features.
#
#         MCapp (EXECUTABLE CLI MODULE)
#         -------------------------
#
#         vandal.MCapp is an executable function that runs the Command Line Interface of the vandal MonteCarlo module.
#             print(help(vandal.MCapp)) in order to see available features.
#
#         EOQapp (EXECUTABLE CLI MODULE)
#         -------------------------
#
#         vandal.EOQapp is an executable function that runs the Command Line Interface of the vandal EOQ module.
#             print(help(vandal.EOQapp)) in order to see available features.
#
# PACKAGE CONTENTS
#     __main__
#     hub (package)
#     misc (package)
#     objects (package)
#
# SUBMODULES
#     toolkit
#
# DATA
#     __APPversion__ = 'v 1.4.2'
#     __all__ = [<function random_value>, <function random_pool>, <function ...
#     __contact__ = 'dakundih@unin.hr | kundihdavid@gmail.com'
#     __copyright__ = 'Copyright © 2021-2022 David Kundih'
#     __documentation__ = 'https://github.com/dkundih/vandal | https://pypi....
#     __donate__ = 'https://patreon.com/dkundih | https://buymeacoffee.com/d...
#     __license__ = 'Copyright © 2021-2022 David Kundih. All rights r...kund...
#
# VERSION
#     3.6.6
#
# AUTHOR
#     David Kundih
#
# CREDITS
#     ['dkundih <https://github.com/dkundih>']
#
# FILE
#     c:\users\kundi\appdata\local\programs\python\python39\lib\site-packages\vandal\__init__.py

# %%
help(vandal.MonteCarlo) # help on object options and possibilities.
# Out:
# Help on class MonteCarlo in module vandal.objects.montecarlo:
#
# class MonteCarlo(builtins.object)
#  |  MonteCarlo(list_of_values: dict = None, time_seq: int = None, num_sims: int = None, ref_col: int = 0, ref_row: int = 0) -> object
#  |
#  |  (OBJECT INFO)
#  |  -------------
#  |
#  |  eg. MonteCarlo = vandal.MonteCarlo()
#  |
#  |  vandal.MonteCarlo - main class that stores the simulation data.
#  |
#  |      * takes 5 additional arguments.
#  |          list_of_values - pandas dataframe of values.
#  |          time_seq - desired time sequence.
#  |          num_sims - desired number of simulation iterations.
#  |          ref_col (default: ref_col = 0) - column index of the dictionary values.
#  |          ref_row (default: ref_row = 0) - row index on which the starting point of the simulation is created.
#  |      * Requirements:
#  |          dictionary of key, value pair.
#  |
#  |  (OBJECT FUNCTIONS)
#  |  ------------------
#  |
#  |  eg. vandal.MonteCarlo.function()
#  |
#  |      .execute() - executes a Monte Carlo simulation on a defined data set.
#  |          * takes 1 additional argument.
#  |              filtered (defualt: filtered = True) - filters the print option and leaves just the return object.
#  |
#  |      .graph() - plots the Monte Carlo simulation on a graph.
#  |          * takes 5 optional customization arguments. (default: graph_title = 'Monte Carlo simulation', x_title = 'X axis', y_title = 'Y axis', plot_size = (25,10), perform_block = True).
#  |              graph_title - title of the graph.
#  |              x_title - title of the X axis.
#  |              y_title - title on the Y axis.
#  |              plot_size - desired size of the graph. eg. - (x_lenght_num, y_lenght_num). - NOTE: values must be inside the parentheses and divided by a comma.
#  |              perform_block (default: perform_block = True) - False/True may be used depending on the IDE requirements.
#  |
#  |      .get_risk() - calculates the risk of value decrease over time.
#  |          * takes 1 additional argument.
#  |              risk_sims (default: risk_sims = 5000) - number of simulations to perform the risk percantage.
#  |
#  |      .get_stats() - shows the statistics of the Monte Carlo simulation.
#  |          * takes no additional arguments.
#  |
#  |      .get_change() - shows the percentage of Monte Carlo simulation value change for every iteration.
#  |          * takes no additional arguments.
#  |
#  |      .hist() - plots the histogram of Monte Carlo simulation.
#  |          * takes 7 optional customization arguments. (default: graph_title = 'Monte Carlo simulation', x_title = 'X axis', y_title = 'Y axis', plot_size = (25,10), set_bins = None, perform_block = True, method = 'b').
#  |          If method = 'e' is chosen, no customization arguments apply.
#  |              graph_title - title of the graph.
#  |              x_title - title of the X axis.
#  |              y_title - title on the Y axis.
#  |              plot_size - desired size of the graph. eg. - (x_lenght_num, y_lenght_num). - NOTE: values must be inside the parentheses and divided by a comma.
#  |              perform_block (default: perform_block = True) - False/True may be used depending on the IDE requirements.
#  |              method - default method is Basic histogram and it's performed by automation. In order to plot Empirical rule histogram add method = 'e' as the last argument. - NOTE: method of a histogram must be placed within quotation marks.
#  |              set_bins - sets the amount of bins of the histogram. (default: set_bins = self.time_seq)
#  |          * automatically executes the .get_stats() function in order to get standard deviation for the Empirical rule plotting.
#  |
#  |  MCapp (EXECUTABLE CLI MODULE)
#  |  -------------------------
#  |
#  |  vandal.MCapp is an executable function that runs the Command Line Interface of the vandal MonteCarlo module.
#  |      print(help(vandal.MCapp)) in order to see available features.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, list_of_values: dict = None, time_seq: int = None, num_sims: int = None, ref_col: int = 0, ref_row: int = 0) -> object
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self) -> str
#  |      Return repr(self).
#  |
#  |  __str__(self) -> str
#  |      Return str(self).
#  |
#  |  execute(self, filtered: bool = True) -> dict
#  |      # executes a Monte Carlo simulation on a defined data set.
#  |
#  |  get_change(self) -> float
#  |      # shows the percentage of Monte Carlo simulation value change for every iteration.
#  |
#  |  get_risk(self, risk_sims: int = 5000) -> float
#  |      # calculates the risk of negative values occuring.
#  |
#  |  get_stats(self) -> dict
#  |      # shows the statistics of the Monte Carlo simulation.
#  |
#  |  graph(self, graph_title: str = 'Monte Carlo simulation', x_title: str = 'X axis', y_title: str = 'Y axis', plot_size: tuple = (25, 10), perform_block: bool = True) -> object
#  |      # plots the Monte Carlo simulation on a graph.
#  |
#  |  hist(self, graph_title: str = 'Histogram of value frequencies', x_title: str = 'X axis', y_title: str = 'Y axis', plot_size: tuple = (25, 10), perform_block: bool = True, set_bins: int = None, **method: str) -> object
#  |      # plots the histogram of Monte Carlo simulation.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __APPversion__ = 'v 1.4.2'
#  |
#  |  __contact__ = 'dakundih@unin.hr | kundihdavid@gmail.com'
#  |
#  |  __copyright__ = 'Copyright © 2021-2022 David Kundih'
#  |
#  |  __documentation__ = 'https://github.com/dkundih/vandal | https://pypi....
#  |
#  |  __donate__ = 'https://patreon.com/dkundih | https://buymeacoffee.com/d...
#  |
#  |  __license__ = 'Copyright © 2021-2022 David Kundih. All rights r...kund...

# %%
help(vandal.MonteCarlo.graph) #Help on function options and possibilities.
# Out:
# Help on function graph in module vandal.objects.montecarlo:
#
# graph(self, graph_title: str = 'Monte Carlo simulation', x_title: str = 'X axis', y_title: str = 'Y axis', plot_size: tuple = (25, 10), perform_block: bool = True) -> object
#     # plots the Monte Carlo simulation on a graph.

# %%
vandal.__file__ # shows the library path.
# Out:
# 'C:\\Users\\kundi\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\vandal\\__init__.py'

# %%
vandal.__all__ # shows the imported objects and modules from the library in the main module.
# Out:
# [<function vandal.hub.toolkit.random_value(mean, st_dev, **rounded)>,
#  <function vandal.hub.toolkit.random_pool(mean, st_dev, pool_size, **rounded)>,
#  <function vandal.hub.toolkit.split_values(data, split_method)>,
#  <function vandal.hub.toolkit.join_values(data, join_method)>,
#  <function vandal.hub.toolkit.replace_values(data, replaced_value, replacing_value)>,
#  <function vandal.hub.toolkit.list_sort(data, array)>,
#  <function vandal.hub.toolkit.index_sort(data, split_method, index_array)>,
#  <function vandal.hub.toolkit.auto_sort(data, split_method, trigger=<function <lambda> at 0x0000025B3CAACAF0>)>,
#  <function vandal.hub.toolkit.create_password(length=8)>,
#  <function vandal.hub.toolkit.file_handler(file)>,
#  <function vandal.hub.toolkit.save_to(file, prefix, func_name, choice)>,
#  <module 'vandal.hub.toolkit' from 'C:\\Users\\kundi\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\vandal\\hub\\toolkit.py'>,
#  vandal.objects.montecarlo.MonteCarlo,
#  <function vandal.objects.montecarlo.MCapp()>,
#  vandal.objects.eoq.EOQ,
#  <function vandal.objects.eoq.EOQapp()>,
#  vandal.objects.dijkstra.Dijkstra]

# %%
vandal.objects.__all__ # shows the available objects from the objects module.
# Out:
# [vandal.objects.montecarlo.MonteCarlo,
#  vandal.objects.eoq.EOQ,
#  vandal.objects.dijkstra.Dijkstra,
#  <function vandal.objects.montecarlo.MCapp()>,
#  <function vandal.objects.eoq.EOQapp()>]

# %%
vandal.misc.__all__ # shows the meta data from the misc module.
# Out:
# ['David Kundih',
#  'Copyright © 2021-2022 David Kundih',
#  ['dkundih <https://github.com/dkundih>'],
#  'Copyright © 2021-2022 David Kundih. All rights reserved. Licensed under the Apache License, Version 2.0 | For more details about the license and terms of use visit the official vandal documentation linked at https://github.com/dkundih/vandal and https://pypi.org/project/vandal',
#  '3.6.6',
#  'https://github.com/dkundih/vandal | https://pypi.org/project/vandal',
#  'dakundih@unin.hr | kundihdavid@gmail.com',
#  'https://patreon.com/dkundih | https://buymeacoffee.com/dkundih',
#  'v 1.4.2']
