# %% [markdown]
# vandal.MonteCarlo demonstration

# %%
import vandal # vandal 3.8.5 was used in this example.
import pandas as pd # importing pandas to create a DataFrame.

# %%
vandal.__version__ # version used.
# Out:
# '3.8.5'

# %%
MC = vandal.MonteCarlo({
    'Example_data' : [38,37,38,36,36,35,36,34,33,34,35], # example list of values. (ref_col = 0)
    'Example_data2' : [142, 149, 153, 154, 150, 149, 149, 151, 152, 150, 146], # example list of values. (ref_col = 1)
    },
50, 
300, 
ref_col= 1,
ref_row = 6,
) # object defined as MC.

# %%
MC.execute(filtered=False) # executes the Monte Carlo simulation.
# Out:
# Monte Carlo has been set up for 300 simulations in a period of 50 time measurement units and executed.
# NOTE: Use data with reasonable standard deviation in order to prevent exponential growth of the function that cannot be plotted properly, recognize such abnormal values by a + sign anywhere in the data executed below.
# Monte Carlo simulation set up and ready to plot.
#            0           1           2           3           4           5    \
# 0   146.545400  150.709882  146.774547  148.905598  147.095860  150.353763
# 1   149.325046  149.709045  149.968714  146.193224  147.257794  150.621088
# 2   146.281631  153.829301  149.053513  145.849477  145.231832  149.890780
# 3   148.604333  159.654911  145.221167  145.452108  142.955044  152.471220
# 4   149.257243  166.117849  141.850511  150.278693  148.410133  153.626066
# 5   148.617824  162.074502  147.362280  152.405069  150.007370  156.061190
# 6   151.132509  163.465335  150.089535  147.334902  150.505482  157.453968
# 7   156.708560  168.646495  152.217282  144.459579  149.945306  158.611361
# 8   156.001596  176.458311  156.493989  150.194618  143.993116  157.813744
# 9   158.228345  174.884809  161.797961  150.979215  139.678762  157.671741
# 10  158.054684  174.565083  165.213853  151.698063  138.731654  160.370156
# 11  151.357600  171.623093  161.988496  151.367894  140.820430  153.015570
# 12  146.772333  170.277689  164.006304  154.334194  139.893885  151.286274
# 13  148.396249  175.788774  165.065503  155.709449  139.179012  146.987822
# 14  148.455528  180.658721  162.035122  150.502813  134.400133  147.686597
# 15  148.809169  183.712162  161.559090  153.582155  136.161350  150.963334
# 16  147.649335  191.078258  157.104661  154.127722  141.201163  144.757604
# 17  147.577773  191.856753  162.046619  151.190346  144.402329  140.269767
# 18  155.400209  193.990643  166.578062  156.006138  148.041722  145.690148
# 19  162.178748  190.820613  168.284702  156.198901  147.484361  146.711604
# 20  162.224357  187.316397  165.185092  165.090111  150.490085  143.729003
# 21  165.577679  180.852214  167.833144  165.733521  151.486951  139.668811
# 22  159.441497  190.233565  166.598419  170.831675  155.157704  138.735865
# 23  156.906146  196.952516  169.410375  173.311832  161.810750  133.736138
# 24  162.837375  197.387271  175.381426  168.895865  168.513243  138.169165
# 25  160.520554  202.433823  179.867459  168.136554  162.080858  138.914722
# 26  166.438298  200.042353  185.650210  168.807369  168.984257  139.599848
# 27  159.261278  204.952574  187.761981  171.528255  171.688453  140.276653
# 28  161.385702  207.096190  192.080990  170.802954  177.556167  135.264408
# 29  163.354829  203.448298  194.176969  163.318492  185.608939  133.064522
# 30  164.366887  204.650943  195.671774  161.570845  182.738825  136.018637
# 31  165.606873  208.856268  197.045239  170.104636  182.440576  130.805321
# 37 -0.038373  0.002741 -0.000987  0.031212  0.005573  0.005417
# 38  0.006337  0.014508 -0.015461  0.010538 -0.022705  0.001877
# 39  0.007719 -0.008237  0.011170  0.006817 -0.015961 -0.001600
# 40  0.002555  0.075740 -0.012127  0.019402 -0.011756  0.035472
# 41  0.011894  0.006592  0.058436  0.019289  0.027923  0.021139
# 42  0.009300 -0.020229  0.023505 -0.006140 -0.006657  0.029956
# 43 -0.030178 -0.012567 -0.002532 -0.002510  0.012912 -0.013497
# 44  0.026006 -0.024773  0.006513 -0.010491  0.032179  0.002974
# 45 -0.000031  0.024070  0.019015 -0.012356  0.033706  0.039932
# 46  0.017061 -0.005538  0.003700  0.048199  0.001696 -0.005400
# 47 -0.004089  0.004668 -0.013094 -0.004855  0.002900 -0.009337
# 48  0.041774 -0.013967  0.043194 -0.002110  0.032433  0.008829
# 49 -0.005014 -0.018604  0.003869 -0.027472  0.004638 -0.010853
# 50  0.023013 -0.014561  0.005447 -0.021710 -0.010607 -0.025524
#
# [51 rows x 300 columns]

# %%
print(MC.get_risk(15000)) # shows the risk evaluation on top of the number of simulations defined in the parentheses.
# Out:
# 36.28%

# %%
MC.get_stats() # shows the statistics of the executed Monte Carlo simulation.
# Out:
#                     Statistics
# Mean value              175.53
# Standard deviation       29.29
# Maximum value           301.21
# Minimum value           105.45

# %%
MC.hist(graph_title='GitHub Repository Demo', x_title = 'Time period', y_title = 'Value') # histogram of values.
# Out:
# Histogram plotting initiated...
# CHOSEN METHOD: Basic histogram model.
# Histogram plotting finished.

# %%
MC.hist(x_title = 'Time period', y_title = 'Value', method = 'e') # histogram with Empirical rule applied, BEWARE: this option is currently being worked on so do not use it in any research!!!
# Out:
# Histogram plotting initiated...
# CHOSEN METHOD: Empirical rule.
# Histogram plotting finished.

# %%
print(MC) # explains the object.
# Out:
# Monte Carlo defining object that stores the configuration data for creating 300 simulations in a period of 50 time measurement units.

# %%
print(repr(MC)) # explains the representation of the object.
# Out:
# Monte Carlo defining object that stores the configuration data for creating 300 simulations in a period of 50 time measurement units.

# %%
vandal.__license__ #shows the license.
# Out:
# 'Copyright © 2021-2022 David Kundih. All rights reserved. Licensed under the Apache License, Version 2.0 | For more details about the license and terms of use visit the official vandal documentation linked at https://github.com/dkundih/vandal and https://pypi.org/project/vandal'

# %%
vandal.__contact__ # shows the contact information.
# Out:
# 'dakundih@unin.hr | kundihdavid@gmail.com'

# %%
vandal.__documentation__ # shows the documentation details.
# Out:
# 'https://github.com/dkundih/vandal | https://pypi.org/project/vandal'

# %%
vandal.__donate__ # shows the donation options.
# Out:
# 'https://patreon.com/dkundih | https://buymeacoffee.com/dkundih'

# %%
vandal.__credits__ # shows credits.
# Out:
# ['dkundih <https://github.com/dkundih>']

# %%
vandal.__author__ # shows the author.
# Out:
# 'David Kundih'

# %%
vandal.__copyright__ # shows the copyright information.
# Out:
# 'Copyright © 2021-2022 David Kundih'

# %%
help(vandal) # help on library options and possibilities.
# Out:
# Help on package vandal:
#
# NAME
#     vandal
#
# DESCRIPTION
#     vandal - Data science, Data manipulation and Machine learning library.
#     =====================================================================
#
#     This is a connection to the __init__ file of the vandal library.
#
#     AVAILABLE FEATURES IN THE LIBRARY:
#
#         TOOLKIT (MODULE FUNCTIONS)
#         --------------------------
#
#         set of available data manipulation functions from the vandal library.
#             print(help(any_function_listed_below)) in order to see the function details or print(help(vandal.toolkit)) for all functions at once.
#
#             FUNCTIONS (ACCESSIBLE DIRECTLY FROM THE LIBRARY)
#             ------------------------------------------------
#
#                 random_value(mean, st_dev, **rounded) - gives a random value of mean and standard deviation inputed, if rounded = 'y', value will be rounded.
#
#                 random_pool(mean, st_dev, pool_size, **rounded) - gives random values of mean and standard deviation inputed for the amount of values defined in the pool size, if rounded = 'y', values will be rounded.
#
#                 split_values(data, split_method) - splits the data using a split method character.
#
#                 join_values(data, join_method) - joins the data using a join metod character.
#
#                 replace_values(data, replaced_value, replacing_value) - replaces a defined value with a desired value.
#
#                 list_sort(data, array) - manually sorts data depending on defined array of indexes.
#
#                 index_sort(data, split_method, index_array) - sorts the indicies in a list of values based on the index array defined as [x,x,x].
#
#                 auto_sort(data, split_method, trigger = lambda x: x[0]) - automatically splits all values in a list and sorts them based on the added trigger as lambda x: [x[i], x[i]] and joins them back together.
#
#                 create_password(length) - creates a random password with adjustable lenght (default: length = 8).
#
#                 save_to(file, prefix, func_name, choice) - file saver for code clarity.
#
#                 file_handler(file) - handles the file extension upon import.
#
#         MONTECARLO (OBJECT)
#         -------------------
#
#         vandal.MonteCarlo is a module for performing the Monte Carlo simulation over the defined data with a lot of useful features.
#             print(help(vandal.MonteCarlo)) in order to see available features.
#
#         EOQ (OBJECT)
#         ------------
#
#         vandal.EOQ is a module for finding an Economic order quantity over the defined data with a lot of useful features.
#             print(help(vandal.EOQ)) in order to see available features.
#
#         Dijkstra (OBJECT)
#         -----------------
#
#         vandal.Dijkstra is a module for finding the optimal route between the defined nodes from the place of origin to the final destination.
#             print(help(vandal.Dijkstra)) in order to see available features.
#
#         MCapp (EXECUTABLE CLI MODULE)
#         -------------------------
#
#         vandal.MCapp is an executable function that runs the Command Line Interface of the vandal MonteCarlo module.
#             print(help(vandal.MCapp)) in order to see available features.
#
#         EOQapp (EXECUTABLE CLI MODULE)
#         -------------------------
#
#         vandal.EOQapp is an executable function that runs the Command Line Interface of the vandal EOQ module.
#             print(help(vandal.EOQapp)) in order to see available features.
#
# PACKAGE CONTENTS
#     __main__
#     hub (package)
#     misc (package)
#     objects (package)
#
# SUBMODULES
#     toolkit
#
# CLASSES
#     builtins.object
#         vandal.objects.dijkstra.Dijkstra
#         vandal.objects.eoq.EOQ
#         vandal.objects.montecarlo.MonteCarlo
#     builtins.type(builtins.object)
#         logistics.plugins.metaclass.Meta
#
#     class Dijkstra(builtins.object)
#      |  Dijkstra(nodes: dict = None, origin: str = None, destination: str = None) -> object
#      |
#      |  (OBJECT INFO)
#      |  -------------
#      |
#      |  eg. Dijkstra = vandal.Dijkstra()
#      |
#      |  vandal.Dijkstra - main class that contains contains the data of defined nodes, origin and the desired destination.
#      |      * takes 3 additional arguments.
#      |          nodes - dictionary of dictionaries of nodes with their corelating weights.
#      |
#      |          eg.
#      |          nodes = {
#      |          'a':{'b':8,'c':5},
#      |          'b':{'c':2,'d':4},
#      |          'c':{'b':5,'d':4,'e':3},
#      |          'd':{'e':5},
#      |          'e':{'d':6},
#      |          }
#      |
#      |          origin - origin node as a starting point.
#      |          destination - destination node of the desired route.
#      |
#      |  (OBJECT FUNCTIONS)
#      |  ------------------
#      |
#      |  eg. vandal.Dijkstra.function()
#      |
#      |      .execute() - executes the Dijkstra algorithm on top of the defined data.
#      |          * takes 1 additional argument.
#      |              filtered (default: filtered = True) - filters the print option and leaves just the return object.
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, nodes: dict = None, origin: str = None, destination: str = None) -> object
#      |      * initial launch.
#      |
#      |  __repr__(self) -> str
#      |      * class information.
#      |
#      |  __str__(self) -> str
#      |      * class information.
#      |
#      |  execute(self, filtered: bool = True) -> Union[List[List[float]], List[List[str]], List[Dict[str, str]], List[Dict[str, List[float]]]]
#      |      * executes a Dijkstra algorithm route scan on a defined path.
#      |
#      |      - filtered (True/False) - filters the information about path.
#      |      # DEFAULT: Dijkstra.execute(filtered : BooleanType = True.)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __APPversion__ = 'v 1.4.3'
#      |
#      |  __contact__ = 'dakundih@unin.hr | kundihdavid@gmail.com'
#      |
#      |  __copyright__ = 'Copyright © 2021-2022 David Kundih'
#      |
#      |  __documentation__ = 'https://github.com/dkundih/vandal | https://pypi....
#      |
#      |  __donate__ = 'https://patreon.com/dkundih | https://buymeacoffee.com/d...
#      |
#      |  __license__ = 'Copyright © 2021-2022 David Kundih. All rights r...kund...
#
#     class EOQ(builtins.object)
#      |  EOQ(annual_demand_quantity: Union[int, float] = None, order_fixed_cost: Union[int, float] = None, annual_holding_cost: Union[int, float] = None) -> object
#      |
#      |  (OBJECT INFO)
#      |  -------------
#      |
#      |  eg. EOQ = vandal.EOQ()
#      |
#      |  vandal.EOQ - main class that stores the data required for an EOQ simulation.
#      |      * takes 3 additional arguments.
#      |          annual_demand_quantity - integer of demanded quantity in a year.
#      |          order_fixed_cost - integer or float presenting the fixed cost of the order.
#      |          annual_holding_cost - cost of holding the goods in a year.
#      |
#      |  (OBJECT FUNCTIONS)
#      |  ------------------
#      |
#      |  eg. vandal.EOQ.function()
#      |
#      |      .execute() - executes the calculation of EOQ over the defined parameters.
#      |          * takes 1 additional argument.
#      |              filtered (defualt: filtered = True) - filters the print option and leaves just the return object.
#      |
#      |  EOQapp (EXECUTABLE CLI MODULE)
#      |  -------------------------
#      |
#      |  vandal.EOQapp is an executable function that runs the Command Line Interface of the vandal EOQ module.
#      |      print(help(vandal.EOQapp)) in order to see available features.
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, annual_demand_quantity: Union[int, float] = None, order_fixed_cost: Union[int, float] = None, annual_holding_cost: Union[int, float] = None) -> object
#      |      * initial launch.
#      |
#      |  __repr__(self) -> str
#      |      * class information.
#      |
#      |  __str__(self) -> str
#      |      * class information.
#      |
#      |  execute(self, filtered=True) -> Union[int, float]
#      |      * executes the calculation of EOQ over the defined parameters.
#      |
#      |      - filtered (True/False) - filters the data of EOQ initial parameters printed.
#      |      # DEFAULT: EOQ.execute(filtered : BooleanType = True.)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __APPversion__ = 'v 1.4.3'
#      |
#      |  __contact__ = 'dakundih@unin.hr | kundihdavid@gmail.com'
#      |
#      |  __copyright__ = 'Copyright © 2021-2022 David Kundih'
#      |
#      |  __documentation__ = 'https://github.com/dkundih/vandal | https://pypi....
#      |
#      |  __donate__ = 'https://patreon.com/dkundih | https://buymeacoffee.com/d...
#      |
#      |  __license__ = 'Copyright © 2021-2022 David Kundih. All rights r...kund...
#
#     class Meta(builtins.type)
#      |  Meta(name, base, attr) -> object
#      |
#      |  * makes multiple instances of the object available.
#      |
#      |  Method resolution order:
#      |      Meta
#      |      builtins.type
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, *args, **kwargs) -> object
#      |      Call self as a function.
#      |
#      |  __init__(self, name, base, attr) -> object
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.type:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __dir__(self, /)
#      |      Specialized __dir__ implementation for types.
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __instancecheck__(self, instance, /)
#      |      Check if an object is an instance.
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __sizeof__(self, /)
#      |      Return memory consumption of the type object.
#      |
#      |  __subclasscheck__(self, subclass, /)
#      |      Check if a class is a subclass.
#      |
#      |  __subclasses__(self, /)
#      |      Return a list of immediate subclasses.
#      |
#      |  mro(self, /)
#      |      Return a type's method resolution order.
#      |
#      |  ----------------------------------------------------------------------
#      |  Class methods inherited from builtins.type:
#      |
#      |  __prepare__(...) from builtins.type
#      |      __prepare__() -> dict
#      |      used to create the namespace for the class statement
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from builtins.type:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.type:
#      |
#      |  __abstractmethods__
#      |
#      |  __dict__
#      |
#      |  __text_signature__
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from builtins.type:
#      |
#      |  __base__ = <class 'type'>
#      |      type(object_or_name, bases, dict)
#      |      type(object) -> the object's type
#      |      type(name, bases, dict) -> a new type
#      |
#      |
#      |  __bases__ = (<class 'type'>,)
#      |
#      |  __basicsize__ = 880
#      |
#      |  __dictoffset__ = 264
#      |
#      |  __flags__ = 2148292096
#      |
#      |  __itemsize__ = 40
#      |
#      |  __mro__ = (<class 'logistics.plugins.metaclass.Meta'>, <class 'type'>,...
#      |
#      |  __weakrefoffset__ = 368
#
#     class MonteCarlo(builtins.object)
#      |  MonteCarlo(list_of_values: Union[List[float], Dict[str, List[float]]] = None, time_seq: int = None, num_sims: int = None, ref_col: int = 0, ref_row: int = 0) -> object
#      |
#      |  (OBJECT INFO)
#      |  -------------
#      |
#      |  eg. MonteCarlo = vandal.MonteCarlo()
#      |
#      |  vandal.MonteCarlo - main class that stores the simulation data.
#      |
#      |      * takes 5 additional arguments.
#      |          list_of_values - pandas dataframe of values.
#      |          time_seq - desired time sequence.
#      |          num_sims - desired number of simulation iterations.
#      |          ref_col (default: ref_col = 0) - column index of the dictionary values.
#      |          ref_row (default: ref_row = 0) - row index on which the starting point of the simulation is created.
#      |      * Requirements:
#      |          data stored as dictionary of key, value pair | list | numpy array | pandas DataFrame.
#      |
#      |  (OBJECT FUNCTIONS)
#      |  ------------------
#      |
#      |  eg. vandal.MonteCarlo.function()
#      |
#      |      .execute() - executes a Monte Carlo simulation on a defined data set.
#      |          * takes 1 additional argument.
#      |              filtered (defualt: filtered = True) - filters the print option and leaves just the return object.
#      |
#      |      .graph() - plots the Monte Carlo simulation on a graph.
#      |          * takes 5 optional customization arguments. (default: graph_title = 'Monte Carlo simulation', x_title = 'X axis', y_title = 'Y axis', plot_size = (25,10), perform_block = True).
#      |              graph_title - title of the graph.
#      |              x_title - title of the X axis.
#      |              y_title - title on the Y axis.
#      |              plot_size - desired size of the graph. eg. - (x_lenght_num, y_lenght_num). - NOTE: values must be inside the parentheses and divided by a comma.
#      |              perform_block (default: perform_block = True) - False/True may be used depending on the IDE requirements.
#      |
#      |      .get_risk() - calculates the risk of value decrease over time.
#      |          * takes 1 additional argument.
#      |              risk_sims (default: risk_sims = 5000) - number of simulations to perform the risk percantage.
#      |
#      |      .get_stats() - shows the statistics of the Monte Carlo simulation.
#      |          * takes no additional arguments.
#      |
#      |      .get_change() - shows the percentage of Monte Carlo simulation value change for every iteration.
#      |          * takes no additional arguments.
#      |
#      |      .hist() - plots the histogram of Monte Carlo simulation.
#      |          * takes 7 optional customization arguments. (default: graph_title = 'Monte Carlo simulation', x_title = 'X axis', y_title = 'Y axis', plot_size = (25,10), set_bins = None, perform_block = True, method = 'b').
#      |          If method = 'e' is chosen, no customization arguments apply.
#      |              graph_title - title of the graph.
#      |              x_title - title of the X axis.
#      |              y_title - title on the Y axis.
#      |              plot_size - desired size of the graph. eg. - (x_lenght_num, y_lenght_num). - NOTE: values must be inside the parentheses and divided by a comma.
#      |              perform_block (default: perform_block = True) - False/True may be used depending on the IDE requirements.
#      |              method - default method is Basic histogram and it's performed by automation. In order to plot Empirical rule histogram add method = 'e' as the last argument. - NOTE: method of a histogram must be placed within quotation marks.
#      |              set_bins - sets the amount of bins of the histogram. (default: set_bins = self.time_seq)
#      |          * automatically executes the .get_stats() function in order to get standard deviation for the Empirical rule plotting.
#      |
#      |  MCapp (EXECUTABLE CLI MODULE)
#      |  -------------------------
#      |
#      |  vandal.MCapp is an executable function that runs the Command Line Interface of the vandal MonteCarlo module.
#      |      print(help(vandal.MCapp)) in order to see available features.
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, list_of_values: Union[List[float], Dict[str, List[float]]] = None, time_seq: int = None, num_sims: int = None, ref_col: int = 0, ref_row: int = 0) -> object
#      |      * initial launch.
#      |
#      |  __repr__(self) -> str
#      |      * class information.
#      |
#      |  __str__(self) -> str
#      |      * class information.
#      |
#      |  execute(self, filtered: bool = True) -> Union[List[List[float]], List[Dict[str, List[float]]]]
#      |      * executes a Monte Carlo simulation on a defined data set.
#      |
#      |      - filtered (True/False) - filters the data setup print and warnings.
#      |      # DEFAULT: MonteCarlo.execute(filtered : BooleanType = True.)
#      |
#      |  get_change(self) -> Union[List[List[float]], List[Dict[str, List[float]]]]
#      |      * shows the percentage of Monte Carlo simulation value change for every iteration.
#      |
#      |  get_risk(self, risk_sims: int = 5000) -> Union[int, float]
#      |      * calculates the risk of negative values occuring.
#      |
#      |      - risk_sims - number of simulations to run risk evaluation on.
#      |      # DEFAULT: MonteCarlo.get_risk(risk_sims : IntegerType = 5000.)
#      |
#      |  get_stats(self) -> Union[List[List[float]], List[List[str]], List[Dict[str, str]], List[Dict[str, List[float]]]]
#      |      * shows the statistics of the Monte Carlo simulation.
#      |
#      |  graph(self, graph_title: str = 'Monte Carlo simulation', x_title: str = 'X axis', y_title: str = 'Y axis', plot_size: tuple = (25, 10), perform_block: bool = True) -> object
#      |      * plots the Monte Carlo simulation on a graph.
#      |
#      |      - graph title - sets a graph title.
#      |      - x_title - sets an x axis title.
#      |      - y_title - sets and y axis title.
#      |      - plot_size - sets a size of graph in a tuple (eg. (x,y).)
#      |      - perform_block (True/False) - customizable wheel to disable block in some IDEs.
#      |      # DEFAULT: MonteCarlo.graph(graph_title : StringType = 'Monte Carlo simulation', x_title : StringType = 'X axis', y_title : StringType = 'Y axis', plot_size : TupleType = (25,10), perform_block : BooleanType = True.)
#      |
#      |  hist(self, graph_title: str = 'Histogram of value frequencies', x_title: str = 'X axis', y_title: str = 'Y axis', plot_size: tuple = (25, 10), perform_block: bool = True, set_bins: int = None, **method: str) -> object
#      |      * plots the histogram of Monte Carlo simulation.
#      |
#      |      - graph title - sets a graph title.
#      |      - x_title - sets an x axis title.
#      |      - y_title - sets and y axis title.
#      |      - plot_size - sets a size of graph in a tuple (eg. (x,y).)
#      |      - perform_block (True/False) - customizable wheel to disable block in some IDEs.
#      |      - set_bins - sets amount of histogram bins.
#      |      - **method ('e' - empirical, 'b' - basic)- method of a histogram.
#      |      # DEFAULT: MonteCarlo.hist(graph_title : StringType = 'Histogram of value frequencies', x_title : StringType = 'X axis', y_title : StringType = 'Y axis', plot_size : TupleType = (25,10), perform_block : BooleanType = True,set_bins : IntegerType = None, **method : StringType.)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __APPversion__ = 'v 1.4.3'
#      |
#      |  __contact__ = 'dakundih@unin.hr | kundihdavid@gmail.com'
#      |
#      |  __copyright__ = 'Copyright © 2021-2022 David Kundih'
#      |
#      |  __documentation__ = 'https://github.com/dkundih/vandal | https://pypi....
#      |
#      |  __donate__ = 'https://patreon.com/dkundih | https://buymeacoffee.com/d...
#      |
#      |  __license__ = 'Copyright © 2021-2022 David Kundih. All rights r...kund...
#
# FUNCTIONS
#     EOQapp()
#         runs as:
#
#             * IDE: vandal.EOQapp()
#             * TERMINAL: python -m vandal -e eoq / python -m vandal --entry eoq
#
#     MCapp()
#         runs as:
#
#             * IDE: vandal.MCapp()
#             * TERMINAL: python -m vandal -e montecarlo / python -m vandal --entry montecarlo
#
#     auto_sort(data, split_method, trigger=<function <lambda> at 0x0000023ED9022F70>)
#         # automatically splits all values in a list and sorts them based on the added trigger as lambda x: [x[i], x[i]] and joins them back together.
#
#     create_password(length=8)
#         # creates a random password with adjustable lenght (default: length = 8).
#
#     file_handler(file)
#         # handles the file extenstion upon import.
#
#     index_sort(data, split_method, index_array)
#         # sorts the indicies in a list of values based on the index array defined as [x,x,x].
#
#     join_values(data, join_method)
#         # joins the data using a join metod character.
#
#     list_sort(data, array)
#         # manually sorts data depending on defined array of indexes.
#
#     random_pool(mean, st_dev, pool_size, **rounded)
#         # gives random values of mean and standard deviation inputed for the amount of values defined in the pool size, if rounded = 'y', values will be rounded.
#
#     random_value(mean, st_dev, **rounded)
#         # gives a random value of mean and standard deviation inputed, if rounded = 'y', value will be rounded.
#
#     replace_values(data, replaced_value, replacing_value)
#         # replaces a defined value with a desired value.
#
#     save_to(file, prefix, func_name, choice)
#         # file saver for code clarity.
#
#     split_values(data, split_method)
#         # splits the data using a split method character.
#
# DATA
#     __APPversion__ = 'v 1.4.3'
#     __all__ = ['random_value', 'random_pool', 'split_values', 'join_values...
#     __contact__ = 'dakundih@unin.hr | kundihdavid@gmail.com'
#     __copyright__ = 'Copyright © 2021-2022 David Kundih'
#     __documentation__ = 'https://github.com/dkundih/vandal | https://pypi....
#     __donate__ = 'https://patreon.com/dkundih | https://buymeacoffee.com/d...
#     __license__ = 'Copyright © 2021-2022 David Kundih. All rights r...kund...
#
# VERSION
#     3.8.5
#
# AUTHOR
#     David Kundih
#
# CREDITS
#     ['dkundih <https://github.com/dkundih>']
#
# FILE
#     c:\users\kundi\appdata\local\programs\python\python39\lib\site-packages\vandal\__init__.py

# %%
help(vandal.MonteCarlo) # help on object options and possibilities.
# Out:
# Help on class MonteCarlo in module vandal.objects.montecarlo:
#
# class MonteCarlo(builtins.object)
#  |  MonteCarlo(list_of_values: Union[List[float], Dict[str, List[float]]] = None, time_seq: int = None, num_sims: int = None, ref_col: int = 0, ref_row: int = 0) -> object
#  |
#  |  (OBJECT INFO)
#  |  -------------
#  |
#  |  eg. MonteCarlo = vandal.MonteCarlo()
#  |
#  |  vandal.MonteCarlo - main class that stores the simulation data.
#  |
#  |      * takes 5 additional arguments.
#  |          list_of_values - pandas dataframe of values.
#  |          time_seq - desired time sequence.
#  |          num_sims - desired number of simulation iterations.
#  |          ref_col (default: ref_col = 0) - column index of the dictionary values.
#  |          ref_row (default: ref_row = 0) - row index on which the starting point of the simulation is created.
#  |      * Requirements:
#  |          data stored as dictionary of key, value pair | list | numpy array | pandas DataFrame.
#  |
#  |  (OBJECT FUNCTIONS)
#  |  ------------------
#  |
#  |  eg. vandal.MonteCarlo.function()
#  |
#  |      .execute() - executes a Monte Carlo simulation on a defined data set.
#  |          * takes 1 additional argument.
#  |              filtered (defualt: filtered = True) - filters the print option and leaves just the return object.
#  |
#  |      .graph() - plots the Monte Carlo simulation on a graph.
#  |          * takes 5 optional customization arguments. (default: graph_title = 'Monte Carlo simulation', x_title = 'X axis', y_title = 'Y axis', plot_size = (25,10), perform_block = True).
#  |              graph_title - title of the graph.
#  |              x_title - title of the X axis.
#  |              y_title - title on the Y axis.
#  |              plot_size - desired size of the graph. eg. - (x_lenght_num, y_lenght_num). - NOTE: values must be inside the parentheses and divided by a comma.
#  |              perform_block (default: perform_block = True) - False/True may be used depending on the IDE requirements.
#  |
#  |      .get_risk() - calculates the risk of value decrease over time.
#  |          * takes 1 additional argument.
#  |              risk_sims (default: risk_sims = 5000) - number of simulations to perform the risk percantage.
#  |
#  |      .get_stats() - shows the statistics of the Monte Carlo simulation.
#  |          * takes no additional arguments.
#  |
#  |      .get_change() - shows the percentage of Monte Carlo simulation value change for every iteration.
#  |          * takes no additional arguments.
#  |
#  |      .hist() - plots the histogram of Monte Carlo simulation.
#  |          * takes 7 optional customization arguments. (default: graph_title = 'Monte Carlo simulation', x_title = 'X axis', y_title = 'Y axis', plot_size = (25,10), set_bins = None, perform_block = True, method = 'b').
#  |          If method = 'e' is chosen, no customization arguments apply.
#  |              graph_title - title of the graph.
#  |              x_title - title of the X axis.
#  |              y_title - title on the Y axis.
#  |              plot_size - desired size of the graph. eg. - (x_lenght_num, y_lenght_num). - NOTE: values must be inside the parentheses and divided by a comma.
#  |              perform_block (default: perform_block = True) - False/True may be used depending on the IDE requirements.
#  |              method - default method is Basic histogram and it's performed by automation. In order to plot Empirical rule histogram add method = 'e' as the last argument. - NOTE: method of a histogram must be placed within quotation marks.
#  |              set_bins - sets the amount of bins of the histogram. (default: set_bins = self.time_seq)
#  |          * automatically executes the .get_stats() function in order to get standard deviation for the Empirical rule plotting.
#  |
#  |  MCapp (EXECUTABLE CLI MODULE)
#  |  -------------------------
#  |
#  |  vandal.MCapp is an executable function that runs the Command Line Interface of the vandal MonteCarlo module.
#  |      print(help(vandal.MCapp)) in order to see available features.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, list_of_values: Union[List[float], Dict[str, List[float]]] = None, time_seq: int = None, num_sims: int = None, ref_col: int = 0, ref_row: int = 0) -> object
#  |      * initial launch.
#  |
#  |  __repr__(self) -> str
#  |      * class information.
#  |
#  |  __str__(self) -> str
#  |      * class information.
#  |
#  |  execute(self, filtered: bool = True) -> Union[List[List[float]], List[Dict[str, List[float]]]]
#  |      * executes a Monte Carlo simulation on a defined data set.
#  |
#  |      - filtered (True/False) - filters the data setup print and warnings.
#  |      # DEFAULT: MonteCarlo.execute(filtered : BooleanType = True.)
#  |
#  |  get_change(self) -> Union[List[List[float]], List[Dict[str, List[float]]]]
#  |      * shows the percentage of Monte Carlo simulation value change for every iteration.
#  |
#  |  get_risk(self, risk_sims: int = 5000) -> Union[int, float]
#  |      * calculates the risk of negative values occuring.
#  |
#  |      - risk_sims - number of simulations to run risk evaluation on.
#  |      # DEFAULT: MonteCarlo.get_risk(risk_sims : IntegerType = 5000.)
#  |
#  |  get_stats(self) -> Union[List[List[float]], List[List[str]], List[Dict[str, str]], List[Dict[str, List[float]]]]
#  |      * shows the statistics of the Monte Carlo simulation.
#  |
#  |  graph(self, graph_title: str = 'Monte Carlo simulation', x_title: str = 'X axis', y_title: str = 'Y axis', plot_size: tuple = (25, 10), perform_block: bool = True) -> object
#  |      * plots the Monte Carlo simulation on a graph.
#  |
#  |      - graph title - sets a graph title.
#  |      - x_title - sets an x axis title.
#  |      - y_title - sets and y axis title.
#  |      - plot_size - sets a size of graph in a tuple (eg. (x,y).)
#  |      - perform_block (True/False) - customizable wheel to disable block in some IDEs.
#  |      # DEFAULT: MonteCarlo.graph(graph_title : StringType = 'Monte Carlo simulation', x_title : StringType = 'X axis', y_title : StringType = 'Y axis', plot_size : TupleType = (25,10), perform_block : BooleanType = True.)
#  |
#  |  hist(self, graph_title: str = 'Histogram of value frequencies', x_title: str = 'X axis', y_title: str = 'Y axis', plot_size: tuple = (25, 10), perform_block: bool = True, set_bins: int = None, **method: str) -> object
#  |      * plots the histogram of Monte Carlo simulation.
#  |
#  |      - graph title - sets a graph title.
#  |      - x_title - sets an x axis title.
#  |      - y_title - sets and y axis title.
#  |      - plot_size - sets a size of graph in a tuple (eg. (x,y).)
#  |      - perform_block (True/False) - customizable wheel to disable block in some IDEs.
#  |      - set_bins - sets amount of histogram bins.
#  |      - **method ('e' - empirical, 'b' - basic)- method of a histogram.
#  |      # DEFAULT: MonteCarlo.hist(graph_title : StringType = 'Histogram of value frequencies', x_title : StringType = 'X axis', y_title : StringType = 'Y axis', plot_size : TupleType = (25,10), perform_block : BooleanType = True,set_bins : IntegerType = None, **method : StringType.)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __APPversion__ = 'v 1.4.3'
#  |
#  |  __contact__ = 'dakundih@unin.hr | kundihdavid@gmail.com'
#  |
#  |  __copyright__ = 'Copyright © 2021-2022 David Kundih'
#  |
#  |  __documentation__ = 'https://github.com/dkundih/vandal | https://pypi....
#  |
#  |  __donate__ = 'https://patreon.com/dkundih | https://buymeacoffee.com/d...
#  |
#  |  __license__ = 'Copyright © 2021-2022 David Kundih. All rights r...kund...

# %%
help(vandal.MonteCarlo.graph) #Help on function options and possibilities.
# Out:
# Help on function graph in module vandal.objects.montecarlo:
#
# graph(self, graph_title: str = 'Monte Carlo simulation', x_title: str = 'X axis', y_title: str = 'Y axis', plot_size: tuple = (25, 10), perform_block: bool = True) -> object
#     * plots the Monte Carlo simulation on a graph.
#
#     - graph title - sets a graph title.
#     - x_title - sets an x axis title.
#     - y_title - sets and y axis title.
#     - plot_size - sets a size of graph in a tuple (eg. (x,y).)
#     - perform_block (True/False) - customizable wheel to disable block in some IDEs.
#     # DEFAULT: MonteCarlo.graph(graph_title : StringType = 'Monte Carlo simulation', x_title : StringType = 'X axis', y_title : StringType = 'Y axis', plot_size : TupleType = (25,10), perform_block : BooleanType = True.)

# %%
vandal.__file__ # shows the library path.
# Out:
# 'C:\\Users\\kundi\\AppData\\Local\\Programs\\Python\\Python39\\lib\\site-packages\\vandal\\__init__.py'

# %%
vandal.__all__ # shows the imported objects and modules from the library in the main module.
# Out:
# ['random_value',
#  'random_pool',
#  'split_values',
#  'join_values',
#  'replace_values',
#  'list_sort',
#  'index_sort',
#  'auto_sort',
#  'create_password',
#  'file_handler',
#  'save_to',
#  'toolkit',
#  'MonteCarlo',
#  'MCapp',
#  'EOQ',
#  'EOQapp',
#  'Dijkstra',
#  'Meta']

# %%
vandal.objects.__all__ # shows the available objects from the objects module.
# Out:
# ['MonteCarlo', 'EOQ', 'Dijkstra', 'MCapp', 'EOQapp', 'Meta']

# %%
vandal.misc.__all__ # shows the meta data from the misc module.
# Out:
# ['David Kundih',
#  'Copyright © 2021-2022 David Kundih',
#  ['dkundih <https://github.com/dkundih>'],
#  'Copyright © 2021-2022 David Kundih. All rights reserved. Licensed under the Apache License, Version 2.0 | For more details about the license and terms of use visit the official vandal documentation linked at https://github.com/dkundih/vandal and https://pypi.org/project/vandal',
#  '3.8.5',
#  'https://github.com/dkundih/vandal | https://pypi.org/project/vandal',
#  'dakundih@unin.hr | kundihdavid@gmail.com',
#  'https://patreon.com/dkundih | https://buymeacoffee.com/dkundih',
#  'v 1.4.3']
